# %% [markdown]
# # CFTC data
#
# Scraper for Commitment of Traders from CFTC.

# %% [markdown]
# ## Compare files CFTC x ICE
#
# Let's compare file schemas.

# %%
filename = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv'

import pandas as pd
df = pd.read_csv(filename,
                 skip_blank_lines=True,
                 na_values=[' ', '#VALUE!'],
                 index_col = False,
                 header=0
                 )

file_cftc = r'C:\Users\ROSA_L\Downloads\f_year.xls'
df_cftc = pd.read_excel(file_cftc, engine='xlrd')

# %%
ice_cols = set(df.columns)
cftc_cols = set(df_cftc.columns)

print(f'lenght ice: {len(ice_cols)}')
print(f'lenght cftc: {len(cftc_cols)}')

print(f'ice - cftc: {sorted(ice_cols - cftc_cols)}')
print('\n')
print(f'cftc - ice: {sorted(cftc_cols - ice_cols)}')

# %%
cftc_ice_mapping = {'M_Money_Positions_Long_ALL': 'M_Money_Positions_Long_All', 
                    'M_Money_Positions_Short_ALL': 'M_Money_Positions_Short_All', 
                    'M_Money_Positions_Spread_ALL': 'M_Money_Positions_Spread_All', 
                    'Other_Rept_Positions_Long_ALL': 'Other_Rept_Positions_Long_All', 
                    'Other_Rept_Positions_Short_ALL': 'Other_Rept_Positions_Short_All', 
                    'Other_Rept_Positions_Spread_ALL': 'Other_Rept_Positions_Spread_All', 
                    'Other_Rept_Positions_Spread_Othr': 'Other_Rept_Positions_Spread_Other', 
                    'Pct_of_OI_Other_Rept_Spread_Othr': 'Pct_of_OI_Other_Rept_Spread_Other', 
                    'Prod_Merc_Positions_Long_ALL': 'Prod_Merc_Positions_Long_All', 
                    'Prod_Merc_Positions_Short_ALL': 'Prod_Merc_Positions_Short_All', 
                    #'Report_Date_as_MM_DD_YYYY': 'As_of_Date_In_Form_YYMMDD', 
                    'Swap__Positions_Short_All': 'Swap_Positions_Short_All', 
                    'Swap__Positions_Spread_All': 'Swap_Positions_Spread_All'}

df_cftc.rename(columns=cftc_ice_mapping, inplace=True)

ice_cols = set(df.columns)
cftc_cols = set(df_cftc.columns)

print(f'ice - cftc: {sorted(ice_cols - cftc_cols)}')
print('\n')
print(f'cftc - ice: {sorted(cftc_cols - ice_cols)}')

# %% [markdown]
# To make these 2 scrapers share the same table, we need to:
#
# - add column Report_Date_as_MM_DD_YYYY
# - add provider column
# - fill in provider dimension

# %% [markdown]
# ## Test scraper
# Let's test the scraper.

# %%
# %cd ..
# Out:
# C:\Users\ROSA_L\PycharmProjects\scraper

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logger = logging.getLogger()
logging.basicConfig(level=logging.DEBUG)
logger.setLevel(logging.DEBUG)

# %%
from scraper.core import factory

# %%
job = factory.get_scraper_job('gov_cftc', 'futures_and_options_comb', full_load=True)
#job = factory.get_scraper_job('gov_cftc', 'futures_and_options_comb')
# Out:
# DEBUG:scraper.core.factory:Loading module scraper.jobs.gov_cftc.futures_and_options_comb
# DEBUG:scraper.core.factory:Getting class FuturesAndOptionsCombJob

# %%
job.get_sources()

# %%
[vars(source) for source in job.sources]

# %%
job.download_and_get_checksum()
job.rm_sources_up_to_date()
job.transform()

# %%
job.data

# %%
job.run()
# Out:
# INFO:scraper.jobs.gov_cftc.futures_and_options_comb:Defining list of files to load.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Start year: 2017
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Generating source files for com
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for com and 2021
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for com and 2020
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for com and 2019
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for com and 2018
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for com and 2017
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for com and hist_2006_2016
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Generating source files for fut
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for fut and 2021
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for fut and 2020
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for fut and 2019
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for fut and 2018
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for fut and 2017
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Creating source for fut and hist_2006_2016
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/source
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source HTTP/1.1" 200 768256
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size before: 12
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size after: 0
# DEBUG:scraper.core.job:download: True, parallel download: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_2021.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/com_disagg_txt_2017.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/com_disagg_txt_2019.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_2019.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/com_disagg_txt_2021.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_2018.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/com_disagg_txt_2018.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/com_disagg_txt_hist_2006_2016.zip HTTP/1.1" 301 300
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_2017.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_2020.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/com_disagg_txt_2020.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_hist_2006_2016.zip HTTP/1.1" 301 300
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/com_disagg_txt_2019.zip HTTP/1.1" 200 2056717
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_2021.zip HTTP/1.1" 200 591301
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/com_disagg_txt_2017.zip HTTP/1.1" 200 1794263
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/com_disagg_txt_hist_2006_2016.zip HTTP/1.1" 200 12912932
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_hist_2006_2016.zip HTTP/1.1" 200 12240715
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_2020.zip HTTP/1.1" 200 1930322
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/com_disagg_txt_2021.zip HTTP/1.1" 200 612886
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/com_disagg_txt_2020.zip HTTP/1.1" 200 2005733
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_2019.zip HTTP/1.1" 200 1981332
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_2017.zip HTTP/1.1" 200 1805242
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_2018.zip HTTP/1.1" 200 1961740
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/com_disagg_txt_2018.zip HTTP/1.1" 200 2047343
# INFO:scraper.core.utils:download_and_get_checksum: 5036.46183013916 ms
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_h06-16
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_h06-16 HTTP/1.1" 200 732
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_2017
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2017 HTTP/1.1" 200 700
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_2018
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2018 HTTP/1.1" 200 700
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_2019
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2019 HTTP/1.1" 200 700
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_2020
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2020 HTTP/1.1" 200 700
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_2021
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2021 HTTP/1.1" 200 723
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_com_disagg_txt_h06-16
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_h06-16 HTTP/1.1" 200 771
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_com_disagg_txt_2017
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2017 HTTP/1.1" 200 739
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_com_disagg_txt_2018
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2018 HTTP/1.1" 200 739
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_com_disagg_txt_2019
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2019 HTTP/1.1" 200 739
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_com_disagg_txt_2020
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2020 HTTP/1.1" 200 739
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_com_disagg_txt_2021
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2021 HTTP/1.1" 200 739
# INFO:scraper.core.utils:rm_sources_up_to_date: 493.8359260559082 ms
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Transforming provider ...
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Adding provider to dynamic_dim: {'code': 'GOV_CFTC', 'long_name': 'CFTC - Commodity Futures Trading Commission', 'url': 'https://www.cftc.gov/'}
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/provider
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/provider HTTP/1.1" 200 6922
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size after: 0
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading 12 files in parallel...
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2021.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2020.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2019.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading c_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2021.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading c_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2019.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading c_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2020.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:c_year.txt: 3271 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2018.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading c_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2018.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:c_year.txt: 11237 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:c_year.txt: 11097 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2017.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading c_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2017.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_hist_2006_2016.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C_Disagg06_16.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_hist_2006_2016.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:c_year.txt: 11232 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2021.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading f_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2021.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:f_year.txt: 3169 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2020.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading f_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2020.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:c_year.txt: 10651 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2019.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading f_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2019.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:f_year.txt: 10786 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2018.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading f_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2018.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:f_year.txt: 10954 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2017.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading f_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2017.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:f_year.txt: 10874 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_hist_2006_2016.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Reading F_Disagg06_16.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_hist_2006_2016.zip
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:f_year.txt: 10204 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:C_Disagg06_16.txt: 73248 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:F_Disagg06_16.txt: 70199 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Concatenating results ...
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Loading 236922 rows to self.data
# DEBUG:scraper.core.job:Running insert_new_dynamic_dim(): 2 items
# DEBUG:scraper.core.job:Processing source: size 0
# DEBUG:scraper.core.job:Processing provider: size 0
# INFO:scraper.core.utils:insert_new_dynamic_dim: 2.996683120727539 ms
# INFO:scraper.jobs.gov_cftc.futures_and_options_comb:Writing to database.
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Database: mssql+pyodbc://omr:Sekiyu8trd@vipenta.iea.org/external_db_dev?driver=ODBC+Driver+13+for+SQL+Server
# DEBUG:scraper.jobs.gov_cftc.futures_and_options_comb:Cleaning table main.futures_options_data for provider GOV_CFTC
# INFO:scraper.jobs.gov_cftc.futures_and_options_comb:Loading 236922 rows to database.
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2021 HTTP/1.1" 200 739
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7039 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2020 HTTP/1.1" 200 739
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7040 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2019 HTTP/1.1" 200 739
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7042 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2018 HTTP/1.1" 200 739
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7043 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_2017 HTTP/1.1" 200 739
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7044 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_com_disagg_txt_h06-16 HTTP/1.1" 200 771
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7041 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2021 HTTP/1.1" 200 723
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7058 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2020 HTTP/1.1" 200 700
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7059 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2019 HTTP/1.1" 200 700
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7060 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2018 HTTP/1.1" 200 700
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7061 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2017 HTTP/1.1" 200 700
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7062 HTTP/1.1" 201 10
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_h06-16 HTTP/1.1" 200 732
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7063 HTTP/1.1" 201 10
# INFO:scraper.core.utils:update_sources_metadata: 979.7582626342773 ms

# %% [markdown]
# ### Test futures only

# %%
# job = factory.get_scraper_job('gov_cftc', 'futures_only')
job = factory.get_scraper_job('gov_cftc', 'futures_only', full_load=True)
# Out:
# DEBUG:scraper.core.factory:Loading module scraper.jobs.gov_cftc.futures_only
# DEBUG:scraper.core.factory:Getting class FuturesOnlyJob

# %%
job.run()
# Out:
# INFO:scraper.jobs.gov_cftc.futures_only:Defining list of files to load.
# DEBUG:scraper.jobs.gov_cftc.futures_only:Start year: 2021
# DEBUG:scraper.jobs.gov_cftc.futures_only:Creating source for 2021
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/source
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source HTTP/1.1" 200 767979
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size after: 0
# DEBUG:scraper.core.job:download: True, parallel download: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.cftc.gov:443
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /files/dea/history/fut_disagg_txt_2021.zip HTTP/1.1" 301 290
# DEBUG:urllib3.connectionpool:https://www.cftc.gov:443 "GET /sites/default/files/files/dea/history/fut_disagg_txt_2021.zip HTTP/1.1" 200 591301
# INFO:scraper.core.utils:download_and_get_checksum: 1779.0374755859375 ms
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing gov_cftc_fut_disagg_txt_2021
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2021 HTTP/1.1" 200 700
# INFO:scraper.core.utils:rm_sources_up_to_date: 953.7737369537354 ms
# DEBUG:scraper.jobs.gov_cftc.futures_only:Transforming provider ...
# DEBUG:scraper.jobs.gov_cftc.futures_only:Adding provider to dynamic_dim: {'code': 'GOV_CFTC', 'long_name': 'CFTC - Commodity Futures Trading Commission', 'url': 'https://www.cftc.gov/'}
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/provider
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/provider HTTP/1.1" 200 6922
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size after: 0
# DEBUG:scraper.jobs.gov_cftc.futures_only:Reading 1 files in parallel...
# DEBUG:scraper.jobs.gov_cftc.futures_only:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2021.zip
# DEBUG:scraper.jobs.gov_cftc.futures_only:Reading f_year.txt from C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_fut_disagg_txt_2021.zip
# DEBUG:scraper.jobs.gov_cftc.futures_only:f_year.txt: 3169 rows loaded.
# DEBUG:scraper.jobs.gov_cftc.futures_only:Concatenating results ...
# DEBUG:scraper.jobs.gov_cftc.futures_only:Loading 3169 rows to self.data
# DEBUG:scraper.core.job:Running insert_new_dynamic_dim(): 2 items
# DEBUG:scraper.core.job:Processing source: size 0
# DEBUG:scraper.core.job:Processing provider: size 0
# INFO:scraper.core.utils:insert_new_dynamic_dim: 1.9989013671875 ms
# INFO:scraper.jobs.gov_cftc.futures_only:Writing to database.
# DEBUG:scraper.jobs.gov_cftc.futures_only:Database: mssql+pyodbc://omr:Sekiyu8trd@vipenta.iea.org/external_db_dev?driver=ODBC+Driver+13+for+SQL+Server
# DEBUG:scraper.jobs.gov_cftc.futures_only:Loading 3169 rows to temporary table #futures_options_temp
# DEBUG:scraper.jobs.gov_cftc.futures_only:Merging data from #futures_options_temp into futures_options_data
# DEBUG:scraper.jobs.gov_cftc.futures_only:Merge query: MERGE main.futures_options_data target
# USING main.#futures_options_temp as source
# ON (target.[provider] = source.[provider] AND target.[Week_of_Release] = source.[Week_of_Release] AND target.[CFTC_Contract_Market_Code] = source.[CFTC_Contract_Market_Code] AND target.[CFTC_Market_Code] = source.[CFTC_Market_Code] AND target.[CFTC_Region_Code] = source.[CFTC_Region_Code] AND target.[CFTC_Commodity_Code] = source.[CFTC_Commodity_Code] AND target.[FutOnly_or_Combined] = source.[FutOnly_or_Combined])
# WHEN MATCHED AND (target.[Market_and_Exchange_Names] <> source.[Market_and_Exchange_Names] OR target.[As_of_Date_In_Form_YYMMDD] <> source.[As_of_Date_In_Form_YYMMDD] OR target.[Report_Date_as_YYYY-MM-DD] <> source.[Report_Date_as_YYYY-MM-DD] OR target.[Open_Interest_All] <> source.[Open_Interest_All] OR target.[Prod_Merc_Positions_Long_All] <> source.[Prod_Merc_Positions_Long_All] OR target.[Prod_Merc_Positions_Short_All] <> source.[Prod_Merc_Positions_Short_All] OR target.[Swap_Positions_Long_All] <> source.[Swap_Positions_Long_All] OR target.[Swap_Positions_Short_All] <> source.[Swap_Positions_Short_All] OR target.[Swap_Positions_Spread_All] <> source.[Swap_Positions_Spread_All] OR target.[M_Money_Positions_Long_All] <> source.[M_Money_Positions_Long_All] OR target.[M_Money_Positions_Short_All] <> source.[M_Money_Positions_Short_All] OR target.[M_Money_Positions_Spread_All] <> source.[M_Money_Positions_Spread_All] OR target.[Other_Rept_Positions_Long_All] <> source.[Other_Rept_Positions_Long_All] OR target.[Other_Rept_Positions_Short_All] <> source.[Other_Rept_Positions_Short_All] OR target.[Other_Rept_Positions_Spread_All] <> source.[Other_Rept_Positions_Spread_All] OR target.[Tot_Rept_Positions_Long_All] <> source.[Tot_Rept_Positions_Long_All] OR target.[Tot_Rept_Positions_Short_All] <> source.[Tot_Rept_Positions_Short_All] OR target.[NonRept_Positions_Long_All] <> source.[NonRept_Positions_Long_All] OR target.[NonRept_Positions_Short_All] <> source.[NonRept_Positions_Short_All] OR target.[Open_Interest_Old] <> source.[Open_Interest_Old] OR target.[Prod_Merc_Positions_Long_Old] <> source.[Prod_Merc_Positions_Long_Old] OR target.[Prod_Merc_Positions_Short_Old] <> source.[Prod_Merc_Positions_Short_Old] OR target.[Swap_Positions_Long_Old] <> source.[Swap_Positions_Long_Old] OR target.[Swap_Positions_Short_Old] <> source.[Swap_Positions_Short_Old] OR target.[Swap_Positions_Spread_Old] <> source.[Swap_Positions_Spread_Old] OR target.[M_Money_Positions_Long_Old] <> source.[M_Money_Positions_Long_Old] OR target.[M_Money_Positions_Short_Old] <> source.[M_Money_Positions_Short_Old] OR target.[M_Money_Positions_Spread_Old] <> source.[M_Money_Positions_Spread_Old] OR target.[Other_Rept_Positions_Long_Old] <> source.[Other_Rept_Positions_Long_Old] OR target.[Other_Rept_Positions_Short_Old] <> source.[Other_Rept_Positions_Short_Old] OR target.[Other_Rept_Positions_Spread_Old] <> source.[Other_Rept_Positions_Spread_Old] OR target.[Tot_Rept_Positions_Long_Old] <> source.[Tot_Rept_Positions_Long_Old] OR target.[Tot_Rept_Positions_Short_Old] <> source.[Tot_Rept_Positions_Short_Old] OR target.[NonRept_Positions_Long_Old] <> source.[NonRept_Positions_Long_Old] OR target.[NonRept_Positions_Short_Old] <> source.[NonRept_Positions_Short_Old] OR target.[Open_Interest_Other] <> source.[Open_Interest_Other] OR target.[Prod_Merc_Positions_Long_Other] <> source.[Prod_Merc_Positions_Long_Other] OR target.[Prod_Merc_Positions_Short_Other] <> source.[Prod_Merc_Positions_Short_Other] OR target.[Swap_Positions_Long_Other] <> source.[Swap_Positions_Long_Other] OR target.[Swap_Positions_Short_Other] <> source.[Swap_Positions_Short_Other] OR target.[Swap_Positions_Spread_Other] <> source.[Swap_Positions_Spread_Other] OR target.[M_Money_Positions_Long_Other] <> source.[M_Money_Positions_Long_Other] OR target.[M_Money_Positions_Short_Other] <> source.[M_Money_Positions_Short_Other] OR target.[M_Money_Positions_Spread_Other] <> source.[M_Money_Positions_Spread_Other] OR target.[Other_Rept_Positions_Long_Other] <> source.[Other_Rept_Positions_Long_Other] OR target.[Other_Rept_Positions_Short_Other] <> source.[Other_Rept_Positions_Short_Other] OR target.[Other_Rept_Positions_Spread_Other] <> source.[Other_Rept_Positions_Spread_Other] OR target.[Tot_Rept_Positions_Long_Other] <> source.[Tot_Rept_Positions_Long_Other] OR target.[Tot_Rept_Positions_Short_Other] <> source.[Tot_Rept_Positions_Short_Other] OR target.[NonRept_Positions_Long_Other] <> source.[NonRept_P ...
# THEN UPDATE SET target.[Market_and_Exchange_Names] = source.[Market_and_Exchange_Names], target.[As_of_Date_In_Form_YYMMDD] = source.[As_of_Date_In_Form_YYMMDD], target.[Report_Date_as_YYYY-MM-DD] = source.[Report_Date_as_YYYY-MM-DD], target.[Open_Interest_All] = source.[Open_Interest_All], target.[Prod_Merc_Positions_Long_All] = source.[Prod_Merc_Positions_Long_All], target.[Prod_Merc_Positions_Short_All] = source.[Prod_Merc_Positions_Short_All], target.[Swap_Positions_Long_All] = source.[Swap_Positions_Long_All], target.[Swap_Positions_Short_All] = source.[Swap_Positions_Short_All], target.[Swap_Positions_Spread_All] = source.[Swap_Positions_Spread_All], target.[M_Money_Positions_Long_All] = source.[M_Money_Positions_Long_All], target.[M_Money_Positions_Short_All] = source.[M_Money_Positions_Short_All], target.[M_Money_Positions_Spread_All] = source.[M_Money_Positions_Spread_All], target.[Other_Rept_Positions_Long_All] = source.[Other_Rept_Positions_Long_All], target.[Other_Rept_Positions_Short_All] = source.[Other_Rept_Positions_Short_All], target.[Other_Rept_Positions_Spread_All] = source.[Other_Rept_Positions_Spread_All], target.[Tot_Rept_Positions_Long_All] = source.[Tot_Rept_Positions_Long_All], target.[Tot_Rept_Positions_Short_All] = source.[Tot_Rept_Positions_Short_All], target.[NonRept_Positions_Long_All] = source.[NonRept_Positions_Long_All], target.[NonRept_Positions_Short_All] = source.[NonRept_Positions_Short_All], target.[Open_Interest_Old] = source.[Open_Interest_Old], target.[Prod_Merc_Positions_Long_Old] = source.[Prod_Merc_Positions_Long_Old], target.[Prod_Merc_Positions_Short_Old] = source.[Prod_Merc_Positions_Short_Old], target.[Swap_Positions_Long_Old] = source.[Swap_Positions_Long_Old], target.[Swap_Positions_Short_Old] = source.[Swap_Positions_Short_Old], target.[Swap_Positions_Spread_Old] = source.[Swap_Positions_Spread_Old], target.[M_Money_Positions_Long_Old] = source.[M_Money_Positions_Long_Old], target.[M_Money_Positions_Short_Old] = source.[M_Money_Positions_Short_Old], target.[M_Money_Positions_Spread_Old] = source.[M_Money_Positions_Spread_Old], target.[Other_Rept_Positions_Long_Old] = source.[Other_Rept_Positions_Long_Old], target.[Other_Rept_Positions_Short_Old] = source.[Other_Rept_Positions_Short_Old], target.[Other_Rept_Positions_Spread_Old] = source.[Other_Rept_Positions_Spread_Old], target.[Tot_Rept_Positions_Long_Old] = source.[Tot_Rept_Positions_Long_Old], target.[Tot_Rept_Positions_Short_Old] = source.[Tot_Rept_Positions_Short_Old], target.[NonRept_Positions_Long_Old] = source.[NonRept_Positions_Long_Old], target.[NonRept_Positions_Short_Old] = source.[NonRept_Positions_Short_Old], target.[Open_Interest_Other] = source.[Open_Interest_Other], target.[Prod_Merc_Positions_Long_Other] = source.[Prod_Merc_Positions_Long_Other], target.[Prod_Merc_Positions_Short_Other] = source.[Prod_Merc_Positions_Short_Other], target.[Swap_Positions_Long_Other] = source.[Swap_Positions_Long_Other], target.[Swap_Positions_Short_Other] = source.[Swap_Positions_Short_Other], target.[Swap_Positions_Spread_Other] = source.[Swap_Positions_Spread_Other], target.[M_Money_Positions_Long_Other] = source.[M_Money_Positions_Long_Other], target.[M_Money_Positions_Short_Other] = source.[M_Money_Positions_Short_Other], target.[M_Money_Positions_Spread_Other] = source.[M_Money_Positions_Spread_Other], target.[Other_Rept_Positions_Long_Other] = source.[Other_Rept_Positions_Long_Other], target.[Other_Rept_Positions_Short_Other] = source.[Other_Rept_Positions_Short_Other], target.[Other_Rept_Positions_Spread_Other] = source.[Other_Rept_Positions_Spread_Other], target.[Tot_Rept_Positions_Long_Other] = source.[Tot_Rept_Positions_Long_Other], target.[Tot_Rept_Positions_Short_Other] = source.[Tot_Rept_Positions_Short_Other], target.[NonRept_Positions_Long_Other] = source.[NonRept_Positions_Long_Other], target.[NonRept_Positions_Short_Other] = source.[NonRept_Positions_Short_Other], target.[Change_in_Open_Interest_All] = source.[ ...
# WHEN NOT MATCHED
# THEN INSERT ([Market_and_Exchange_Names], [As_of_Date_In_Form_YYMMDD], [Report_Date_as_YYYY-MM-DD], [CFTC_Contract_Market_Code], [CFTC_Market_Code], [CFTC_Region_Code], [CFTC_Commodity_Code], [Open_Interest_All], [Prod_Merc_Positions_Long_All], [Prod_Merc_Positions_Short_All], [Swap_Positions_Long_All], [Swap_Positions_Short_All], [Swap_Positions_Spread_All], [M_Money_Positions_Long_All], [M_Money_Positions_Short_All], [M_Money_Positions_Spread_All], [Other_Rept_Positions_Long_All], [Other_Rept_Positions_Short_All], [Other_Rept_Positions_Spread_All], [Tot_Rept_Positions_Long_All], [Tot_Rept_Positions_Short_All], [NonRept_Positions_Long_All], [NonRept_Positions_Short_All], [Open_Interest_Old], [Prod_Merc_Positions_Long_Old], [Prod_Merc_Positions_Short_Old], [Swap_Positions_Long_Old], [Swap_Positions_Short_Old], [Swap_Positions_Spread_Old], [M_Money_Positions_Long_Old], [M_Money_Positions_Short_Old], [M_Money_Positions_Spread_Old], [Other_Rept_Positions_Long_Old], [Other_Rept_Positions_Short_Old], [Other_Rept_Positions_Spread_Old], [Tot_Rept_Positions_Long_Old], [Tot_Rept_Positions_Short_Old], [NonRept_Positions_Long_Old], [NonRept_Positions_Short_Old], [Open_Interest_Other], [Prod_Merc_Positions_Long_Other], [Prod_Merc_Positions_Short_Other], [Swap_Positions_Long_Other], [Swap_Positions_Short_Other], [Swap_Positions_Spread_Other], [M_Money_Positions_Long_Other], [M_Money_Positions_Short_Other], [M_Money_Positions_Spread_Other], [Other_Rept_Positions_Long_Other], [Other_Rept_Positions_Short_Other], [Other_Rept_Positions_Spread_Other], [Tot_Rept_Positions_Long_Other], [Tot_Rept_Positions_Short_Other], [NonRept_Positions_Long_Other], [NonRept_Positions_Short_Other], [Change_in_Open_Interest_All], [Change_in_Prod_Merc_Long_All], [Change_in_Prod_Merc_Short_All], [Change_in_Swap_Long_All], [Change_in_Swap_Short_All], [Change_in_Swap_Spread_All], [Change_in_M_Money_Long_All], [Change_in_M_Money_Short_All], [Change_in_M_Money_Spread_All], [Change_in_Other_Rept_Long_All], [Change_in_Other_Rept_Short_All], [Change_in_Other_Rept_Spread_All], [Change_in_Tot_Rept_Long_All], [Change_in_Tot_Rept_Short_All], [Change_in_NonRept_Long_All], [Change_in_NonRept_Short_All], [Pct_of_Open_Interest_All], [Pct_of_OI_Prod_Merc_Long_All], [Pct_of_OI_Prod_Merc_Short_All], [Pct_of_OI_Swap_Long_All], [Pct_of_OI_Swap_Short_All], [Pct_of_OI_Swap_Spread_All], [Pct_of_OI_M_Money_Long_All], [Pct_of_OI_M_Money_Short_All], [Pct_of_OI_M_Money_Spread_All], [Pct_of_OI_Other_Rept_Long_All], [Pct_of_OI_Other_Rept_Short_All], [Pct_of_OI_Other_Rept_Spread_All], [Pct_of_OI_Tot_Rept_Long_All], [Pct_of_OI_Tot_Rept_Short_All], [Pct_of_OI_NonRept_Long_All], [Pct_of_OI_NonRept_Short_All], [Pct_of_Open_Interest_Old], [Pct_of_OI_Prod_Merc_Long_Old], [Pct_of_OI_Prod_Merc_Short_Old], [Pct_of_OI_Swap_Long_Old], [Pct_of_OI_Swap_Short_Old], [Pct_of_OI_Swap_Spread_Old], [Pct_of_OI_M_Money_Long_Old], [Pct_of_OI_M_Money_Short_Old], [Pct_of_OI_M_Money_Spread_Old], [Pct_of_OI_Other_Rept_Long_Old], [Pct_of_OI_Other_Rept_Short_Old], [Pct_of_OI_Other_Rept_Spread_Old], [Pct_of_OI_Tot_Rept_Long_Old], [Pct_of_OI_Tot_Rept_Short_Old], [Pct_of_OI_NonRept_Long_Old], [Pct_of_OI_NonRept_Short_Old], [Pct_of_Open_Interest_Other], [Pct_of_OI_Prod_Merc_Long_Other], [Pct_of_OI_Prod_Merc_Short_Other], [Pct_of_OI_Swap_Long_Other], [Pct_of_OI_Swap_Short_Other], [Pct_of_OI_Swap_Spread_Other], [Pct_of_OI_M_Money_Long_Other], [Pct_of_OI_M_Money_Short_Other], [Pct_of_OI_M_Money_Spread_Other], [Pct_of_OI_Other_Rept_Long_Other], [Pct_of_OI_Other_Rept_Short_Other], [Pct_of_OI_Other_Rept_Spread_Other], [Pct_of_OI_Tot_Rept_Long_Other], [Pct_of_OI_Tot_Rept_Short_Other], [Pct_of_OI_NonRept_Long_Other], [Pct_of_OI_NonRept_Short_Other], [Traders_Tot_All], [Traders_Prod_Merc_Long_All], [Traders_Prod_Merc_Short_All], [Traders_Swap_Long_All], [Traders_Swap_Short_All], [Traders_Swap_Spread_All], [Traders_M_Money_Long_All], [Traders_M_Money_Short_All], [Traders_M_Money_Spread_All], [Traders_Other_Rept_Long_All], [Traders_Other ...
# VALUES (source.[Market_and_Exchange_Names], source.[As_of_Date_In_Form_YYMMDD], source.[Report_Date_as_YYYY-MM-DD], source.[CFTC_Contract_Market_Code], source.[CFTC_Market_Code], source.[CFTC_Region_Code], source.[CFTC_Commodity_Code], source.[Open_Interest_All], source.[Prod_Merc_Positions_Long_All], source.[Prod_Merc_Positions_Short_All], source.[Swap_Positions_Long_All], source.[Swap_Positions_Short_All], source.[Swap_Positions_Spread_All], source.[M_Money_Positions_Long_All], source.[M_Money_Positions_Short_All], source.[M_Money_Positions_Spread_All], source.[Other_Rept_Positions_Long_All], source.[Other_Rept_Positions_Short_All], source.[Other_Rept_Positions_Spread_All], source.[Tot_Rept_Positions_Long_All], source.[Tot_Rept_Positions_Short_All], source.[NonRept_Positions_Long_All], source.[NonRept_Positions_Short_All], source.[Open_Interest_Old], source.[Prod_Merc_Positions_Long_Old], source.[Prod_Merc_Positions_Short_Old], source.[Swap_Positions_Long_Old], source.[Swap_Positions_Short_Old], source.[Swap_Positions_Spread_Old], source.[M_Money_Positions_Long_Old], source.[M_Money_Positions_Short_Old], source.[M_Money_Positions_Spread_Old], source.[Other_Rept_Positions_Long_Old], source.[Other_Rept_Positions_Short_Old], source.[Other_Rept_Positions_Spread_Old], source.[Tot_Rept_Positions_Long_Old], source.[Tot_Rept_Positions_Short_Old], source.[NonRept_Positions_Long_Old], source.[NonRept_Positions_Short_Old], source.[Open_Interest_Other], source.[Prod_Merc_Positions_Long_Other], source.[Prod_Merc_Positions_Short_Other], source.[Swap_Positions_Long_Other], source.[Swap_Positions_Short_Other], source.[Swap_Positions_Spread_Other], source.[M_Money_Positions_Long_Other], source.[M_Money_Positions_Short_Other], source.[M_Money_Positions_Spread_Other], source.[Other_Rept_Positions_Long_Other], source.[Other_Rept_Positions_Short_Other], source.[Other_Rept_Positions_Spread_Other], source.[Tot_Rept_Positions_Long_Other], source.[Tot_Rept_Positions_Short_Other], source.[NonRept_Positions_Long_Other], source.[NonRept_Positions_Short_Other], source.[Change_in_Open_Interest_All], source.[Change_in_Prod_Merc_Long_All], source.[Change_in_Prod_Merc_Short_All], source.[Change_in_Swap_Long_All], source.[Change_in_Swap_Short_All], source.[Change_in_Swap_Spread_All], source.[Change_in_M_Money_Long_All], source.[Change_in_M_Money_Short_All], source.[Change_in_M_Money_Spread_All], source.[Change_in_Other_Rept_Long_All], source.[Change_in_Other_Rept_Short_All], source.[Change_in_Other_Rept_Spread_All], source.[Change_in_Tot_Rept_Long_All], source.[Change_in_Tot_Rept_Short_All], source.[Change_in_NonRept_Long_All], source.[Change_in_NonRept_Short_All], source.[Pct_of_Open_Interest_All], source.[Pct_of_OI_Prod_Merc_Long_All], source.[Pct_of_OI_Prod_Merc_Short_All], source.[Pct_of_OI_Swap_Long_All], source.[Pct_of_OI_Swap_Short_All], source.[Pct_of_OI_Swap_Spread_All], source.[Pct_of_OI_M_Money_Long_All], source.[Pct_of_OI_M_Money_Short_All], source.[Pct_of_OI_M_Money_Spread_All], source.[Pct_of_OI_Other_Rept_Long_All], source.[Pct_of_OI_Other_Rept_Short_All], source.[Pct_of_OI_Other_Rept_Spread_All], source.[Pct_of_OI_Tot_Rept_Long_All], source.[Pct_of_OI_Tot_Rept_Short_All], source.[Pct_of_OI_NonRept_Long_All], source.[Pct_of_OI_NonRept_Short_All], source.[Pct_of_Open_Interest_Old], source.[Pct_of_OI_Prod_Merc_Long_Old], source.[Pct_of_OI_Prod_Merc_Short_Old], source.[Pct_of_OI_Swap_Long_Old], source.[Pct_of_OI_Swap_Short_Old], source.[Pct_of_OI_Swap_Spread_Old], source.[Pct_of_OI_M_Money_Long_Old], source.[Pct_of_OI_M_Money_Short_Old], source.[Pct_of_OI_M_Money_Spread_Old], source.[Pct_of_OI_Other_Rept_Long_Old], source.[Pct_of_OI_Other_Rept_Short_Old], source.[Pct_of_OI_Other_Rept_Spread_Old], source.[Pct_of_OI_Tot_Rept_Long_Old], source.[Pct_of_OI_Tot_Rept_Short_Old], source.[Pct_of_OI_NonRept_Long_Old], source.[Pct_of_OI_NonRept_Short_Old], source.[Pct_of_Open_Interest_Other], source.[Pct_of_OI_Prod_Merc_Long_Other], source.[Pct_of_OI_Prod_M ...
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=gov_cftc_fut_disagg_txt_2021 HTTP/1.1" 200 700
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7058 HTTP/1.1" 201 10
# INFO:scraper.core.utils:update_sources_metadata: 1134.4382762908936 ms

# %%
print('CFTC_SubGroup_Code', job.data['CFTC_SubGroup_Code'].str.len().max())
print('CFTC_Market_Code_Quotes', job.data['CFTC_Market_Code_Quotes'].str.len().max())
print('CFTC_Contract_Market_Code_Quotes', job.data['CFTC_Contract_Market_Code_Quotes'].str.len().max())
print('Market_and_Exchange_Names', job.data['Market_and_Exchange_Names'].str.len().max())
print('As_of_Date_In_Form_YYMMDD', job.data['As_of_Date_In_Form_YYMMDD'].str.len().max())
print('Report_Date_as_YYYY-MM-DD', job.data['Report_Date_as_YYYY-MM-DD'].str.len().max())
print('CFTC_Contract_Market_Code', job.data['CFTC_Contract_Market_Code'].str.len().max())
print('CFTC_Market_Code', job.data['CFTC_Market_Code'].str.len().max())
print('CFTC_Commodity_Code', job.data['CFTC_Commodity_Code'].str.len().max())
print('Contract_Units', job.data['Contract_Units'].str.len().max())
print('CFTC_Contract_Market_Code_Quotes', job.data['CFTC_Contract_Market_Code_Quotes'].str.len().max())
print('CFTC_Commodity_Code_Quotes', job.data['CFTC_Commodity_Code_Quotes'].str.len().max())
print('FutOnly_or_Combined', job.data['FutOnly_or_Combined'].str.len().max())
print('source', job.data['source'].str.len().max())
print('provider', job.data['provider'].str.len().max())
# Out:
# CFTC_SubGroup_Code 3
# CFTC_Market_Code_Quotes 4
# CFTC_Contract_Market_Code_Quotes 6
# Market_and_Exchange_Names 78
# As_of_Date_In_Form_YYMMDD 6
# Report_Date_as_YYYY-MM-DD 10
# CFTC_Contract_Market_Code 6
# CFTC_Market_Code 4
# CFTC_Commodity_Code 4
# Contract_Units 48
# CFTC_Contract_Market_Code_Quotes 6
# CFTC_Commodity_Code_Quotes 4
# FutOnly_or_Combined 7
# source 28
# provider 8

# %%
job.data[job.data['Contract_Units'].str.len() == 114]['Contract_Units'].tolist()

# %%
# Lets go step by step on fixing these errors
from zipfile import ZipFile
import pandas as pd
from typing import List

csv_columns = {'Market_and_Exchange_Names': str,
                   'As_of_Date_In_Form_YYMMDD': str,
                   'Report_Date_as_YYYY-MM-DD': str,
                   'CFTC_Contract_Market_Code': str,
                   'CFTC_Market_Code': str,
                   'CFTC_Region_Code': int,
                   'CFTC_Commodity_Code': str,
                   'Open_Interest_All': float,
                   'Prod_Merc_Positions_Long_All': int,
                   'Prod_Merc_Positions_Short_All': int,
                   'Swap_Positions_Long_All': int,
                   'Swap__Positions_Short_All': int,
                   'Swap__Positions_Spread_All': int,
                   'M_Money_Positions_Long_All': int,
                   'M_Money_Positions_Short_All': int,
                   'M_Money_Positions_Spread_All': int,
                   'Other_Rept_Positions_Long_All': int,
                   'Other_Rept_Positions_Short_All': int,
                   'Other_Rept_Positions_Spread_All': int,
                   'Tot_Rept_Positions_Long_All': float,
                   'Tot_Rept_Positions_Short_All': float,
                   'NonRept_Positions_Long_All': int,
                   'NonRept_Positions_Short_All': int,
                   'Open_Interest_Old': float,
                   'Prod_Merc_Positions_Long_Old': int,
                   'Prod_Merc_Positions_Short_Old': int,
                   'Swap_Positions_Long_Old': int,
                   'Swap__Positions_Short_Old': int,
                   'Swap__Positions_Spread_Old': int,
                   'M_Money_Positions_Long_Old': int,
                   'M_Money_Positions_Short_Old': int,
                   'M_Money_Positions_Spread_Old': int,
                   'Other_Rept_Positions_Long_Old': int,
                   'Other_Rept_Positions_Short_Old': int,
                   'Other_Rept_Positions_Spread_Old': int,
                   'Tot_Rept_Positions_Long_Old': float,
                   'Tot_Rept_Positions_Short_Old': float,
                   'NonRept_Positions_Long_Old': float,
                   'NonRept_Positions_Short_Old': float,
                   'Open_Interest_Other': float,
                   'Prod_Merc_Positions_Long_Other': float,
                   'Prod_Merc_Positions_Short_Other': float,
                   'Swap_Positions_Long_Other': float,
                   'Swap__Positions_Short_Other': float,
                   'Swap__Positions_Spread_Other': float,
                   'M_Money_Positions_Long_Other': float,
                   'M_Money_Positions_Short_Other': float,
                   'M_Money_Positions_Spread_Other': float,
                   'Other_Rept_Positions_Long_Other': float,
                   'Other_Rept_Positions_Short_Other': float,
                   'Other_Rept_Positions_Spread_Other': float,
                   'Tot_Rept_Positions_Long_Other': float,
                   'Tot_Rept_Positions_Short_Other': float,
                   'NonRept_Positions_Long_Other': float,
                   'NonRept_Positions_Short_Other': float,
                   'Change_in_Open_Interest_All': float,
                   'Change_in_Prod_Merc_Long_All': float,
                   'Change_in_Prod_Merc_Short_All': float,
                   'Change_in_Swap_Long_All': float,
                   'Change_in_Swap_Short_All': float,
                   'Change_in_Swap_Spread_All': float,
                   'Change_in_M_Money_Long_All': float,
                   'Change_in_M_Money_Short_All': float,
                   'Change_in_M_Money_Spread_All': float,
                   'Change_in_Other_Rept_Long_All': float,
                   'Change_in_Other_Rept_Short_All': float,
                   'Change_in_Other_Rept_Spread_All': float,
                   'Change_in_Tot_Rept_Long_All': float,
                   'Change_in_Tot_Rept_Short_All': float,
                   'Change_in_NonRept_Long_All': float,
                   'Change_in_NonRept_Short_All': float,
                   'Pct_of_Open_Interest_All': float,
                   'Pct_of_OI_Prod_Merc_Long_All': float,
                   'Pct_of_OI_Prod_Merc_Short_All': float,
                   'Pct_of_OI_Swap_Long_All': float,
                   'Pct_of_OI_Swap_Short_All': float,
                   'Pct_of_OI_Swap_Spread_All': float,
                   'Pct_of_OI_M_Money_Long_All': float,
                   'Pct_of_OI_M_Money_Short_All': float,
                   'Pct_of_OI_M_Money_Spread_All': float,
                   'Pct_of_OI_Other_Rept_Long_All': float,
                   'Pct_of_OI_Other_Rept_Short_All': float,
                   'Pct_of_OI_Other_Rept_Spread_All': float,
                   'Pct_of_OI_Tot_Rept_Long_All': float,
                   'Pct_of_OI_Tot_Rept_Short_All': float,
                   'Pct_of_OI_NonRept_Long_All': float,
                   'Pct_of_OI_NonRept_Short_All': float,
                   'Pct_of_Open_Interest_Old': float,
                   'Pct_of_OI_Prod_Merc_Long_Old': float,
                   'Pct_of_OI_Prod_Merc_Short_Old': float,
                   'Pct_of_OI_Swap_Long_Old': float,
                   'Pct_of_OI_Swap_Short_Old': float,
                   'Pct_of_OI_Swap_Spread_Old': float,
                   'Pct_of_OI_M_Money_Long_Old': float,
                   'Pct_of_OI_M_Money_Short_Old': float,
                   'Pct_of_OI_M_Money_Spread_Old': float,
                   'Pct_of_OI_Other_Rept_Long_Old': float,
                   'Pct_of_OI_Other_Rept_Short_Old': float,
                   'Pct_of_OI_Other_Rept_Spread_Old': float,
                   'Pct_of_OI_Tot_Rept_Long_Old': float,
                   'Pct_of_OI_Tot_Rept_Short_Old': float,
                   'Pct_of_OI_NonRept_Long_Old': float,
                   'Pct_of_OI_NonRept_Short_Old': float,
                   'Pct_of_Open_Interest_Other': float,
                   'Pct_of_OI_Prod_Merc_Long_Other': float,
                   'Pct_of_OI_Prod_Merc_Short_Other': float,
                   'Pct_of_OI_Swap_Long_Other': float,
                   'Pct_of_OI_Swap_Short_Other': float,
                   'Pct_of_OI_Swap_Spread_Other': float,
                   'Pct_of_OI_M_Money_Long_Other': float,
                   'Pct_of_OI_M_Money_Short_Other': float,
                   'Pct_of_OI_M_Money_Spread_Other': float,
                   'Pct_of_OI_Other_Rept_Long_Other': float,
                   'Pct_of_OI_Other_Rept_Short_Other': float,
                   'Pct_of_OI_Other_Rept_Spread_Other': float,
                   'Pct_of_OI_Tot_Rept_Long_Other': float,
                   'Pct_of_OI_Tot_Rept_Short_Other': float,
                   'Pct_of_OI_NonRept_Long_Other': float,
                   'Pct_of_OI_NonRept_Short_Other': float,
                   'Traders_Tot_All': float,
                   'Traders_Prod_Merc_Long_All': float,
                   'Traders_Prod_Merc_Short_All': float,
                   'Traders_Swap_Long_All': float,
                   'Traders_Swap_Short_All': float,
                   'Traders_Swap_Spread_All': float,
                   'Traders_M_Money_Long_All': float,
                   'Traders_M_Money_Short_All': float,
                   'Traders_M_Money_Spread_All': float,
                   'Traders_Other_Rept_Long_All': float,
                   'Traders_Other_Rept_Short_All': float,
                   'Traders_Other_Rept_Spread_All': float,
                   'Traders_Tot_Rept_Long_All': float,
                   'Traders_Tot_Rept_Short_All': float,
                   'Traders_Tot_Old': float,
                   'Traders_Prod_Merc_Long_Old': float,
                   'Traders_Prod_Merc_Short_Old': float,
                   'Traders_Swap_Long_Old': float,
                   'Traders_Swap_Short_Old': float,
                   'Traders_Swap_Spread_Old': float,
                   'Traders_M_Money_Long_Old': float,
                   'Traders_M_Money_Short_Old': float,
                   'Traders_M_Money_Spread_Old': float,
                   'Traders_Other_Rept_Long_Old': float,
                   'Traders_Other_Rept_Short_Old': float,
                   'Traders_Other_Rept_Spread_Old': float,
                   'Traders_Tot_Rept_Long_Old': float,
                   'Traders_Tot_Rept_Short_Old': float,
                   'Traders_Tot_Other': float,
                   'Traders_Prod_Merc_Long_Other': float,
                   'Traders_Prod_Merc_Short_Other': float,
                   'Traders_Swap_Long_Other': float,
                   'Traders_Swap_Short_Other': float,
                   'Traders_Swap_Spread_Other': float,
                   'Traders_M_Money_Long_Other': float,
                   'Traders_M_Money_Short_Other': float,
                   'Traders_M_Money_Spread_Other': float,
                   'Traders_Other_Rept_Long_Other': float,
                   'Traders_Other_Rept_Short_Other': float,
                   'Traders_Other_Rept_Spread_Other': float,
                   'Traders_Tot_Rept_Long_Other': float,
                   'Traders_Tot_Rept_Short_Other': float,
                   'Conc_Gross_LE_4_TDR_Long_All': float,
                   'Conc_Gross_LE_4_TDR_Short_All': float,
                   'Conc_Gross_LE_8_TDR_Long_All': float,
                   'Conc_Gross_LE_8_TDR_Short_All': float,
                   'Conc_Net_LE_4_TDR_Long_All': float,
                   'Conc_Net_LE_4_TDR_Short_All': float,
                   'Conc_Net_LE_8_TDR_Long_All': float,
                   'Conc_Net_LE_8_TDR_Short_All': float,
                   'Conc_Gross_LE_4_TDR_Long_Old': float,
                   'Conc_Gross_LE_4_TDR_Short_Old': float,
                   'Conc_Gross_LE_8_TDR_Long_Old': float,
                   'Conc_Gross_LE_8_TDR_Short_Old': float,
                   'Conc_Net_LE_4_TDR_Long_Old': float,
                   'Conc_Net_LE_4_TDR_Short_Old': float,
                   'Conc_Net_LE_8_TDR_Long_Old': float,
                   'Conc_Net_LE_8_TDR_Short_Old': float,
                   'Conc_Gross_LE_4_TDR_Long_Other': float,
                   'Conc_Gross_LE_4_TDR_Short_Other': float,
                   'Conc_Gross_LE_8_TDR_Long_Other': float,
                   'Conc_Gross_LE_8_TDR_Short_Other': float,
                   'Conc_Net_LE_4_TDR_Long_Other': float,
                   'Conc_Net_LE_4_TDR_Short_Other': float,
                   'Conc_Net_LE_8_TDR_Long_Other': float,
                   'Conc_Net_LE_8_TDR_Short_Other': float,
                   'Contract_Units': str,
                   'CFTC_Contract_Market_Code_Quotes': float,
                   'CFTC_Market_Code_Quotes': float,
                   'CFTC_Commodity_Code_Quotes': float,
                   'CFTC_SubGroup_Code': float,
                   'FutOnly_or_Combined': str}
null_values = ['.', ' ']


path = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\gov_cftc_com_disagg_txt_2021.zip'

z = ZipFile(path)
dfs: List[pd.DataFrame] = []
for filename in z.namelist():
    logger.debug(f'Reading {filename} from {path}')
    with z.open(filename) as file:
        try:
            df = pd.read_csv(file,
            skip_blank_lines=True,
            #names=csv_columns.keys(),
            #dtype=csv_columns,
            na_values=null_values,
            header=0
            )
            logger.debug(f'{filename}: {len(df)} rows loaded.')
            dfs.append(df)
        except ValueError as e:
            logger.exception(f'Error while reading file {filename}')
            raise e

        df = pd.concat(dfs)
df

# %%
len(df.columns)

# %%
dict(df.dtypes)

# %%
df['CFTC_Contract_Market_Code_Quotes'].drop_duplicates()
