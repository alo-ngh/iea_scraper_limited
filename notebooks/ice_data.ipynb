# %% [markdown]
# # Ice data
#
# This notebook is aimed to test ICE data scraper.
#
# It loads futures and options data available at https://www.theice.com/marketdata/reports/122.
#
# This scraper can load either the current file or all the history when the flag full_load is set.

# %%
# %cd ..
# Out:
# C:\Users\ROSA_L\PycharmProjects\scraper

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logger = logging.getLogger()
logging.basicConfig(level=logging.DEBUG)
logger.setLevel(logging.DEBUG)

# %%
from scraper.core import factory

# %%
job = factory.get_scraper_job('com_theice', 'ice_hist_data')
# Out:
# DEBUG:scraper.core.factory:Loading module scraper.jobs.com_theice.ice_hist_data
# DEBUG:scraper.core.factory:Getting class IceHistDataJob

# %%
job.get_sources()

# %%
job.download_and_get_checksum(download=False)

# %%
job.rm_sources_up_to_date()
# Out:
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2011
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2011 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2011
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2011 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2012
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2012 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2012
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2012 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2013
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2013 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2013
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2013 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2014
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2014 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2014
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2014 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2015
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2015 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2015
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2015 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2016
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2016 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2016
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2016 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2017
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2017 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2017
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2017 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2018
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2018 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2018
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2018 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2019
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2019 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2019
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2019 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2020
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2020 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2020
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2020 in source!
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2021
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2021 HTTP/1.1" 404 3
# ERROR:scraper.core.job:Non blocking Exception on rm_sources_up_to_date() while processing com_theice_COTHist2021
# Traceback (most recent call last):
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\job.py", line 552, in rm_sources_up_to_date
#     db_source = get_db_source_dict(source.code)
#   File "C:\Users\ROSA_L\PycharmProjects\scraper\scraper\core\utils.py", line 152, in get_db_source_dict
#     raise ValueError(f"No code: {source_code} in source!")
# ValueError: No code: com_theice_COTHist2021 in source!
# INFO:scraper.core.utils:rm_sources_up_to_date: 411.04817390441895 ms

# %%
job.transform()
# Out:
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading 11 files in parallel...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2020.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2021
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2019.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2020
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2019
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv: 120 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2018.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2018
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading and cleaning 2018 file: C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2018.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2020.csv: 624 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2017.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2019.csv: 624 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2017
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2016.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2016
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year 2018: removing additional last column
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2018.csv: 636 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2015.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2015
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2017.csv: 624 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2014.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2014
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2016.csv: 624 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2013.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2013
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2015.csv: 624 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2012.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2012
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2014.csv: 320 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2011.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2011
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2013.csv: 208 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2012.csv: 212 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2011.csv: 208 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Concatenating results ...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Loading 4824 rows to self.data

# %%
display(job.data.query("As_of_Date_In_Form_YYMMDD == '180102'")[['As_of_Date_In_Form_YYMMDD', 'Swap_Positions_Short_Old', 'Week_of_Release']])

job.data.query("As_of_Date_In_Form_YYMMDD == '180102'")['Week_of_Release'].dt.day
# Out:
#    As_of_Date_In_Form_YYMMDD  Swap_Positions_Short_Old Week_of_Release
# 0                     180102                     36980      2018-01-02
# 1                     180102                     36690      2018-01-02
# 2                     180102                     36242      2018-01-02
# 3                     180102                     36390      2018-01-02
# 4                     180102                      7250      2018-01-02
# 5                     180102                      7103      2018-01-02
# 6                     180102                     18770      2018-01-02
# 7                     180102                     18558      2018-01-02
# 8                     180102                      8084      2018-01-02
# 9                     180102                      7068      2018-01-02
# 10                    180102                      1640      2018-01-02
# 11                    180102                      1640      2018-01-02
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# Name: Week_of_Release, dtype: int64

# %%
job.data[['Week_of_Release', 'CFTC_Commodity_Code', 'FutOnly_or_Combined']].drop_duplicates()
# Out:
#     Week_of_Release CFTC_Commodity_Code FutOnly_or_Combined
# 0        2021-01-05                   G             FutOnly
# 1        2021-01-05                   G            Combined
# 2        2021-01-05                   B             FutOnly
# 3        2021-01-05                   B            Combined
# 4        2021-01-05                   W             FutOnly
# ..              ...                 ...                 ...
# 203      2011-12-20                   B            Combined
# 204      2011-12-27                   G             FutOnly
# 205      2011-12-27                   G            Combined
# 206      2011-12-27                   B             FutOnly
# 207      2011-12-27                   B            Combined
#
# [4824 rows x 3 columns]

# %%
# let's try a full load
from scraper.core import factory
job = factory.get_scraper_job('com_theice', 'ice_hist_data')
job.run()
# Out:
# DEBUG:scraper.core.factory:Loading module scraper.jobs.com_theice.ice_hist_data
# DEBUG:scraper.core.factory:Getting class IceHistDataJob
# INFO:scraper.jobs.com_theice.ice_hist_data:Defining list of files to load.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Start year: 2021
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Creating source for 2021
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/source
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source HTTP/1.1" 200 763573
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size after: 0
# DEBUG:scraper.core.job:download: True, parallel download: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.theice.com:443
# DEBUG:urllib3.connectionpool:https://www.theice.com:443 "GET /publicdocs/futures/COTHist2021.csv HTTP/1.1" 200 None
# INFO:scraper.core.utils:download_and_get_checksum: 1517.0588493347168 ms
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2021
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2021 HTTP/1.1" 200 705
# INFO:scraper.core.utils:rm_sources_up_to_date: 43.8237190246582 ms
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Transforming provider ...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Adding provider to dynamic_dim: {'code': 'COM_THEICE', 'long_name': 'ICE - Intercontinental Exchange, Inc.', 'url': 'https://www.theice.com'}
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/provider
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/provider HTTP/1.1" 200 6922
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size after: 0
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading 1 files in parallel...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2021
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv: 132 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Concatenating results ...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Loading 132 rows to self.data
# DEBUG:scraper.core.job:Running insert_new_dynamic_dim(): 2 items
# DEBUG:scraper.core.job:Processing source: size 0
# DEBUG:scraper.core.job:Processing provider: size 0
# INFO:scraper.core.utils:insert_new_dynamic_dim: 2.02178955078125 ms
# INFO:scraper.jobs.com_theice.ice_hist_data:Writing to database.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Datebase: mssql+pyodbc://omr:Sekiyu8trd@vipenta.iea.org/external_db_dev?driver=ODBC+Driver+13+for+SQL+Server
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Loading 132 rows to temporary table #futures_options_temp
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Merging data from #futures_options_temp into futures_options_data
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Merge query: MERGE main.futures_options_data target
# USING main.#futures_options_temp as source
# ON (target.[provider] = source.[provider] AND target.[Week_of_Release] = source.[Week_of_Release] AND target.[CFTC_Contract_Market_Code] = source.[CFTC_Contract_Market_Code] AND target.[CFTC_Market_Code] = source.[CFTC_Market_Code] AND target.[CFTC_Region_Code] = source.[CFTC_Region_Code] AND target.[CFTC_Commodity_Code] = source.[CFTC_Commodity_Code] AND target.[FutOnly_or_Combined] = source.[FutOnly_or_Combined])
# WHEN MATCHED AND (target.[Market_and_Exchange_Names] <> source.[Market_and_Exchange_Names] OR target.[As_of_Date_In_Form_YYMMDD] <> source.[As_of_Date_In_Form_YYMMDD] OR target.[As_of_Date_Form_MM/DD/YYYY] <> source.[As_of_Date_Form_MM/DD/YYYY] OR target.[Open_Interest_All] <> source.[Open_Interest_All] OR target.[Prod_Merc_Positions_Long_All] <> source.[Prod_Merc_Positions_Long_All] OR target.[Prod_Merc_Positions_Short_All] <> source.[Prod_Merc_Positions_Short_All] OR target.[Swap_Positions_Long_All] <> source.[Swap_Positions_Long_All] OR target.[Swap_Positions_Short_All] <> source.[Swap_Positions_Short_All] OR target.[Swap_Positions_Spread_All] <> source.[Swap_Positions_Spread_All] OR target.[M_Money_Positions_Long_All] <> source.[M_Money_Positions_Long_All] OR target.[M_Money_Positions_Short_All] <> source.[M_Money_Positions_Short_All] OR target.[M_Money_Positions_Spread_All] <> source.[M_Money_Positions_Spread_All] OR target.[Other_Rept_Positions_Long_All] <> source.[Other_Rept_Positions_Long_All] OR target.[Other_Rept_Positions_Short_All] <> source.[Other_Rept_Positions_Short_All] OR target.[Other_Rept_Positions_Spread_All] <> source.[Other_Rept_Positions_Spread_All] OR target.[Tot_Rept_Positions_Long_All] <> source.[Tot_Rept_Positions_Long_All] OR target.[Tot_Rept_Positions_Short_All] <> source.[Tot_Rept_Positions_Short_All] OR target.[NonRept_Positions_Long_All] <> source.[NonRept_Positions_Long_All] OR target.[NonRept_Positions_Short_All] <> source.[NonRept_Positions_Short_All] OR target.[Open_Interest_Old] <> source.[Open_Interest_Old] OR target.[Prod_Merc_Positions_Long_Old] <> source.[Prod_Merc_Positions_Long_Old] OR target.[Prod_Merc_Positions_Short_Old] <> source.[Prod_Merc_Positions_Short_Old] OR target.[Swap_Positions_Long_Old] <> source.[Swap_Positions_Long_Old] OR target.[Swap_Positions_Short_Old] <> source.[Swap_Positions_Short_Old] OR target.[Swap_Positions_Spread_Old] <> source.[Swap_Positions_Spread_Old] OR target.[M_Money_Positions_Long_Old] <> source.[M_Money_Positions_Long_Old] OR target.[M_Money_Positions_Short_Old] <> source.[M_Money_Positions_Short_Old] OR target.[M_Money_Positions_Spread_Old] <> source.[M_Money_Positions_Spread_Old] OR target.[Other_Rept_Positions_Long_Old] <> source.[Other_Rept_Positions_Long_Old] OR target.[Other_Rept_Positions_Short_Old] <> source.[Other_Rept_Positions_Short_Old] OR target.[Other_Rept_Positions_Spread_Old] <> source.[Other_Rept_Positions_Spread_Old] OR target.[Tot_Rept_Positions_Long_Old] <> source.[Tot_Rept_Positions_Long_Old] OR target.[Tot_Rept_Positions_Short_Old] <> source.[Tot_Rept_Positions_Short_Old] OR target.[NonRept_Positions_Long_Old] <> source.[NonRept_Positions_Long_Old] OR target.[NonRept_Positions_Short_Old] <> source.[NonRept_Positions_Short_Old] OR target.[Open_Interest_Other] <> source.[Open_Interest_Other] OR target.[Prod_Merc_Positions_Long_Other] <> source.[Prod_Merc_Positions_Long_Other] OR target.[Prod_Merc_Positions_Short_Other] <> source.[Prod_Merc_Positions_Short_Other] OR target.[Swap_Positions_Long_Other] <> source.[Swap_Positions_Long_Other] OR target.[Swap_Positions_Short_Other] <> source.[Swap_Positions_Short_Other] OR target.[Swap_Positions_Spread_Other] <> source.[Swap_Positions_Spread_Other] OR target.[M_Money_Positions_Long_Other] <> source.[M_Money_Positions_Long_Other] OR target.[M_Money_Positions_Short_Other] <> source.[M_Money_Positions_Short_Other] OR target.[M_Money_Positions_Spread_Other] <> source.[M_Money_Positions_Spread_Other] OR target.[Other_Rept_Positions_Long_Other] <> source.[Other_Rept_Positions_Long_Other] OR target.[Other_Rept_Positions_Short_Other] <> source.[Other_Rept_Positions_Short_Other] OR target.[Other_Rept_Positions_Spread_Other] <> source.[Other_Rept_Positions_Spread_Other] OR target.[Tot_Rept_Positions_Long_Other] <> source.[Tot_Rept_Positions_Long_Other] OR target.[Tot_Rept_Positions_Short_Other] <> source.[Tot_Rept_Positions_Short_Other] OR target.[NonRept_Positions_Long_Other] <> source.[NonRept ...
# THEN UPDATE SET target.[Market_and_Exchange_Names] = source.[Market_and_Exchange_Names], target.[As_of_Date_In_Form_YYMMDD] = source.[As_of_Date_In_Form_YYMMDD], target.[As_of_Date_Form_MM/DD/YYYY] = source.[As_of_Date_Form_MM/DD/YYYY], target.[Open_Interest_All] = source.[Open_Interest_All], target.[Prod_Merc_Positions_Long_All] = source.[Prod_Merc_Positions_Long_All], target.[Prod_Merc_Positions_Short_All] = source.[Prod_Merc_Positions_Short_All], target.[Swap_Positions_Long_All] = source.[Swap_Positions_Long_All], target.[Swap_Positions_Short_All] = source.[Swap_Positions_Short_All], target.[Swap_Positions_Spread_All] = source.[Swap_Positions_Spread_All], target.[M_Money_Positions_Long_All] = source.[M_Money_Positions_Long_All], target.[M_Money_Positions_Short_All] = source.[M_Money_Positions_Short_All], target.[M_Money_Positions_Spread_All] = source.[M_Money_Positions_Spread_All], target.[Other_Rept_Positions_Long_All] = source.[Other_Rept_Positions_Long_All], target.[Other_Rept_Positions_Short_All] = source.[Other_Rept_Positions_Short_All], target.[Other_Rept_Positions_Spread_All] = source.[Other_Rept_Positions_Spread_All], target.[Tot_Rept_Positions_Long_All] = source.[Tot_Rept_Positions_Long_All], target.[Tot_Rept_Positions_Short_All] = source.[Tot_Rept_Positions_Short_All], target.[NonRept_Positions_Long_All] = source.[NonRept_Positions_Long_All], target.[NonRept_Positions_Short_All] = source.[NonRept_Positions_Short_All], target.[Open_Interest_Old] = source.[Open_Interest_Old], target.[Prod_Merc_Positions_Long_Old] = source.[Prod_Merc_Positions_Long_Old], target.[Prod_Merc_Positions_Short_Old] = source.[Prod_Merc_Positions_Short_Old], target.[Swap_Positions_Long_Old] = source.[Swap_Positions_Long_Old], target.[Swap_Positions_Short_Old] = source.[Swap_Positions_Short_Old], target.[Swap_Positions_Spread_Old] = source.[Swap_Positions_Spread_Old], target.[M_Money_Positions_Long_Old] = source.[M_Money_Positions_Long_Old], target.[M_Money_Positions_Short_Old] = source.[M_Money_Positions_Short_Old], target.[M_Money_Positions_Spread_Old] = source.[M_Money_Positions_Spread_Old], target.[Other_Rept_Positions_Long_Old] = source.[Other_Rept_Positions_Long_Old], target.[Other_Rept_Positions_Short_Old] = source.[Other_Rept_Positions_Short_Old], target.[Other_Rept_Positions_Spread_Old] = source.[Other_Rept_Positions_Spread_Old], target.[Tot_Rept_Positions_Long_Old] = source.[Tot_Rept_Positions_Long_Old], target.[Tot_Rept_Positions_Short_Old] = source.[Tot_Rept_Positions_Short_Old], target.[NonRept_Positions_Long_Old] = source.[NonRept_Positions_Long_Old], target.[NonRept_Positions_Short_Old] = source.[NonRept_Positions_Short_Old], target.[Open_Interest_Other] = source.[Open_Interest_Other], target.[Prod_Merc_Positions_Long_Other] = source.[Prod_Merc_Positions_Long_Other], target.[Prod_Merc_Positions_Short_Other] = source.[Prod_Merc_Positions_Short_Other], target.[Swap_Positions_Long_Other] = source.[Swap_Positions_Long_Other], target.[Swap_Positions_Short_Other] = source.[Swap_Positions_Short_Other], target.[Swap_Positions_Spread_Other] = source.[Swap_Positions_Spread_Other], target.[M_Money_Positions_Long_Other] = source.[M_Money_Positions_Long_Other], target.[M_Money_Positions_Short_Other] = source.[M_Money_Positions_Short_Other], target.[M_Money_Positions_Spread_Other] = source.[M_Money_Positions_Spread_Other], target.[Other_Rept_Positions_Long_Other] = source.[Other_Rept_Positions_Long_Other], target.[Other_Rept_Positions_Short_Other] = source.[Other_Rept_Positions_Short_Other], target.[Other_Rept_Positions_Spread_Other] = source.[Other_Rept_Positions_Spread_Other], target.[Tot_Rept_Positions_Long_Other] = source.[Tot_Rept_Positions_Long_Other], target.[Tot_Rept_Positions_Short_Other] = source.[Tot_Rept_Positions_Short_Other], target.[NonRept_Positions_Long_Other] = source.[NonRept_Positions_Long_Other], target.[NonRept_Positions_Short_Other] = source.[NonRept_Positions_Short_Other], target.[Change_in_Open_Interest_All] = source ...
# WHEN NOT MATCHED
# THEN INSERT ([Market_and_Exchange_Names], [As_of_Date_In_Form_YYMMDD], [As_of_Date_Form_MM/DD/YYYY], [CFTC_Contract_Market_Code], [CFTC_Market_Code], [CFTC_Region_Code], [CFTC_Commodity_Code], [Open_Interest_All], [Prod_Merc_Positions_Long_All], [Prod_Merc_Positions_Short_All], [Swap_Positions_Long_All], [Swap_Positions_Short_All], [Swap_Positions_Spread_All], [M_Money_Positions_Long_All], [M_Money_Positions_Short_All], [M_Money_Positions_Spread_All], [Other_Rept_Positions_Long_All], [Other_Rept_Positions_Short_All], [Other_Rept_Positions_Spread_All], [Tot_Rept_Positions_Long_All], [Tot_Rept_Positions_Short_All], [NonRept_Positions_Long_All], [NonRept_Positions_Short_All], [Open_Interest_Old], [Prod_Merc_Positions_Long_Old], [Prod_Merc_Positions_Short_Old], [Swap_Positions_Long_Old], [Swap_Positions_Short_Old], [Swap_Positions_Spread_Old], [M_Money_Positions_Long_Old], [M_Money_Positions_Short_Old], [M_Money_Positions_Spread_Old], [Other_Rept_Positions_Long_Old], [Other_Rept_Positions_Short_Old], [Other_Rept_Positions_Spread_Old], [Tot_Rept_Positions_Long_Old], [Tot_Rept_Positions_Short_Old], [NonRept_Positions_Long_Old], [NonRept_Positions_Short_Old], [Open_Interest_Other], [Prod_Merc_Positions_Long_Other], [Prod_Merc_Positions_Short_Other], [Swap_Positions_Long_Other], [Swap_Positions_Short_Other], [Swap_Positions_Spread_Other], [M_Money_Positions_Long_Other], [M_Money_Positions_Short_Other], [M_Money_Positions_Spread_Other], [Other_Rept_Positions_Long_Other], [Other_Rept_Positions_Short_Other], [Other_Rept_Positions_Spread_Other], [Tot_Rept_Positions_Long_Other], [Tot_Rept_Positions_Short_Other], [NonRept_Positions_Long_Other], [NonRept_Positions_Short_Other], [Change_in_Open_Interest_All], [Change_in_Prod_Merc_Long_All], [Change_in_Prod_Merc_Short_All], [Change_in_Swap_Long_All], [Change_in_Swap_Short_All], [Change_in_Swap_Spread_All], [Change_in_M_Money_Long_All], [Change_in_M_Money_Short_All], [Change_in_M_Money_Spread_All], [Change_in_Other_Rept_Long_All], [Change_in_Other_Rept_Short_All], [Change_in_Other_Rept_Spread_All], [Change_in_Tot_Rept_Long_All], [Change_in_Tot_Rept_Short_All], [Change_in_NonRept_Long_All], [Change_in_NonRept_Short_All], [Pct_of_Open_Interest_All], [Pct_of_OI_Prod_Merc_Long_All], [Pct_of_OI_Prod_Merc_Short_All], [Pct_of_OI_Swap_Long_All], [Pct_of_OI_Swap_Short_All], [Pct_of_OI_Swap_Spread_All], [Pct_of_OI_M_Money_Long_All], [Pct_of_OI_M_Money_Short_All], [Pct_of_OI_M_Money_Spread_All], [Pct_of_OI_Other_Rept_Long_All], [Pct_of_OI_Other_Rept_Short_All], [Pct_of_OI_Other_Rept_Spread_All], [Pct_of_OI_Tot_Rept_Long_All], [Pct_of_OI_Tot_Rept_Short_All], [Pct_of_OI_NonRept_Long_All], [Pct_of_OI_NonRept_Short_All], [Pct_of_Open_Interest_Old], [Pct_of_OI_Prod_Merc_Long_Old], [Pct_of_OI_Prod_Merc_Short_Old], [Pct_of_OI_Swap_Long_Old], [Pct_of_OI_Swap_Short_Old], [Pct_of_OI_Swap_Spread_Old], [Pct_of_OI_M_Money_Long_Old], [Pct_of_OI_M_Money_Short_Old], [Pct_of_OI_M_Money_Spread_Old], [Pct_of_OI_Other_Rept_Long_Old], [Pct_of_OI_Other_Rept_Short_Old], [Pct_of_OI_Other_Rept_Spread_Old], [Pct_of_OI_Tot_Rept_Long_Old], [Pct_of_OI_Tot_Rept_Short_Old], [Pct_of_OI_NonRept_Long_Old], [Pct_of_OI_NonRept_Short_Old], [Pct_of_Open_Interest_Other], [Pct_of_OI_Prod_Merc_Long_Other], [Pct_of_OI_Prod_Merc_Short_Other], [Pct_of_OI_Swap_Long_Other], [Pct_of_OI_Swap_Short_Other], [Pct_of_OI_Swap_Spread_Other], [Pct_of_OI_M_Money_Long_Other], [Pct_of_OI_M_Money_Short_Other], [Pct_of_OI_M_Money_Spread_Other], [Pct_of_OI_Other_Rept_Long_Other], [Pct_of_OI_Other_Rept_Short_Other], [Pct_of_OI_Other_Rept_Spread_Other], [Pct_of_OI_Tot_Rept_Long_Other], [Pct_of_OI_Tot_Rept_Short_Other], [Pct_of_OI_NonRept_Long_Other], [Pct_of_OI_NonRept_Short_Other], [Traders_Tot_All], [Traders_Prod_Merc_Long_All], [Traders_Prod_Merc_Short_All], [Traders_Swap_Long_All], [Traders_Swap_Short_All], [Traders_Swap_Spread_All], [Traders_M_Money_Long_All], [Traders_M_Money_Short_All], [Traders_M_Money_Spread_All], [Traders_Other_Rept_Long_All], [Traders_Othe ...
# VALUES (source.[Market_and_Exchange_Names], source.[As_of_Date_In_Form_YYMMDD], source.[As_of_Date_Form_MM/DD/YYYY], source.[CFTC_Contract_Market_Code], source.[CFTC_Market_Code], source.[CFTC_Region_Code], source.[CFTC_Commodity_Code], source.[Open_Interest_All], source.[Prod_Merc_Positions_Long_All], source.[Prod_Merc_Positions_Short_All], source.[Swap_Positions_Long_All], source.[Swap_Positions_Short_All], source.[Swap_Positions_Spread_All], source.[M_Money_Positions_Long_All], source.[M_Money_Positions_Short_All], source.[M_Money_Positions_Spread_All], source.[Other_Rept_Positions_Long_All], source.[Other_Rept_Positions_Short_All], source.[Other_Rept_Positions_Spread_All], source.[Tot_Rept_Positions_Long_All], source.[Tot_Rept_Positions_Short_All], source.[NonRept_Positions_Long_All], source.[NonRept_Positions_Short_All], source.[Open_Interest_Old], source.[Prod_Merc_Positions_Long_Old], source.[Prod_Merc_Positions_Short_Old], source.[Swap_Positions_Long_Old], source.[Swap_Positions_Short_Old], source.[Swap_Positions_Spread_Old], source.[M_Money_Positions_Long_Old], source.[M_Money_Positions_Short_Old], source.[M_Money_Positions_Spread_Old], source.[Other_Rept_Positions_Long_Old], source.[Other_Rept_Positions_Short_Old], source.[Other_Rept_Positions_Spread_Old], source.[Tot_Rept_Positions_Long_Old], source.[Tot_Rept_Positions_Short_Old], source.[NonRept_Positions_Long_Old], source.[NonRept_Positions_Short_Old], source.[Open_Interest_Other], source.[Prod_Merc_Positions_Long_Other], source.[Prod_Merc_Positions_Short_Other], source.[Swap_Positions_Long_Other], source.[Swap_Positions_Short_Other], source.[Swap_Positions_Spread_Other], source.[M_Money_Positions_Long_Other], source.[M_Money_Positions_Short_Other], source.[M_Money_Positions_Spread_Other], source.[Other_Rept_Positions_Long_Other], source.[Other_Rept_Positions_Short_Other], source.[Other_Rept_Positions_Spread_Other], source.[Tot_Rept_Positions_Long_Other], source.[Tot_Rept_Positions_Short_Other], source.[NonRept_Positions_Long_Other], source.[NonRept_Positions_Short_Other], source.[Change_in_Open_Interest_All], source.[Change_in_Prod_Merc_Long_All], source.[Change_in_Prod_Merc_Short_All], source.[Change_in_Swap_Long_All], source.[Change_in_Swap_Short_All], source.[Change_in_Swap_Spread_All], source.[Change_in_M_Money_Long_All], source.[Change_in_M_Money_Short_All], source.[Change_in_M_Money_Spread_All], source.[Change_in_Other_Rept_Long_All], source.[Change_in_Other_Rept_Short_All], source.[Change_in_Other_Rept_Spread_All], source.[Change_in_Tot_Rept_Long_All], source.[Change_in_Tot_Rept_Short_All], source.[Change_in_NonRept_Long_All], source.[Change_in_NonRept_Short_All], source.[Pct_of_Open_Interest_All], source.[Pct_of_OI_Prod_Merc_Long_All], source.[Pct_of_OI_Prod_Merc_Short_All], source.[Pct_of_OI_Swap_Long_All], source.[Pct_of_OI_Swap_Short_All], source.[Pct_of_OI_Swap_Spread_All], source.[Pct_of_OI_M_Money_Long_All], source.[Pct_of_OI_M_Money_Short_All], source.[Pct_of_OI_M_Money_Spread_All], source.[Pct_of_OI_Other_Rept_Long_All], source.[Pct_of_OI_Other_Rept_Short_All], source.[Pct_of_OI_Other_Rept_Spread_All], source.[Pct_of_OI_Tot_Rept_Long_All], source.[Pct_of_OI_Tot_Rept_Short_All], source.[Pct_of_OI_NonRept_Long_All], source.[Pct_of_OI_NonRept_Short_All], source.[Pct_of_Open_Interest_Old], source.[Pct_of_OI_Prod_Merc_Long_Old], source.[Pct_of_OI_Prod_Merc_Short_Old], source.[Pct_of_OI_Swap_Long_Old], source.[Pct_of_OI_Swap_Short_Old], source.[Pct_of_OI_Swap_Spread_Old], source.[Pct_of_OI_M_Money_Long_Old], source.[Pct_of_OI_M_Money_Short_Old], source.[Pct_of_OI_M_Money_Spread_Old], source.[Pct_of_OI_Other_Rept_Long_Old], source.[Pct_of_OI_Other_Rept_Short_Old], source.[Pct_of_OI_Other_Rept_Spread_Old], source.[Pct_of_OI_Tot_Rept_Long_Old], source.[Pct_of_OI_Tot_Rept_Short_Old], source.[Pct_of_OI_NonRept_Long_Old], source.[Pct_of_OI_NonRept_Short_Old], source.[Pct_of_Open_Interest_Other], source.[Pct_of_OI_Prod_Merc_Long_Other], source.[Pct_of_OI_Prod_ ...
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2021 HTTP/1.1" 200 705
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7028 HTTP/1.1" 201 10
# INFO:scraper.core.utils:update_sources_metadata: 84.71512794494629 ms

# %%
# let's try a full load
from scraper.core import factory
job = factory.get_scraper_job('com_theice', 'ice_hist_data')
job.run()
# Out:
# DEBUG:scraper.core.factory:Loading module scraper.jobs.com_theice.ice_hist_data
# DEBUG:scraper.core.factory:Getting class IceHistDataJob
# INFO:scraper.jobs.com_theice.ice_hist_data:Defining list of files to load.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Start year: 2021
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Creating source for 2021
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/source
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source HTTP/1.1" 200 763566
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['source'] size after: 0
# DEBUG:scraper.core.job:download: True, parallel download: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.theice.com:443
# DEBUG:urllib3.connectionpool:https://www.theice.com:443 "GET /publicdocs/futures/COTHist2021.csv HTTP/1.1" 200 None
# INFO:scraper.core.utils:download_and_get_checksum: 582.2272300720215 ms
# DEBUG:scraper.core.job:rm_sources_up_to_date: processing com_theice_COTHist2021
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2021 HTTP/1.1" 200 698
# INFO:scraper.core.utils:rm_sources_up_to_date: 45.000314712524414 ms
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Transforming provider ...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Adding provider to dynamic_dim: {'code': 'COM_THEICE', 'long_name': 'ICE - Intercontinental Exchange, Inc.', 'url': 'https://www.theice.com'}
# DEBUG:scraper.core.job:remove_existing_dynamic_dim: query - http://vipenta:8000/dimension/provider
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/provider HTTP/1.1" 200 6922
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size before: 1
# DEBUG:scraper.core.job:self.dynamic_dim['provider'] size after: 0
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading 1 files in parallel...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Reading C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Year in file: 2021
# DEBUG:scraper.jobs.com_theice.ice_hist_data:C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv: 132 rows loaded.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Concatenating results ...
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Loading 132 rows to self.data
# DEBUG:scraper.core.job:Running insert_new_dynamic_dim(): 2 items
# DEBUG:scraper.core.job:Processing source: size 0
# DEBUG:scraper.core.job:Processing provider: size 0
# INFO:scraper.core.utils:insert_new_dynamic_dim: 2.0008087158203125 ms
# INFO:scraper.jobs.com_theice.ice_hist_data:Writing to database.
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Datebase: mssql+pyodbc://omr:Sekiyu8trd@vipenta.iea.org/external_db_dev?driver=ODBC+Driver+13+for+SQL+Server
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Loading 132 rows to temporary table #futures_options_temp
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Merging data from #futures_options_temp into futures_options_data
# DEBUG:scraper.jobs.com_theice.ice_hist_data:Merge query: MERGE main.futures_options_data target
# USING main.#futures_options_temp as source
# ON (target.[provider] = source.[provider] AND target.[Week_of_Release] = source.[Week_of_Release] AND target.[CFTC_Contract_Market_Code] = source.[CFTC_Contract_Market_Code] AND target.[CFTC_Market_Code] = source.[CFTC_Market_Code] AND target.[CFTC_Region_Code] = source.[CFTC_Region_Code] AND target.[CFTC_Commodity_Code] = source.[CFTC_Commodity_Code] AND target.[FutOnly_or_Combined] = source.[FutOnly_or_Combined])
# WHEN MATCHED AND (target.[Market_and_Exchange_Names] <> source.[Market_and_Exchange_Names] OR target.[As_of_Date_In_Form_YYMMDD] <> source.[As_of_Date_In_Form_YYMMDD] OR target.[As_of_Date_Form_MM/DD/YYYY] <> source.[As_of_Date_Form_MM/DD/YYYY] OR target.[Open_Interest_All] <> source.[Open_Interest_All] OR target.[Prod_Merc_Positions_Long_All] <> source.[Prod_Merc_Positions_Long_All] OR target.[Prod_Merc_Positions_Short_All] <> source.[Prod_Merc_Positions_Short_All] OR target.[Swap_Positions_Long_All] <> source.[Swap_Positions_Long_All] OR target.[Swap_Positions_Short_All] <> source.[Swap_Positions_Short_All] OR target.[Swap_Positions_Spread_All] <> source.[Swap_Positions_Spread_All] OR target.[M_Money_Positions_Long_All] <> source.[M_Money_Positions_Long_All] OR target.[M_Money_Positions_Short_All] <> source.[M_Money_Positions_Short_All] OR target.[M_Money_Positions_Spread_All] <> source.[M_Money_Positions_Spread_All] OR target.[Other_Rept_Positions_Long_All] <> source.[Other_Rept_Positions_Long_All] OR target.[Other_Rept_Positions_Short_All] <> source.[Other_Rept_Positions_Short_All] OR target.[Other_Rept_Positions_Spread_All] <> source.[Other_Rept_Positions_Spread_All] OR target.[Tot_Rept_Positions_Long_All] <> source.[Tot_Rept_Positions_Long_All] OR target.[Tot_Rept_Positions_Short_All] <> source.[Tot_Rept_Positions_Short_All] OR target.[NonRept_Positions_Long_All] <> source.[NonRept_Positions_Long_All] OR target.[NonRept_Positions_Short_All] <> source.[NonRept_Positions_Short_All] OR target.[Open_Interest_Old] <> source.[Open_Interest_Old] OR target.[Prod_Merc_Positions_Long_Old] <> source.[Prod_Merc_Positions_Long_Old] OR target.[Prod_Merc_Positions_Short_Old] <> source.[Prod_Merc_Positions_Short_Old] OR target.[Swap_Positions_Long_Old] <> source.[Swap_Positions_Long_Old] OR target.[Swap_Positions_Short_Old] <> source.[Swap_Positions_Short_Old] OR target.[Swap_Positions_Spread_Old] <> source.[Swap_Positions_Spread_Old] OR target.[M_Money_Positions_Long_Old] <> source.[M_Money_Positions_Long_Old] OR target.[M_Money_Positions_Short_Old] <> source.[M_Money_Positions_Short_Old] OR target.[M_Money_Positions_Spread_Old] <> source.[M_Money_Positions_Spread_Old] OR target.[Other_Rept_Positions_Long_Old] <> source.[Other_Rept_Positions_Long_Old] OR target.[Other_Rept_Positions_Short_Old] <> source.[Other_Rept_Positions_Short_Old] OR target.[Other_Rept_Positions_Spread_Old] <> source.[Other_Rept_Positions_Spread_Old] OR target.[Tot_Rept_Positions_Long_Old] <> source.[Tot_Rept_Positions_Long_Old] OR target.[Tot_Rept_Positions_Short_Old] <> source.[Tot_Rept_Positions_Short_Old] OR target.[NonRept_Positions_Long_Old] <> source.[NonRept_Positions_Long_Old] OR target.[NonRept_Positions_Short_Old] <> source.[NonRept_Positions_Short_Old] OR target.[Open_Interest_Other] <> source.[Open_Interest_Other] OR target.[Prod_Merc_Positions_Long_Other] <> source.[Prod_Merc_Positions_Long_Other] OR target.[Prod_Merc_Positions_Short_Other] <> source.[Prod_Merc_Positions_Short_Other] OR target.[Swap_Positions_Long_Other] <> source.[Swap_Positions_Long_Other] OR target.[Swap_Positions_Short_Other] <> source.[Swap_Positions_Short_Other] OR target.[Swap_Positions_Spread_Other] <> source.[Swap_Positions_Spread_Other] OR target.[M_Money_Positions_Long_Other] <> source.[M_Money_Positions_Long_Other] OR target.[M_Money_Positions_Short_Other] <> source.[M_Money_Positions_Short_Other] OR target.[M_Money_Positions_Spread_Other] <> source.[M_Money_Positions_Spread_Other] OR target.[Other_Rept_Positions_Long_Other] <> source.[Other_Rept_Positions_Long_Other] OR target.[Other_Rept_Positions_Short_Other] <> source.[Other_Rept_Positions_Short_Other] OR target.[Other_Rept_Positions_Spread_Other] <> source.[Other_Rept_Positions_Spread_Other] OR target.[Tot_Rept_Positions_Long_Other] <> source.[Tot_Rept_Positions_Long_Other] OR target.[Tot_Rept_Positions_Short_Other] <> source.[Tot_Rept_Positions_Short_Other] OR target.[NonRept_Positions_Long_Other] <> source.[NonRept ...
# THEN UPDATE SET target.[Market_and_Exchange_Names] = source.[Market_and_Exchange_Names], target.[As_of_Date_In_Form_YYMMDD] = source.[As_of_Date_In_Form_YYMMDD], target.[As_of_Date_Form_MM/DD/YYYY] = source.[As_of_Date_Form_MM/DD/YYYY], target.[Open_Interest_All] = source.[Open_Interest_All], target.[Prod_Merc_Positions_Long_All] = source.[Prod_Merc_Positions_Long_All], target.[Prod_Merc_Positions_Short_All] = source.[Prod_Merc_Positions_Short_All], target.[Swap_Positions_Long_All] = source.[Swap_Positions_Long_All], target.[Swap_Positions_Short_All] = source.[Swap_Positions_Short_All], target.[Swap_Positions_Spread_All] = source.[Swap_Positions_Spread_All], target.[M_Money_Positions_Long_All] = source.[M_Money_Positions_Long_All], target.[M_Money_Positions_Short_All] = source.[M_Money_Positions_Short_All], target.[M_Money_Positions_Spread_All] = source.[M_Money_Positions_Spread_All], target.[Other_Rept_Positions_Long_All] = source.[Other_Rept_Positions_Long_All], target.[Other_Rept_Positions_Short_All] = source.[Other_Rept_Positions_Short_All], target.[Other_Rept_Positions_Spread_All] = source.[Other_Rept_Positions_Spread_All], target.[Tot_Rept_Positions_Long_All] = source.[Tot_Rept_Positions_Long_All], target.[Tot_Rept_Positions_Short_All] = source.[Tot_Rept_Positions_Short_All], target.[NonRept_Positions_Long_All] = source.[NonRept_Positions_Long_All], target.[NonRept_Positions_Short_All] = source.[NonRept_Positions_Short_All], target.[Open_Interest_Old] = source.[Open_Interest_Old], target.[Prod_Merc_Positions_Long_Old] = source.[Prod_Merc_Positions_Long_Old], target.[Prod_Merc_Positions_Short_Old] = source.[Prod_Merc_Positions_Short_Old], target.[Swap_Positions_Long_Old] = source.[Swap_Positions_Long_Old], target.[Swap_Positions_Short_Old] = source.[Swap_Positions_Short_Old], target.[Swap_Positions_Spread_Old] = source.[Swap_Positions_Spread_Old], target.[M_Money_Positions_Long_Old] = source.[M_Money_Positions_Long_Old], target.[M_Money_Positions_Short_Old] = source.[M_Money_Positions_Short_Old], target.[M_Money_Positions_Spread_Old] = source.[M_Money_Positions_Spread_Old], target.[Other_Rept_Positions_Long_Old] = source.[Other_Rept_Positions_Long_Old], target.[Other_Rept_Positions_Short_Old] = source.[Other_Rept_Positions_Short_Old], target.[Other_Rept_Positions_Spread_Old] = source.[Other_Rept_Positions_Spread_Old], target.[Tot_Rept_Positions_Long_Old] = source.[Tot_Rept_Positions_Long_Old], target.[Tot_Rept_Positions_Short_Old] = source.[Tot_Rept_Positions_Short_Old], target.[NonRept_Positions_Long_Old] = source.[NonRept_Positions_Long_Old], target.[NonRept_Positions_Short_Old] = source.[NonRept_Positions_Short_Old], target.[Open_Interest_Other] = source.[Open_Interest_Other], target.[Prod_Merc_Positions_Long_Other] = source.[Prod_Merc_Positions_Long_Other], target.[Prod_Merc_Positions_Short_Other] = source.[Prod_Merc_Positions_Short_Other], target.[Swap_Positions_Long_Other] = source.[Swap_Positions_Long_Other], target.[Swap_Positions_Short_Other] = source.[Swap_Positions_Short_Other], target.[Swap_Positions_Spread_Other] = source.[Swap_Positions_Spread_Other], target.[M_Money_Positions_Long_Other] = source.[M_Money_Positions_Long_Other], target.[M_Money_Positions_Short_Other] = source.[M_Money_Positions_Short_Other], target.[M_Money_Positions_Spread_Other] = source.[M_Money_Positions_Spread_Other], target.[Other_Rept_Positions_Long_Other] = source.[Other_Rept_Positions_Long_Other], target.[Other_Rept_Positions_Short_Other] = source.[Other_Rept_Positions_Short_Other], target.[Other_Rept_Positions_Spread_Other] = source.[Other_Rept_Positions_Spread_Other], target.[Tot_Rept_Positions_Long_Other] = source.[Tot_Rept_Positions_Long_Other], target.[Tot_Rept_Positions_Short_Other] = source.[Tot_Rept_Positions_Short_Other], target.[NonRept_Positions_Long_Other] = source.[NonRept_Positions_Long_Other], target.[NonRept_Positions_Short_Other] = source.[NonRept_Positions_Short_Other], target.[Change_in_Open_Interest_All] = source ...
# WHEN NOT MATCHED
# THEN INSERT ([Market_and_Exchange_Names], [As_of_Date_In_Form_YYMMDD], [As_of_Date_Form_MM/DD/YYYY], [CFTC_Contract_Market_Code], [CFTC_Market_Code], [CFTC_Region_Code], [CFTC_Commodity_Code], [Open_Interest_All], [Prod_Merc_Positions_Long_All], [Prod_Merc_Positions_Short_All], [Swap_Positions_Long_All], [Swap_Positions_Short_All], [Swap_Positions_Spread_All], [M_Money_Positions_Long_All], [M_Money_Positions_Short_All], [M_Money_Positions_Spread_All], [Other_Rept_Positions_Long_All], [Other_Rept_Positions_Short_All], [Other_Rept_Positions_Spread_All], [Tot_Rept_Positions_Long_All], [Tot_Rept_Positions_Short_All], [NonRept_Positions_Long_All], [NonRept_Positions_Short_All], [Open_Interest_Old], [Prod_Merc_Positions_Long_Old], [Prod_Merc_Positions_Short_Old], [Swap_Positions_Long_Old], [Swap_Positions_Short_Old], [Swap_Positions_Spread_Old], [M_Money_Positions_Long_Old], [M_Money_Positions_Short_Old], [M_Money_Positions_Spread_Old], [Other_Rept_Positions_Long_Old], [Other_Rept_Positions_Short_Old], [Other_Rept_Positions_Spread_Old], [Tot_Rept_Positions_Long_Old], [Tot_Rept_Positions_Short_Old], [NonRept_Positions_Long_Old], [NonRept_Positions_Short_Old], [Open_Interest_Other], [Prod_Merc_Positions_Long_Other], [Prod_Merc_Positions_Short_Other], [Swap_Positions_Long_Other], [Swap_Positions_Short_Other], [Swap_Positions_Spread_Other], [M_Money_Positions_Long_Other], [M_Money_Positions_Short_Other], [M_Money_Positions_Spread_Other], [Other_Rept_Positions_Long_Other], [Other_Rept_Positions_Short_Other], [Other_Rept_Positions_Spread_Other], [Tot_Rept_Positions_Long_Other], [Tot_Rept_Positions_Short_Other], [NonRept_Positions_Long_Other], [NonRept_Positions_Short_Other], [Change_in_Open_Interest_All], [Change_in_Prod_Merc_Long_All], [Change_in_Prod_Merc_Short_All], [Change_in_Swap_Long_All], [Change_in_Swap_Short_All], [Change_in_Swap_Spread_All], [Change_in_M_Money_Long_All], [Change_in_M_Money_Short_All], [Change_in_M_Money_Spread_All], [Change_in_Other_Rept_Long_All], [Change_in_Other_Rept_Short_All], [Change_in_Other_Rept_Spread_All], [Change_in_Tot_Rept_Long_All], [Change_in_Tot_Rept_Short_All], [Change_in_NonRept_Long_All], [Change_in_NonRept_Short_All], [Pct_of_Open_Interest_All], [Pct_of_OI_Prod_Merc_Long_All], [Pct_of_OI_Prod_Merc_Short_All], [Pct_of_OI_Swap_Long_All], [Pct_of_OI_Swap_Short_All], [Pct_of_OI_Swap_Spread_All], [Pct_of_OI_M_Money_Long_All], [Pct_of_OI_M_Money_Short_All], [Pct_of_OI_M_Money_Spread_All], [Pct_of_OI_Other_Rept_Long_All], [Pct_of_OI_Other_Rept_Short_All], [Pct_of_OI_Other_Rept_Spread_All], [Pct_of_OI_Tot_Rept_Long_All], [Pct_of_OI_Tot_Rept_Short_All], [Pct_of_OI_NonRept_Long_All], [Pct_of_OI_NonRept_Short_All], [Pct_of_Open_Interest_Old], [Pct_of_OI_Prod_Merc_Long_Old], [Pct_of_OI_Prod_Merc_Short_Old], [Pct_of_OI_Swap_Long_Old], [Pct_of_OI_Swap_Short_Old], [Pct_of_OI_Swap_Spread_Old], [Pct_of_OI_M_Money_Long_Old], [Pct_of_OI_M_Money_Short_Old], [Pct_of_OI_M_Money_Spread_Old], [Pct_of_OI_Other_Rept_Long_Old], [Pct_of_OI_Other_Rept_Short_Old], [Pct_of_OI_Other_Rept_Spread_Old], [Pct_of_OI_Tot_Rept_Long_Old], [Pct_of_OI_Tot_Rept_Short_Old], [Pct_of_OI_NonRept_Long_Old], [Pct_of_OI_NonRept_Short_Old], [Pct_of_Open_Interest_Other], [Pct_of_OI_Prod_Merc_Long_Other], [Pct_of_OI_Prod_Merc_Short_Other], [Pct_of_OI_Swap_Long_Other], [Pct_of_OI_Swap_Short_Other], [Pct_of_OI_Swap_Spread_Other], [Pct_of_OI_M_Money_Long_Other], [Pct_of_OI_M_Money_Short_Other], [Pct_of_OI_M_Money_Spread_Other], [Pct_of_OI_Other_Rept_Long_Other], [Pct_of_OI_Other_Rept_Short_Other], [Pct_of_OI_Other_Rept_Spread_Other], [Pct_of_OI_Tot_Rept_Long_Other], [Pct_of_OI_Tot_Rept_Short_Other], [Pct_of_OI_NonRept_Long_Other], [Pct_of_OI_NonRept_Short_Other], [Traders_Tot_All], [Traders_Prod_Merc_Long_All], [Traders_Prod_Merc_Short_All], [Traders_Swap_Long_All], [Traders_Swap_Short_All], [Traders_Swap_Spread_All], [Traders_M_Money_Long_All], [Traders_M_Money_Short_All], [Traders_M_Money_Spread_All], [Traders_Other_Rept_Long_All], [Traders_Othe ...
# VALUES (source.[Market_and_Exchange_Names], source.[As_of_Date_In_Form_YYMMDD], source.[As_of_Date_Form_MM/DD/YYYY], source.[CFTC_Contract_Market_Code], source.[CFTC_Market_Code], source.[CFTC_Region_Code], source.[CFTC_Commodity_Code], source.[Open_Interest_All], source.[Prod_Merc_Positions_Long_All], source.[Prod_Merc_Positions_Short_All], source.[Swap_Positions_Long_All], source.[Swap_Positions_Short_All], source.[Swap_Positions_Spread_All], source.[M_Money_Positions_Long_All], source.[M_Money_Positions_Short_All], source.[M_Money_Positions_Spread_All], source.[Other_Rept_Positions_Long_All], source.[Other_Rept_Positions_Short_All], source.[Other_Rept_Positions_Spread_All], source.[Tot_Rept_Positions_Long_All], source.[Tot_Rept_Positions_Short_All], source.[NonRept_Positions_Long_All], source.[NonRept_Positions_Short_All], source.[Open_Interest_Old], source.[Prod_Merc_Positions_Long_Old], source.[Prod_Merc_Positions_Short_Old], source.[Swap_Positions_Long_Old], source.[Swap_Positions_Short_Old], source.[Swap_Positions_Spread_Old], source.[M_Money_Positions_Long_Old], source.[M_Money_Positions_Short_Old], source.[M_Money_Positions_Spread_Old], source.[Other_Rept_Positions_Long_Old], source.[Other_Rept_Positions_Short_Old], source.[Other_Rept_Positions_Spread_Old], source.[Tot_Rept_Positions_Long_Old], source.[Tot_Rept_Positions_Short_Old], source.[NonRept_Positions_Long_Old], source.[NonRept_Positions_Short_Old], source.[Open_Interest_Other], source.[Prod_Merc_Positions_Long_Other], source.[Prod_Merc_Positions_Short_Other], source.[Swap_Positions_Long_Other], source.[Swap_Positions_Short_Other], source.[Swap_Positions_Spread_Other], source.[M_Money_Positions_Long_Other], source.[M_Money_Positions_Short_Other], source.[M_Money_Positions_Spread_Other], source.[Other_Rept_Positions_Long_Other], source.[Other_Rept_Positions_Short_Other], source.[Other_Rept_Positions_Spread_Other], source.[Tot_Rept_Positions_Long_Other], source.[Tot_Rept_Positions_Short_Other], source.[NonRept_Positions_Long_Other], source.[NonRept_Positions_Short_Other], source.[Change_in_Open_Interest_All], source.[Change_in_Prod_Merc_Long_All], source.[Change_in_Prod_Merc_Short_All], source.[Change_in_Swap_Long_All], source.[Change_in_Swap_Short_All], source.[Change_in_Swap_Spread_All], source.[Change_in_M_Money_Long_All], source.[Change_in_M_Money_Short_All], source.[Change_in_M_Money_Spread_All], source.[Change_in_Other_Rept_Long_All], source.[Change_in_Other_Rept_Short_All], source.[Change_in_Other_Rept_Spread_All], source.[Change_in_Tot_Rept_Long_All], source.[Change_in_Tot_Rept_Short_All], source.[Change_in_NonRept_Long_All], source.[Change_in_NonRept_Short_All], source.[Pct_of_Open_Interest_All], source.[Pct_of_OI_Prod_Merc_Long_All], source.[Pct_of_OI_Prod_Merc_Short_All], source.[Pct_of_OI_Swap_Long_All], source.[Pct_of_OI_Swap_Short_All], source.[Pct_of_OI_Swap_Spread_All], source.[Pct_of_OI_M_Money_Long_All], source.[Pct_of_OI_M_Money_Short_All], source.[Pct_of_OI_M_Money_Spread_All], source.[Pct_of_OI_Other_Rept_Long_All], source.[Pct_of_OI_Other_Rept_Short_All], source.[Pct_of_OI_Other_Rept_Spread_All], source.[Pct_of_OI_Tot_Rept_Long_All], source.[Pct_of_OI_Tot_Rept_Short_All], source.[Pct_of_OI_NonRept_Long_All], source.[Pct_of_OI_NonRept_Short_All], source.[Pct_of_Open_Interest_Old], source.[Pct_of_OI_Prod_Merc_Long_Old], source.[Pct_of_OI_Prod_Merc_Short_Old], source.[Pct_of_OI_Swap_Long_Old], source.[Pct_of_OI_Swap_Short_Old], source.[Pct_of_OI_Swap_Spread_Old], source.[Pct_of_OI_M_Money_Long_Old], source.[Pct_of_OI_M_Money_Short_Old], source.[Pct_of_OI_M_Money_Spread_Old], source.[Pct_of_OI_Other_Rept_Long_Old], source.[Pct_of_OI_Other_Rept_Short_Old], source.[Pct_of_OI_Other_Rept_Spread_Old], source.[Pct_of_OI_Tot_Rept_Long_Old], source.[Pct_of_OI_Tot_Rept_Short_Old], source.[Pct_of_OI_NonRept_Long_Old], source.[Pct_of_OI_NonRept_Short_Old], source.[Pct_of_Open_Interest_Other], source.[Pct_of_OI_Prod_Merc_Long_Other], source.[Pct_of_OI_Prod_ ...
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "GET /dimension/source?code=com_theice_COTHist2021 HTTP/1.1" 200 698
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): vipenta:8000
# DEBUG:urllib3.connectionpool:http://vipenta:8000 "PUT /dimension/source/7028 HTTP/1.1" 201 10
# INFO:scraper.core.utils:update_sources_metadata: 84.99026298522949 ms

# %%
list(job.data.columns)
# Out:
# ['Market_and_Exchange_Names',
#  'As_of_Date_In_Form_YYMMDD',
#  'As_of_Date_Form_MM/DD/YYYY',
#  'CFTC_Contract_Market_Code',
#  'CFTC_Market_Code',
#  'CFTC_Region_Code',
#  'CFTC_Commodity_Code',
#  'Open_Interest_All',
#  'Prod_Merc_Positions_Long_All',
#  'Prod_Merc_Positions_Short_All',
#  'Swap_Positions_Long_All',
#  'Swap_Positions_Short_All',
#  'Swap_Positions_Spread_All',
#  'M_Money_Positions_Long_All',
#  'M_Money_Positions_Short_All',
#  'M_Money_Positions_Spread_All',
#  'Other_Rept_Positions_Long_All',
#  'Other_Rept_Positions_Short_All',
#  'Other_Rept_Positions_Spread_All',
#  'Tot_Rept_Positions_Long_All',
#  'Tot_Rept_Positions_Short_All',
#  'NonRept_Positions_Long_All',
#  'NonRept_Positions_Short_All',
#  'Open_Interest_Old',
#  'Prod_Merc_Positions_Long_Old',
#  'Prod_Merc_Positions_Short_Old',
#  'Swap_Positions_Long_Old',
#  'Swap_Positions_Short_Old',
#  'Swap_Positions_Spread_Old',
#  'M_Money_Positions_Long_Old',
#  'M_Money_Positions_Short_Old',
#  'M_Money_Positions_Spread_Old',
#  'Other_Rept_Positions_Long_Old',
#  'Other_Rept_Positions_Short_Old',
#  'Other_Rept_Positions_Spread_Old',
#  'Tot_Rept_Positions_Long_Old',
#  'Tot_Rept_Positions_Short_Old',
#  'NonRept_Positions_Long_Old',
#  'NonRept_Positions_Short_Old',
#  'Open_Interest_Other',
#  'Prod_Merc_Positions_Long_Other',
#  'Prod_Merc_Positions_Short_Other',
#  'Swap_Positions_Long_Other',
#  'Swap_Positions_Short_Other',
#  'Swap_Positions_Spread_Other',
#  'M_Money_Positions_Long_Other',
#  'M_Money_Positions_Short_Other',
#  'M_Money_Positions_Spread_Other',
#  'Other_Rept_Positions_Long_Other',
#  'Other_Rept_Positions_Short_Other',
#  'Other_Rept_Positions_Spread_Other',
#  'Tot_Rept_Positions_Long_Other',
#  'Tot_Rept_Positions_Short_Other',
#  'NonRept_Positions_Long_Other',
#  'NonRept_Positions_Short_Other',
#  'Change_in_Open_Interest_All',
#  'Change_in_Prod_Merc_Long_All',
#  'Change_in_Prod_Merc_Short_All',
#  'Change_in_Swap_Long_All',
#  'Change_in_Swap_Short_All',
#  'Change_in_Swap_Spread_All',
#  'Change_in_M_Money_Long_All',
#  'Change_in_M_Money_Short_All',
#  'Change_in_M_Money_Spread_All',
#  'Change_in_Other_Rept_Long_All',
#  'Change_in_Other_Rept_Short_All',
#  'Change_in_Other_Rept_Spread_All',
#  'Change_in_Tot_Rept_Long_All',
#  'Change_in_Tot_Rept_Short_All',
#  'Change_in_NonRept_Long_All',
#  'Change_in_NonRept_Short_All',
#  'Pct_of_Open_Interest_All',
#  'Pct_of_OI_Prod_Merc_Long_All',
#  'Pct_of_OI_Prod_Merc_Short_All',
#  'Pct_of_OI_Swap_Long_All',
#  'Pct_of_OI_Swap_Short_All',
#  'Pct_of_OI_Swap_Spread_All',
#  'Pct_of_OI_M_Money_Long_All',
#  'Pct_of_OI_M_Money_Short_All',
#  'Pct_of_OI_M_Money_Spread_All',
#  'Pct_of_OI_Other_Rept_Long_All',
#  'Pct_of_OI_Other_Rept_Short_All',
#  'Pct_of_OI_Other_Rept_Spread_All',
#  'Pct_of_OI_Tot_Rept_Long_All',
#  'Pct_of_OI_Tot_Rept_Short_All',
#  'Pct_of_OI_NonRept_Long_All',
#  'Pct_of_OI_NonRept_Short_All',
#  'Pct_of_Open_Interest_Old',
#  'Pct_of_OI_Prod_Merc_Long_Old',
#  'Pct_of_OI_Prod_Merc_Short_Old',
#  'Pct_of_OI_Swap_Long_Old',
#  'Pct_of_OI_Swap_Short_Old',
#  'Pct_of_OI_Swap_Spread_Old',
#  'Pct_of_OI_M_Money_Long_Old',
#  'Pct_of_OI_M_Money_Short_Old',
#  'Pct_of_OI_M_Money_Spread_Old',
#  'Pct_of_OI_Other_Rept_Long_Old',
#  'Pct_of_OI_Other_Rept_Short_Old',
#  'Pct_of_OI_Other_Rept_Spread_Old',
#  'Pct_of_OI_Tot_Rept_Long_Old',
#  'Pct_of_OI_Tot_Rept_Short_Old',
#  'Pct_of_OI_NonRept_Long_Old',
#  'Pct_of_OI_NonRept_Short_Old',
#  'Pct_of_Open_Interest_Other',
#  'Pct_of_OI_Prod_Merc_Long_Other',
#  'Pct_of_OI_Prod_Merc_Short_Other',
#  'Pct_of_OI_Swap_Long_Other',
#  'Pct_of_OI_Swap_Short_Other',
#  'Pct_of_OI_Swap_Spread_Other',
#  'Pct_of_OI_M_Money_Long_Other',
#  'Pct_of_OI_M_Money_Short_Other',
#  'Pct_of_OI_M_Money_Spread_Other',
#  'Pct_of_OI_Other_Rept_Long_Other',
#  'Pct_of_OI_Other_Rept_Short_Other',
#  'Pct_of_OI_Other_Rept_Spread_Other',
#  'Pct_of_OI_Tot_Rept_Long_Other',
#  'Pct_of_OI_Tot_Rept_Short_Other',
#  'Pct_of_OI_NonRept_Long_Other',
#  'Pct_of_OI_NonRept_Short_Other',
#  'Traders_Tot_All',
#  'Traders_Prod_Merc_Long_All',
#  'Traders_Prod_Merc_Short_All',
#  'Traders_Swap_Long_All',
#  'Traders_Swap_Short_All',
#  'Traders_Swap_Spread_All',
#  'Traders_M_Money_Long_All',
#  'Traders_M_Money_Short_All',
#  'Traders_M_Money_Spread_All',
#  'Traders_Other_Rept_Long_All',
#  'Traders_Other_Rept_Short_All',
#  'Traders_Other_Rept_Spread_All',
#  'Traders_Tot_Rept_Long_All',
#  'Traders_Tot_Rept_Short_All',
#  'Traders_Tot_Old',
#  'Traders_Prod_Merc_Long_Old',
#  'Traders_Prod_Merc_Short_Old',
#  'Traders_Swap_Long_Old',
#  'Traders_Swap_Short_Old',
#  'Traders_Swap_Spread_Old',
#  'Traders_M_Money_Long_Old',
#  'Traders_M_Money_Short_Old',
#  'Traders_M_Money_Spread_Old',
#  'Traders_Other_Rept_Long_Old',
#  'Traders_Other_Rept_Short_Old',
#  'Traders_Other_Rept_Spread_Old',
#  'Traders_Tot_Rept_Long_Old',
#  'Traders_Tot_Rept_Short_Old',
#  'Traders_Tot_Other',
#  'Traders_Prod_Merc_Long_Other',
#  'Traders_Prod_Merc_Short_Other',
#  'Traders_Swap_Long_Other',
#  'Traders_Swap_Short_Other',
#  'Traders_Swap_Spread_Other',
#  'Traders_M_Money_Long_Other',
#  'Traders_M_Money_Short_Other',
#  'Traders_M_Money_Spread_Other',
#  'Traders_Other_Rept_Long_Other',
#  'Traders_Other_Rept_Short_Other',
#  'Traders_Other_Rept_Spread_Other',
#  'Traders_Tot_Rept_Long_Other',
#  'Traders_Tot_Rept_Short_Other',
#  'Conc_Gross_LE_4_TDR_Long_All',
#  'Conc_Gross_LE_4_TDR_Short_All',
#  'Conc_Gross_LE_8_TDR_Long_All',
#  'Conc_Gross_LE_8_TDR_Short_All',
#  'Conc_Net_LE_4_TDR_Long_All',
#  'Conc_Net_LE_4_TDR_Short_All',
#  'Conc_Net_LE_8_TDR_Long_All',
#  'Conc_Net_LE_8_TDR_Short_All',
#  'Conc_Gross_LE_4_TDR_Long_Old',
#  'Conc_Gross_LE_4_TDR_Short_Old',
#  'Conc_Gross_LE_8_TDR_Long_Old',
#  'Conc_Gross_LE_8_TDR_Short_Old',
#  'Conc_Net_LE_4_TDR_Long_Old',
#  'Conc_Net_LE_4_TDR_Short_Old',
#  'Conc_Net_LE_8_TDR_Long_Old',
#  'Conc_Net_LE_8_TDR_Short_Old',
#  'Conc_Gross_LE_4_TDR_Long_Other',
#  'Conc_Gross_LE_4_TDR_Short_Other',
#  'Conc_Gross_LE_8_TDR_Long_Other',
#  'Conc_Gross_LE_8_TDR_Short_Other',
#  'Conc_Net_LE_4_TDR_Long_Other',
#  'Conc_Net_LE_4_TDR_Short_Other',
#  'Conc_Net_LE_8_TDR_Long_Other',
#  'Conc_Net_LE_8_TDR_Short_Other',
#  'Contract_Units',
#  'CFTC_Contract_Market_Code_Quotes',
#  'CFTC_Market_Code_Quotes',
#  'CFTC_Commodity_Code_Quotes',
#  'CFTC_SubGroup_Code',
#  'FutOnly_or_Combined',
#  'source',
#  'provider',
#  'Week_of_Release']

# %%
display(job.data.dtypes)
display(job.data['Market_and_Exchange_Names'].drop_duplicates())

display(job.data['CFTC_Market_Code'].drop_duplicates())
display(job.data['CFTC_Commodity_Code_Quotes'].drop_duplicates())
# Out:
# Market_and_Exchange_Names             object
# As_of_Date_In_Form_YYMMDD             object
# As_of_Date_Form_MM/DD/YYYY            object
# CFTC_Contract_Market_Code             object
# CFTC_Market_Code                      object
#                                    ...
# CFTC_SubGroup_Code                   float64
# FutOnly_or_Combined                   object
# source                                object
# Week_of_Release               datetime64[ns]
# date_created                  datetime64[ns]
# Length: 194, dtype: object
# 0               ICE Gasoil Futures - ICE Futures Europe
# 1     ICE Gasoil Futures and Options - ICE Futures E...
# 2          ICE Brent Crude Futures - ICE Futures Europe
# 3     ICE Brent Crude Futures and Options - ICE Futu...
# 4          ICE White Sugar Futures - ICE Futures Europe
# 5     ICE White Sugar Futures and Options- ICE Futur...
# 6                ICE Cocoa Futures - ICE Futures Europe
# 7     ICE Cocoa Futures and Options - ICE Futures Eu...
# 8       ICE Robusta Coffee Futures - ICE Futures Europe
# 9     ICE Robusta Coffee Futures and Options - ICE F...
# 10               ICE Wheat Futures - ICE Futures Europe
# 11    ICE Wheat Futures and Options - ICE Futures Eu...
# Name: Market_and_Exchange_Names, dtype: object
# 0    ICEU
# Name: CFTC_Market_Code, dtype: object
# 0   NaN
# Name: CFTC_Commodity_Code_Quotes, dtype: float64

# %%
[col for col in job.data.columns if 'Swap' in col]
# Out:
# ['Swap_Positions_Long_All',
#  'Swap_Positions_Short_All',
#  'Swap_Positions_Spread_All',
#  'Swap_Positions_Long_Old',
#  'Swap_Positions_Short_Old',
#  'Swap_Positions_Spread_Old',
#  'Swap_Positions_Long_Other',
#  'Swap_Positions_Short_Other',
#  'Swap_Positions_Spread_Other',
#  'Change_in_Swap_Long_All',
#  'Change_in_Swap_Short_All',
#  'Change_in_Swap_Spread_All',
#  'Pct_of_OI_Swap_Long_All',
#  'Pct_of_OI_Swap_Short_All',
#  'Pct_of_OI_Swap_Spread_All',
#  'Pct_of_OI_Swap_Long_Old',
#  'Pct_of_OI_Swap_Short_Old',
#  'Pct_of_OI_Swap_Spread_Old',
#  'Pct_of_OI_Swap_Long_Other',
#  'Pct_of_OI_Swap_Short_Other',
#  'Pct_of_OI_Swap_Spread_Other',
#  'Traders_Swap_Long_All',
#  'Traders_Swap_Short_All',
#  'Traders_Swap_Spread_All',
#  'Traders_Swap_Long_Old',
#  'Traders_Swap_Short_Old',
#  'Traders_Swap_Spread_Old',
#  'Traders_Swap_Long_Other',
#  'Traders_Swap_Short_Other',
#  'Traders_Swap_Spread_Other']

# %%
# column headers for each source file
csv_columns = {'Market_and_Exchange_Names': str,
                   'As_of_Date_In_Form_YYMMDD': int,
                   'As_of_Date_Form_MM/DD/YYYY': str,
                   'CFTC_Contract_Market_Code': str,
                   'CFTC_Market_Code': str,
                   'CFTC_Region_Code': int,
                   'CFTC_Commodity_Code': str,
                   'Open_Interest_All': int,
                   'Prod_Merc_Positions_Long_All': int,
                   'Prod_Merc_Positions_Short_All': int,
                   'Swap_Positions_Long_All': int,
                   'Swap_Positions_Short_All': int,
                   'Swap_Positions_Spread_All': int,
                   'M_Money_Positions_Long_All': int,
                   'M_Money_Positions_Short_All': int,
                   'M_Money_Positions_Spread_All': int,
                   'Other_Rept_Positions_Long_All': int,
                   'Other_Rept_Positions_Short_All': int,
                   'Other_Rept_Positions_Spread_All': int,
                   'Tot_Rept_Positions_Long_All': float,
                   'Tot_Rept_Positions_Short_All': float,
                   'NonRept_Positions_Long_All': int,
                   'NonRept_Positions_Short_All': int,
                   'Open_Interest_Old': int,
                   'Prod_Merc_Positions_Long_Old': int,
                   'Prod_Merc_Positions_Short_Old': int,
                   'Swap_Positions_Long_Old': int,
                   'Swap_Positions_Short_Old': int,
                   'Swap_Positions_Spread_Old': int,
                   'M_Money_Positions_Long_Old': int,
                   'M_Money_Positions_Short_Old': int,
                   'M_Money_Positions_Spread_Old': int,
                   'Other_Rept_Positions_Long_Old': int,
                   'Other_Rept_Positions_Short_Old': int,
                   'Other_Rept_Positions_Spread_Old': int,
                   'Tot_Rept_Positions_Long_Old': float,
                   'Tot_Rept_Positions_Short_Old': float,
                   'NonRept_Positions_Long_Old': int,
                   'NonRept_Positions_Short_Old': int,
                   'Open_Interest_Other': float,
                   'Prod_Merc_Positions_Long_Other': float,
                   'Prod_Merc_Positions_Short_Other': float,
                   'Swap_Positions_Long_Other': float,
                   'Swap_Positions_Short_Other': float,
                   'Swap_Positions_Spread_Other': float,
                   'M_Money_Positions_Long_Other': float,
                   'M_Money_Positions_Short_Other': float,
                   'M_Money_Positions_Spread_Other': float,
                   'Other_Rept_Positions_Long_Other': float,
                   'Other_Rept_Positions_Short_Other': float,
                   'Other_Rept_Positions_Spread_Other': float,
                   'Tot_Rept_Positions_Long_Other': float,
                   'Tot_Rept_Positions_Short_Other': float,
                   'NonRept_Positions_Long_Other': float,
                   'NonRept_Positions_Short_Other': float,
                   'Change_in_Open_Interest_All': float,
                   'Change_in_Prod_Merc_Long_All': float,
                   'Change_in_Prod_Merc_Short_All': float,
                   'Change_in_Swap_Long_All': float,
                   'Change_in_Swap_Short_All': float,
                   'Change_in_Swap_Spread_All': float,
                   'Change_in_M_Money_Long_All': float,
                   'Change_in_M_Money_Short_All': float,
                   'Change_in_M_Money_Spread_All': float,
                   'Change_in_Other_Rept_Long_All': float,
                   'Change_in_Other_Rept_Short_All': float,
                   'Change_in_Other_Rept_Spread_All': float,
                   'Change_in_Tot_Rept_Long_All': float,
                   'Change_in_Tot_Rept_Short_All': float,
                   'Change_in_NonRept_Long_All': float,
                   'Change_in_NonRept_Short_All': float,
                   'Pct_of_Open_Interest_All': int,
                   'Pct_of_OI_Prod_Merc_Long_All': float,
                   'Pct_of_OI_Prod_Merc_Short_All': float,
                   'Pct_of_OI_Swap_Long_All': float,
                   'Pct_of_OI_Swap_Short_All': float,
                   'Pct_of_OI_Swap_Spread_All': float,
                   'Pct_of_OI_M_Money_Long_All': float,
                   'Pct_of_OI_M_Money_Short_All': float,
                   'Pct_of_OI_M_Money_Spread_All': float,
                   'Pct_of_OI_Other_Rept_Long_All': float,
                   'Pct_of_OI_Other_Rept_Short_All': float,
                   'Pct_of_OI_Other_Rept_Spread_All': float,
                   'Pct_of_OI_Tot_Rept_Long_All': str,
                   'Pct_of_OI_Tot_Rept_Short_All': str,
                   'Pct_of_OI_NonRept_Long_All': float,
                   'Pct_of_OI_NonRept_Short_All': float,
                   'Pct_of_Open_Interest_Old': int,
                   'Pct_of_OI_Prod_Merc_Long_Old': float,
                   'Pct_of_OI_Prod_Merc_Short_Old': float,
                   'Pct_of_OI_Swap_Long_Old': float,
                   'Pct_of_OI_Swap_Short_Old': float,
                   'Pct_of_OI_Swap_Spread_Old': float,
                   'Pct_of_OI_M_Money_Long_Old': float,
                   'Pct_of_OI_M_Money_Short_Old': float,
                   'Pct_of_OI_M_Money_Spread_Old': float,
                   'Pct_of_OI_Other_Rept_Long_Old': float,
                   'Pct_of_OI_Other_Rept_Short_Old': float,
                   'Pct_of_OI_Other_Rept_Spread_Old': float,
                   'Pct_of_OI_Tot_Rept_Long_Old': str,
                   'Pct_of_OI_Tot_Rept_Short_Old': str,
                   'Pct_of_OI_NonRept_Long_Old': float,
                   'Pct_of_OI_NonRept_Short_Old': float,
                   'Pct_of_Open_Interest_Other': float,
                   'Pct_of_OI_Prod_Merc_Long_Other': float,
                   'Pct_of_OI_Prod_Merc_Short_Other': float,
                   'Pct_of_OI_Swap_Long_Other': float,
                   'Pct_of_OI_Swap_Short_Other': float,
                   'Pct_of_OI_Swap_Spread_Other': float,
                   'Pct_of_OI_M_Money_Long_Other': float,
                   'Pct_of_OI_M_Money_Short_Other': float,
                   'Pct_of_OI_M_Money_Spread_Other': float,
                   'Pct_of_OI_Other_Rept_Long_Other': float,
                   'Pct_of_OI_Other_Rept_Short_Other': float,
                   'Pct_of_OI_Other_Rept_Spread_Other': float,
                   'Pct_of_OI_Tot_Rept_Long_Other': float,
                   'Pct_of_OI_Tot_Rept_Short_Other': float,
                   'Pct_of_OI_NonRept_Long_Other': float,
                   'Pct_of_OI_NonRept_Short_Other': float,
                   'Traders_Tot_All': int,
                   'Traders_Prod_Merc_Long_All': int,
                   'Traders_Prod_Merc_Short_All': int,
                   'Traders_Swap_Long_All': int,
                   'Traders_Swap_Short_All': int,
                   'Traders_Swap_Spread_All': int,
                   'Traders_M_Money_Long_All': int,
                   'Traders_M_Money_Short_All': int,
                   'Traders_M_Money_Spread_All': int,
                   'Traders_Other_Rept_Long_All': int,
                   'Traders_Other_Rept_Short_All': int,
                   'Traders_Other_Rept_Spread_All': int,
                   'Traders_Tot_Rept_Long_All': float,
                   'Traders_Tot_Rept_Short_All': float,
                   'Traders_Tot_Old': int,
                   'Traders_Prod_Merc_Long_Old': int,
                   'Traders_Prod_Merc_Short_Old': int,
                   'Traders_Swap_Long_Old': int,
                   'Traders_Swap_Short_Old': int,
                   'Traders_Swap_Spread_Old': int,
                   'Traders_M_Money_Long_Old': int,
                   'Traders_M_Money_Short_Old': int,
                   'Traders_M_Money_Spread_Old': int,
                   'Traders_Other_Rept_Long_Old': int,
                   'Traders_Other_Rept_Short_Old': int,
                   'Traders_Other_Rept_Spread_Old': int,
                   'Traders_Tot_Rept_Long_Old': float,
                   'Traders_Tot_Rept_Short_Old': float,
                   'Traders_Tot_Other': float,
                   'Traders_Prod_Merc_Long_Other': float,
                   'Traders_Prod_Merc_Short_Other': float,
                   'Traders_Swap_Long_Other': float,
                   'Traders_Swap_Short_Other': float,
                   'Traders_Swap_Spread_Other': float,
                   'Traders_M_Money_Long_Other': float,
                   'Traders_M_Money_Short_Other': float,
                   'Traders_M_Money_Spread_Other': float,
                   'Traders_Other_Rept_Long_Other': float,
                   'Traders_Other_Rept_Short_Other': float,
                   'Traders_Other_Rept_Spread_Other': float,
                   'Traders_Tot_Rept_Long_Other': float,
                   'Traders_Tot_Rept_Short_Other': float,
                   'Conc_Gross_LE_4_TDR_Long_All': float,
                   'Conc_Gross_LE_4_TDR_Short_All': float,
                   'Conc_Gross_LE_8_TDR_Long_All': float,
                   'Conc_Gross_LE_8_TDR_Short_All': float,
                   'Conc_Net_LE_4_TDR_Long_All': float,
                   'Conc_Net_LE_4_TDR_Short_All': float,
                   'Conc_Net_LE_8_TDR_Long_All': float,
                   'Conc_Net_LE_8_TDR_Short_All': float,
                   'Conc_Gross_LE_4_TDR_Long_Old': float,
                   'Conc_Gross_LE_4_TDR_Short_Old': float,
                   'Conc_Gross_LE_8_TDR_Long_Old': float,
                   'Conc_Gross_LE_8_TDR_Short_Old': float,
                   'Conc_Net_LE_4_TDR_Long_Old': float,
                   'Conc_Net_LE_4_TDR_Short_Old': float,
                   'Conc_Net_LE_8_TDR_Long_Old': float,
                   'Conc_Net_LE_8_TDR_Short_Old': float,
                   'Conc_Gross_LE_4_TDR_Long_Other': float,
                   'Conc_Gross_LE_4_TDR_Short_Other': float,
                   'Conc_Gross_LE_8_TDR_Long_Other': float,
                   'Conc_Gross_LE_8_TDR_Short_Other': float,
                   'Conc_Net_LE_4_TDR_Long_Other': float,
                   'Conc_Net_LE_4_TDR_Short_Other': float,
                   'Conc_Net_LE_8_TDR_Long_Other': float,
                   'Conc_Net_LE_8_TDR_Short_Other': float,
                   'Contract_Units': str,
                   'CFTC_Contract_Market_Code_Quotes': float,
                   'CFTC_Market_Code_Quotes': float,
                   'CFTC_Commodity_Code_Quotes': float,
                   'CFTC_SubGroup_Code': float,
                   'FutOnly_or_Combined': str}

# filename= r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv'

filename = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2020.csv'

import pandas as pd
df = pd.read_csv(filename,
                 skip_blank_lines=True,
                 names=csv_columns.keys(),
                 dtype=csv_columns,
                 na_values=' ',
                 index_col = False,
                 header=0
                 )
print(f'nb cols 2020: {len(df.columns)}')
cols2020 = set(df.columns)

filename18 = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2018.csv'

df18 = pd.read_csv(filename18,
                 skip_blank_lines=True,
                 na_values=' ',
                 index_col = False,
                 header=0
                 )

print(f'nb cols 2018: {len(df18.columns)}')
cols2018 = set(df18.columns)
# Out:
# nb cols 2020: 191
# nb cols 2018: 192

# %%
display(cols2020 - cols2018)
display(cols2018 - cols2020)
# Out:
# {'Swap_Positions_Short_All',
#  'Swap_Positions_Short_Old',
#  'Swap_Positions_Short_Other',
#  'Swap_Positions_Spread_All',
#  'Swap_Positions_Spread_Old',
#  'Swap_Positions_Spread_Other'}
# {'Swap__Positions_Short_All',
#  'Swap__Positions_Short_Old',
#  'Swap__Positions_Short_Other',
#  'Swap__Positions_Spread_All',
#  'Swap__Positions_Spread_Old',
#  'Swap__Positions_Spread_Other',
#  'Unnamed: 191'}

# %%
df18.iloc[:, -1].drop_duplicates()
# Out:
# 0      NaN
# 612      Y
# Name: Unnamed: 191, dtype: object

# %% [markdown]
# So, as we can see, 2018 file has Swap Positions columns with a '_' in excess.
# Moreover, it has an additional last column in the end with 'y' values.
#
# By the log in cell [11], we see that 2017 file has '#VALUE!' values. We need to treat this value as null as well.

# %%
# fix to 2018:
# on doit lire les colonnes en renommant les colonnes contenant _ additionnel
# on doit également ajouter la colonne additionnelle
# pour finir, une fois le data frame lu, on doit supprimer la dernière colonne et renommer les colonnes pour que elles soit egales aux autres années

col_headers18 = [col_header.replace('Swap_Positions', 'Swap__Positions') if ('Swap_Positions_Short_' in col_header or 
                                                                             'Swap_Positions_Spread_' in col_header) 
                                                                         else col_header 
                 for col_header in list(csv_columns)]
col_headers18

# replace keys by 2018 keys
csv18_columns = dict(zip(col_headers18, list(csv_columns.values())))

csv18_columns['Unnamed: 191'] = str

# %%
filename18 = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2018.csv'

df18 = pd.read_csv(filename18,
                 skip_blank_lines=True,
                 na_values=[' ', '#VALUE!'],
                 names=csv18_columns.keys(),
                 dtype=csv18_columns,
                 index_col = False,
                 header=0
                 )

# %%
# remove last column
df18 = df18[df18.columns[:-1]]

# %%
list(df18.columns)
# Out:
# ['Market_and_Exchange_Names',
#  'As_of_Date_In_Form_YYMMDD',
#  'As_of_Date_Form_MM/DD/YYYY',
#  'CFTC_Contract_Market_Code',
#  'CFTC_Market_Code',
#  'CFTC_Region_Code',
#  'CFTC_Commodity_Code',
#  'Open_Interest_All',
#  'Prod_Merc_Positions_Long_All',
#  'Prod_Merc_Positions_Short_All',
#  'Swap_Positions_Long_All',
#  'Swap__Positions_Short_All',
#  'Swap__Positions_Spread_All',
#  'M_Money_Positions_Long_All',
#  'M_Money_Positions_Short_All',
#  'M_Money_Positions_Spread_All',
#  'Other_Rept_Positions_Long_All',
#  'Other_Rept_Positions_Short_All',
#  'Other_Rept_Positions_Spread_All',
#  'Tot_Rept_Positions_Long_All',
#  'Tot_Rept_Positions_Short_All',
#  'NonRept_Positions_Long_All',
#  'NonRept_Positions_Short_All',
#  'Open_Interest_Old',
#  'Prod_Merc_Positions_Long_Old',
#  'Prod_Merc_Positions_Short_Old',
#  'Swap_Positions_Long_Old',
#  'Swap__Positions_Short_Old',
#  'Swap__Positions_Spread_Old',
#  'M_Money_Positions_Long_Old',
#  'M_Money_Positions_Short_Old',
#  'M_Money_Positions_Spread_Old',
#  'Other_Rept_Positions_Long_Old',
#  'Other_Rept_Positions_Short_Old',
#  'Other_Rept_Positions_Spread_Old',
#  'Tot_Rept_Positions_Long_Old',
#  'Tot_Rept_Positions_Short_Old',
#  'NonRept_Positions_Long_Old',
#  'NonRept_Positions_Short_Old',
#  'Open_Interest_Other',
#  'Prod_Merc_Positions_Long_Other',
#  'Prod_Merc_Positions_Short_Other',
#  'Swap_Positions_Long_Other',
#  'Swap__Positions_Short_Other',
#  'Swap__Positions_Spread_Other',
#  'M_Money_Positions_Long_Other',
#  'M_Money_Positions_Short_Other',
#  'M_Money_Positions_Spread_Other',
#  'Other_Rept_Positions_Long_Other',
#  'Other_Rept_Positions_Short_Other',
#  'Other_Rept_Positions_Spread_Other',
#  'Tot_Rept_Positions_Long_Other',
#  'Tot_Rept_Positions_Short_Other',
#  'NonRept_Positions_Long_Other',
#  'NonRept_Positions_Short_Other',
#  'Change_in_Open_Interest_All',
#  'Change_in_Prod_Merc_Long_All',
#  'Change_in_Prod_Merc_Short_All',
#  'Change_in_Swap_Long_All',
#  'Change_in_Swap_Short_All',
#  'Change_in_Swap_Spread_All',
#  'Change_in_M_Money_Long_All',
#  'Change_in_M_Money_Short_All',
#  'Change_in_M_Money_Spread_All',
#  'Change_in_Other_Rept_Long_All',
#  'Change_in_Other_Rept_Short_All',
#  'Change_in_Other_Rept_Spread_All',
#  'Change_in_Tot_Rept_Long_All',
#  'Change_in_Tot_Rept_Short_All',
#  'Change_in_NonRept_Long_All',
#  'Change_in_NonRept_Short_All',
#  'Pct_of_Open_Interest_All',
#  'Pct_of_OI_Prod_Merc_Long_All',
#  'Pct_of_OI_Prod_Merc_Short_All',
#  'Pct_of_OI_Swap_Long_All',
#  'Pct_of_OI_Swap_Short_All',
#  'Pct_of_OI_Swap_Spread_All',
#  'Pct_of_OI_M_Money_Long_All',
#  'Pct_of_OI_M_Money_Short_All',
#  'Pct_of_OI_M_Money_Spread_All',
#  'Pct_of_OI_Other_Rept_Long_All',
#  'Pct_of_OI_Other_Rept_Short_All',
#  'Pct_of_OI_Other_Rept_Spread_All',
#  'Pct_of_OI_Tot_Rept_Long_All',
#  'Pct_of_OI_Tot_Rept_Short_All',
#  'Pct_of_OI_NonRept_Long_All',
#  'Pct_of_OI_NonRept_Short_All',
#  'Pct_of_Open_Interest_Old',
#  'Pct_of_OI_Prod_Merc_Long_Old',
#  'Pct_of_OI_Prod_Merc_Short_Old',
#  'Pct_of_OI_Swap_Long_Old',
#  'Pct_of_OI_Swap_Short_Old',
#  'Pct_of_OI_Swap_Spread_Old',
#  'Pct_of_OI_M_Money_Long_Old',
#  'Pct_of_OI_M_Money_Short_Old',
#  'Pct_of_OI_M_Money_Spread_Old',
#  'Pct_of_OI_Other_Rept_Long_Old',
#  'Pct_of_OI_Other_Rept_Short_Old',
#  'Pct_of_OI_Other_Rept_Spread_Old',
#  'Pct_of_OI_Tot_Rept_Long_Old',
#  'Pct_of_OI_Tot_Rept_Short_Old',
#  'Pct_of_OI_NonRept_Long_Old',
#  'Pct_of_OI_NonRept_Short_Old',
#  'Pct_of_Open_Interest_Other',
#  'Pct_of_OI_Prod_Merc_Long_Other',
#  'Pct_of_OI_Prod_Merc_Short_Other',
#  'Pct_of_OI_Swap_Long_Other',
#  'Pct_of_OI_Swap_Short_Other',
#  'Pct_of_OI_Swap_Spread_Other',
#  'Pct_of_OI_M_Money_Long_Other',
#  'Pct_of_OI_M_Money_Short_Other',
#  'Pct_of_OI_M_Money_Spread_Other',
#  'Pct_of_OI_Other_Rept_Long_Other',
#  'Pct_of_OI_Other_Rept_Short_Other',
#  'Pct_of_OI_Other_Rept_Spread_Other',
#  'Pct_of_OI_Tot_Rept_Long_Other',
#  'Pct_of_OI_Tot_Rept_Short_Other',
#  'Pct_of_OI_NonRept_Long_Other',
#  'Pct_of_OI_NonRept_Short_Other',
#  'Traders_Tot_All',
#  'Traders_Prod_Merc_Long_All',
#  'Traders_Prod_Merc_Short_All',
#  'Traders_Swap_Long_All',
#  'Traders_Swap_Short_All',
#  'Traders_Swap_Spread_All',
#  'Traders_M_Money_Long_All',
#  'Traders_M_Money_Short_All',
#  'Traders_M_Money_Spread_All',
#  'Traders_Other_Rept_Long_All',
#  'Traders_Other_Rept_Short_All',
#  'Traders_Other_Rept_Spread_All',
#  'Traders_Tot_Rept_Long_All',
#  'Traders_Tot_Rept_Short_All',
#  'Traders_Tot_Old',
#  'Traders_Prod_Merc_Long_Old',
#  'Traders_Prod_Merc_Short_Old',
#  'Traders_Swap_Long_Old',
#  'Traders_Swap_Short_Old',
#  'Traders_Swap_Spread_Old',
#  'Traders_M_Money_Long_Old',
#  'Traders_M_Money_Short_Old',
#  'Traders_M_Money_Spread_Old',
#  'Traders_Other_Rept_Long_Old',
#  'Traders_Other_Rept_Short_Old',
#  'Traders_Other_Rept_Spread_Old',
#  'Traders_Tot_Rept_Long_Old',
#  'Traders_Tot_Rept_Short_Old',
#  'Traders_Tot_Other',
#  'Traders_Prod_Merc_Long_Other',
#  'Traders_Prod_Merc_Short_Other',
#  'Traders_Swap_Long_Other',
#  'Traders_Swap_Short_Other',
#  'Traders_Swap_Spread_Other',
#  'Traders_M_Money_Long_Other',
#  'Traders_M_Money_Short_Other',
#  'Traders_M_Money_Spread_Other',
#  'Traders_Other_Rept_Long_Other',
#  'Traders_Other_Rept_Short_Other',
#  'Traders_Other_Rept_Spread_Other',
#  'Traders_Tot_Rept_Long_Other',
#  'Traders_Tot_Rept_Short_Other',
#  'Conc_Gross_LE_4_TDR_Long_All',
#  'Conc_Gross_LE_4_TDR_Short_All',
#  'Conc_Gross_LE_8_TDR_Long_All',
#  'Conc_Gross_LE_8_TDR_Short_All',
#  'Conc_Net_LE_4_TDR_Long_All',
#  'Conc_Net_LE_4_TDR_Short_All',
#  'Conc_Net_LE_8_TDR_Long_All',
#  'Conc_Net_LE_8_TDR_Short_All',
#  'Conc_Gross_LE_4_TDR_Long_Old',
#  'Conc_Gross_LE_4_TDR_Short_Old',
#  'Conc_Gross_LE_8_TDR_Long_Old',
#  'Conc_Gross_LE_8_TDR_Short_Old',
#  'Conc_Net_LE_4_TDR_Long_Old',
#  'Conc_Net_LE_4_TDR_Short_Old',
#  'Conc_Net_LE_8_TDR_Long_Old',
#  'Conc_Net_LE_8_TDR_Short_Old',
#  'Conc_Gross_LE_4_TDR_Long_Other',
#  'Conc_Gross_LE_4_TDR_Short_Other',
#  'Conc_Gross_LE_8_TDR_Long_Other',
#  'Conc_Gross_LE_8_TDR_Short_Other',
#  'Conc_Net_LE_4_TDR_Long_Other',
#  'Conc_Net_LE_4_TDR_Short_Other',
#  'Conc_Net_LE_8_TDR_Long_Other',
#  'Conc_Net_LE_8_TDR_Short_Other',
#  'Contract_Units',
#  'CFTC_Contract_Market_Code_Quotes',
#  'CFTC_Market_Code_Quotes',
#  'CFTC_Commodity_Code_Quotes',
#  'CFTC_SubGroup_Code',
#  'FutOnly_or_Combined']

# %%
df18.columns = csv_columns.keys()

# %%
list(df18.columns)
# Out:
# ['Market_and_Exchange_Names',
#  'As_of_Date_In_Form_YYMMDD',
#  'As_of_Date_Form_MM/DD/YYYY',
#  'CFTC_Contract_Market_Code',
#  'CFTC_Market_Code',
#  'CFTC_Region_Code',
#  'CFTC_Commodity_Code',
#  'Open_Interest_All',
#  'Prod_Merc_Positions_Long_All',
#  'Prod_Merc_Positions_Short_All',
#  'Swap_Positions_Long_All',
#  'Swap_Positions_Short_All',
#  'Swap_Positions_Spread_All',
#  'M_Money_Positions_Long_All',
#  'M_Money_Positions_Short_All',
#  'M_Money_Positions_Spread_All',
#  'Other_Rept_Positions_Long_All',
#  'Other_Rept_Positions_Short_All',
#  'Other_Rept_Positions_Spread_All',
#  'Tot_Rept_Positions_Long_All',
#  'Tot_Rept_Positions_Short_All',
#  'NonRept_Positions_Long_All',
#  'NonRept_Positions_Short_All',
#  'Open_Interest_Old',
#  'Prod_Merc_Positions_Long_Old',
#  'Prod_Merc_Positions_Short_Old',
#  'Swap_Positions_Long_Old',
#  'Swap_Positions_Short_Old',
#  'Swap_Positions_Spread_Old',
#  'M_Money_Positions_Long_Old',
#  'M_Money_Positions_Short_Old',
#  'M_Money_Positions_Spread_Old',
#  'Other_Rept_Positions_Long_Old',
#  'Other_Rept_Positions_Short_Old',
#  'Other_Rept_Positions_Spread_Old',
#  'Tot_Rept_Positions_Long_Old',
#  'Tot_Rept_Positions_Short_Old',
#  'NonRept_Positions_Long_Old',
#  'NonRept_Positions_Short_Old',
#  'Open_Interest_Other',
#  'Prod_Merc_Positions_Long_Other',
#  'Prod_Merc_Positions_Short_Other',
#  'Swap_Positions_Long_Other',
#  'Swap_Positions_Short_Other',
#  'Swap_Positions_Spread_Other',
#  'M_Money_Positions_Long_Other',
#  'M_Money_Positions_Short_Other',
#  'M_Money_Positions_Spread_Other',
#  'Other_Rept_Positions_Long_Other',
#  'Other_Rept_Positions_Short_Other',
#  'Other_Rept_Positions_Spread_Other',
#  'Tot_Rept_Positions_Long_Other',
#  'Tot_Rept_Positions_Short_Other',
#  'NonRept_Positions_Long_Other',
#  'NonRept_Positions_Short_Other',
#  'Change_in_Open_Interest_All',
#  'Change_in_Prod_Merc_Long_All',
#  'Change_in_Prod_Merc_Short_All',
#  'Change_in_Swap_Long_All',
#  'Change_in_Swap_Short_All',
#  'Change_in_Swap_Spread_All',
#  'Change_in_M_Money_Long_All',
#  'Change_in_M_Money_Short_All',
#  'Change_in_M_Money_Spread_All',
#  'Change_in_Other_Rept_Long_All',
#  'Change_in_Other_Rept_Short_All',
#  'Change_in_Other_Rept_Spread_All',
#  'Change_in_Tot_Rept_Long_All',
#  'Change_in_Tot_Rept_Short_All',
#  'Change_in_NonRept_Long_All',
#  'Change_in_NonRept_Short_All',
#  'Pct_of_Open_Interest_All',
#  'Pct_of_OI_Prod_Merc_Long_All',
#  'Pct_of_OI_Prod_Merc_Short_All',
#  'Pct_of_OI_Swap_Long_All',
#  'Pct_of_OI_Swap_Short_All',
#  'Pct_of_OI_Swap_Spread_All',
#  'Pct_of_OI_M_Money_Long_All',
#  'Pct_of_OI_M_Money_Short_All',
#  'Pct_of_OI_M_Money_Spread_All',
#  'Pct_of_OI_Other_Rept_Long_All',
#  'Pct_of_OI_Other_Rept_Short_All',
#  'Pct_of_OI_Other_Rept_Spread_All',
#  'Pct_of_OI_Tot_Rept_Long_All',
#  'Pct_of_OI_Tot_Rept_Short_All',
#  'Pct_of_OI_NonRept_Long_All',
#  'Pct_of_OI_NonRept_Short_All',
#  'Pct_of_Open_Interest_Old',
#  'Pct_of_OI_Prod_Merc_Long_Old',
#  'Pct_of_OI_Prod_Merc_Short_Old',
#  'Pct_of_OI_Swap_Long_Old',
#  'Pct_of_OI_Swap_Short_Old',
#  'Pct_of_OI_Swap_Spread_Old',
#  'Pct_of_OI_M_Money_Long_Old',
#  'Pct_of_OI_M_Money_Short_Old',
#  'Pct_of_OI_M_Money_Spread_Old',
#  'Pct_of_OI_Other_Rept_Long_Old',
#  'Pct_of_OI_Other_Rept_Short_Old',
#  'Pct_of_OI_Other_Rept_Spread_Old',
#  'Pct_of_OI_Tot_Rept_Long_Old',
#  'Pct_of_OI_Tot_Rept_Short_Old',
#  'Pct_of_OI_NonRept_Long_Old',
#  'Pct_of_OI_NonRept_Short_Old',
#  'Pct_of_Open_Interest_Other',
#  'Pct_of_OI_Prod_Merc_Long_Other',
#  'Pct_of_OI_Prod_Merc_Short_Other',
#  'Pct_of_OI_Swap_Long_Other',
#  'Pct_of_OI_Swap_Short_Other',
#  'Pct_of_OI_Swap_Spread_Other',
#  'Pct_of_OI_M_Money_Long_Other',
#  'Pct_of_OI_M_Money_Short_Other',
#  'Pct_of_OI_M_Money_Spread_Other',
#  'Pct_of_OI_Other_Rept_Long_Other',
#  'Pct_of_OI_Other_Rept_Short_Other',
#  'Pct_of_OI_Other_Rept_Spread_Other',
#  'Pct_of_OI_Tot_Rept_Long_Other',
#  'Pct_of_OI_Tot_Rept_Short_Other',
#  'Pct_of_OI_NonRept_Long_Other',
#  'Pct_of_OI_NonRept_Short_Other',
#  'Traders_Tot_All',
#  'Traders_Prod_Merc_Long_All',
#  'Traders_Prod_Merc_Short_All',
#  'Traders_Swap_Long_All',
#  'Traders_Swap_Short_All',
#  'Traders_Swap_Spread_All',
#  'Traders_M_Money_Long_All',
#  'Traders_M_Money_Short_All',
#  'Traders_M_Money_Spread_All',
#  'Traders_Other_Rept_Long_All',
#  'Traders_Other_Rept_Short_All',
#  'Traders_Other_Rept_Spread_All',
#  'Traders_Tot_Rept_Long_All',
#  'Traders_Tot_Rept_Short_All',
#  'Traders_Tot_Old',
#  'Traders_Prod_Merc_Long_Old',
#  'Traders_Prod_Merc_Short_Old',
#  'Traders_Swap_Long_Old',
#  'Traders_Swap_Short_Old',
#  'Traders_Swap_Spread_Old',
#  'Traders_M_Money_Long_Old',
#  'Traders_M_Money_Short_Old',
#  'Traders_M_Money_Spread_Old',
#  'Traders_Other_Rept_Long_Old',
#  'Traders_Other_Rept_Short_Old',
#  'Traders_Other_Rept_Spread_Old',
#  'Traders_Tot_Rept_Long_Old',
#  'Traders_Tot_Rept_Short_Old',
#  'Traders_Tot_Other',
#  'Traders_Prod_Merc_Long_Other',
#  'Traders_Prod_Merc_Short_Other',
#  'Traders_Swap_Long_Other',
#  'Traders_Swap_Short_Other',
#  'Traders_Swap_Spread_Other',
#  'Traders_M_Money_Long_Other',
#  'Traders_M_Money_Short_Other',
#  'Traders_M_Money_Spread_Other',
#  'Traders_Other_Rept_Long_Other',
#  'Traders_Other_Rept_Short_Other',
#  'Traders_Other_Rept_Spread_Other',
#  'Traders_Tot_Rept_Long_Other',
#  'Traders_Tot_Rept_Short_Other',
#  'Conc_Gross_LE_4_TDR_Long_All',
#  'Conc_Gross_LE_4_TDR_Short_All',
#  'Conc_Gross_LE_8_TDR_Long_All',
#  'Conc_Gross_LE_8_TDR_Short_All',
#  'Conc_Net_LE_4_TDR_Long_All',
#  'Conc_Net_LE_4_TDR_Short_All',
#  'Conc_Net_LE_8_TDR_Long_All',
#  'Conc_Net_LE_8_TDR_Short_All',
#  'Conc_Gross_LE_4_TDR_Long_Old',
#  'Conc_Gross_LE_4_TDR_Short_Old',
#  'Conc_Gross_LE_8_TDR_Long_Old',
#  'Conc_Gross_LE_8_TDR_Short_Old',
#  'Conc_Net_LE_4_TDR_Long_Old',
#  'Conc_Net_LE_4_TDR_Short_Old',
#  'Conc_Net_LE_8_TDR_Long_Old',
#  'Conc_Net_LE_8_TDR_Short_Old',
#  'Conc_Gross_LE_4_TDR_Long_Other',
#  'Conc_Gross_LE_4_TDR_Short_Other',
#  'Conc_Gross_LE_8_TDR_Long_Other',
#  'Conc_Gross_LE_8_TDR_Short_Other',
#  'Conc_Net_LE_4_TDR_Long_Other',
#  'Conc_Net_LE_4_TDR_Short_Other',
#  'Conc_Net_LE_8_TDR_Long_Other',
#  'Conc_Net_LE_8_TDR_Short_Other',
#  'Contract_Units',
#  'CFTC_Contract_Market_Code_Quotes',
#  'CFTC_Market_Code_Quotes',
#  'CFTC_Commodity_Code_Quotes',
#  'CFTC_SubGroup_Code',
#  'FutOnly_or_Combined']

# %%
from pathlib import Path
file = Path('/toto/tata/filename2018.csv')

file.stem[-4:]
# Out:
# '2018'

# %%
# files 2015 and 2011 apparently have different structure than others
filename = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2020.csv'

import pandas as pd
df = pd.read_csv(filename,
                 skip_blank_lines=True,
                 na_values=[' ', '#VALUE!'],
                 index_col = False,
                 header=0
                 )
print(f'nb cols 2020: {len(df.columns)}')
cols2020 = set(df.columns)

filename15 = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2015.csv'
filename11 = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2011.csv'

df15 = pd.read_csv(filename15,
                 skip_blank_lines=True,
                 na_values=[' ', '#VALUE!'],
                 index_col = False,
                 header=0
                 )

df11 = pd.read_csv(filename15,
                 skip_blank_lines=True,
                 na_values=[' ', '#VALUE!'],
                 index_col = False,
                 header=0
                 )

print(f'nb cols 2015: {len(df15.columns)}')
cols2015 = set(df15.columns)

print(f'nb cols 2011: {len(df11.columns)}')
cols2011 = set(df11.columns)
# Out:
# nb cols 2020: 191
# nb cols 2015: 191
# nb cols 2011: 191

# %%
cols2020 - cols2015
# Out:
# set()

# %%
cols2015 - cols2020
# Out:
# set()

# %%
cols2020 - cols2011
# Out:
# set()

# %%
cols2011 - cols2020
# Out:
# set()

# %%
df11.dtypes
# Out:
# Market_and_Exchange_Names            object
# As_of_Date_In_Form_YYMMDD             int64
# As_of_Date_Form_MM/DD/YYYY           object
# CFTC_Contract_Market_Code           float64
# CFTC_Market_Code                     object
#                                      ...
# CFTC_Contract_Market_Code_Quotes    float64
# CFTC_Market_Code_Quotes             float64
# CFTC_Commodity_Code_Quotes          float64
# CFTC_SubGroup_Code                  float64
# FutOnly_or_Combined                  object
# Length: 191, dtype: object

# %%
[col for col in cols2020 if 'Swap' in col]
# Out:
# ['Traders_Swap_Short_All',
#  'Pct_of_OI_Swap_Short_All',
#  'Pct_of_OI_Swap_Spread_Other',
#  'Traders_Swap_Spread_Other',
#  'Swap__Positions_Short_All',
#  'Swap__Positions_Short_Old',
#  'Pct_of_OI_Swap_Spread_Old',
#  'Swap_Positions_Long_All',
#  'Traders_Swap_Short_Old',
#  'Traders_Swap_Spread_All',
#  'Swap__Positions_Spread_All',
#  'Change_in_Swap_Spread_All',
#  'Pct_of_OI_Swap_Long_Other',
#  'Pct_of_OI_Swap_Long_Old',
#  'Traders_Swap_Long_Other',
#  'Traders_Swap_Long_Old',
#  'Pct_of_OI_Swap_Long_All',
#  'Swap_Positions_Long_Old',
#  'Traders_Swap_Long_All',
#  'Change_in_Swap_Short_All',
#  'Swap__Positions_Spread_Other',
#  'Swap__Positions_Short_Other',
#  'Swap_Positions_Long_Other',
#  'Swap__Positions_Spread_Old',
#  'Pct_of_OI_Swap_Spread_All',
#  'Change_in_Swap_Long_All',
#  'Traders_Swap_Short_Other',
#  'Pct_of_OI_Swap_Short_Old',
#  'Pct_of_OI_Swap_Short_Other',
#  'Traders_Swap_Spread_Old']

# %%
list(csv_columns)[86:87]
# Out:
# ['Pct_of_OI_NonRept_Short_All']

# %% [markdown]
# # Compare files CFTC x ICE
#
# Let's compare file schemas.

# %%
filename = r'C:\Users\ROSA_L\PycharmProjects\scraper\filestore\com_theice_COTHist2021.csv'

import pandas as pd
df = pd.read_csv(filename,
                 skip_blank_lines=True,
                 na_values=[' ', '#VALUE!'],
                 index_col = False,
                 header=0
                 )

file_cftc = r'C:\Users\ROSA_L\Downloads\f_year.xls'
df_cftc = pd.read_excel(file_cftc, engine='xlrd')

# %%
ice_cols = set(df.columns)
cftc_cols = set(df_cftc.columns)

print(f'lenght ice: {len(ice_cols)}')
print(f'lenght cftc: {len(cftc_cols)}')

print(f'ice - cftc: {sorted(ice_cols - cftc_cols)}')
print('\n')
print(f'cftc - ice: {sorted(cftc_cols - ice_cols)}')
# Out:
# lenght ice: 191
# lenght cftc: 188
# ice - cftc: ['As_of_Date_Form_MM/DD/YYYY', 'CFTC_Commodity_Code_Quotes', 'CFTC_Contract_Market_Code_Quotes', 'CFTC_Market_Code_Quotes', 'M_Money_Positions_Long_All', 'M_Money_Positions_Short_All', 'M_Money_Positions_Spread_All', 'Other_Rept_Positions_Long_All', 'Other_Rept_Positions_Short_All', 'Other_Rept_Positions_Spread_All', 'Other_Rept_Positions_Spread_Other', 'Pct_of_OI_Other_Rept_Spread_Other', 'Prod_Merc_Positions_Long_All', 'Prod_Merc_Positions_Short_All', 'Swap_Positions_Short_All', 'Swap_Positions_Spread_All']
#
#
# cftc - ice: ['M_Money_Positions_Long_ALL', 'M_Money_Positions_Short_ALL', 'M_Money_Positions_Spread_ALL', 'Other_Rept_Positions_Long_ALL', 'Other_Rept_Positions_Short_ALL', 'Other_Rept_Positions_Spread_ALL', 'Other_Rept_Positions_Spread_Othr', 'Pct_of_OI_Other_Rept_Spread_Othr', 'Prod_Merc_Positions_Long_ALL', 'Prod_Merc_Positions_Short_ALL', 'Report_Date_as_MM_DD_YYYY', 'Swap__Positions_Short_All', 'Swap__Positions_Spread_All']

# %%
cftc_ice_mapping = {'M_Money_Positions_Long_ALL': 'M_Money_Positions_Long_All', 
                    'M_Money_Positions_Short_ALL': 'M_Money_Positions_Short_All', 
                    'M_Money_Positions_Spread_ALL': 'M_Money_Positions_Spread_All', 
                    'Other_Rept_Positions_Long_ALL': 'Other_Rept_Positions_Long_All', 
                    'Other_Rept_Positions_Short_ALL': 'Other_Rept_Positions_Short_All', 
                    'Other_Rept_Positions_Spread_ALL': 'Other_Rept_Positions_Spread_All', 
                    'Other_Rept_Positions_Spread_Othr': 'Other_Rept_Positions_Spread_Other', 
                    'Pct_of_OI_Other_Rept_Spread_Othr': 'Pct_of_OI_Other_Rept_Spread_Other', 
                    'Prod_Merc_Positions_Long_ALL': 'Prod_Merc_Positions_Long_All', 
                    'Prod_Merc_Positions_Short_ALL': 'Prod_Merc_Positions_Short_All', 
                    #'Report_Date_as_MM_DD_YYYY': 'As_of_Date_In_Form_YYMMDD', 
                    'Swap__Positions_Short_All': 'Swap_Positions_Short_All', 
                    'Swap__Positions_Spread_All': 'Swap_Positions_Spread_All'}

df_cftc.rename(columns=cftc_ice_mapping, inplace=True)

ice_cols = set(df.columns)
cftc_cols = set(df_cftc.columns)

print(f'ice - cftc: {sorted(ice_cols - cftc_cols)}')
print('\n')
print(f'cftc - ice: {sorted(cftc_cols - ice_cols)}')
# Out:
# ice - cftc: ['As_of_Date_Form_MM/DD/YYYY', 'CFTC_Commodity_Code_Quotes', 'CFTC_Contract_Market_Code_Quotes', 'CFTC_Market_Code_Quotes']
#
#
# cftc - ice: ['Report_Date_as_MM_DD_YYYY']

# %%
display(df[['As_of_Date_Form_MM/DD/YYYY', 'As_of_Date_In_Form_YYMMDD']])
display(df_cftc[['Report_Date_as_MM_DD_YYYY', 'As_of_Date_In_Form_YYMMDD']])
# Out:
#     As_of_Date_Form_MM/DD/YYYY  As_of_Date_In_Form_YYMMDD
# 0                   01-05-2021                     210105
# 1                   01-05-2021                     210105
# 2                   01-05-2021                     210105
# 3                   01-05-2021                     210105
# 4                   01-05-2021                     210105
# ..                         ...                        ...
# 127                 03/16/2021                     210316
# 128                 03/16/2021                     210316
# 129                 03/16/2021                     210316
# 130                 03/16/2021                     210316
# 131                 03/16/2021                     210316
#
# [132 rows x 2 columns]
#      Report_Date_as_MM_DD_YYYY  As_of_Date_In_Form_YYMMDD
# 0                   2021-03-16                     210316
# 1                   2021-03-09                     210309
# 2                   2021-03-02                     210302
# 3                   2021-02-23                     210223
# 4                   2021-02-16                     210216
# ...                        ...                        ...
# 2173                2021-02-02                     210202
# 2174                2021-01-26                     210126
# 2175                2021-01-19                     210119
# 2176                2021-01-12                     210112
# 2177                2021-01-05                     210105
#
# [2178 rows x 2 columns]

# %%
job.data[['Week_of_Release','Swap_Positions_Short_All']]
# Out:
#     Week_of_Release  Swap_Positions_Short_All
# 0        2021-05-01                      1595
# 1        2021-05-01                      1595
# 2        2021-05-01                     77920
# 3        2021-05-01                     88603
# 4        2021-05-01                      3076
# ..              ...                       ...
# 203      2011-12-20                    117776
# 204      2011-12-27                     17182
# 205      2011-12-27                     17283
# 206      2011-12-27                    112657
# 207      2011-12-27                    113600
#
# [4824 rows x 2 columns]
