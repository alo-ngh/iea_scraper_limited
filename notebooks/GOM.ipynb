# %%
# %load_ext autoreload
# %autoreload 2

# %%
from scraper.jobs.gov_bsee.job import OGORAJob
from scraper.core.utils import logger
import logging
logger.level = logging.DEBUG

# %%
gom = OGORAJob(full_load=True)

# %%
from scraper.jobs.gov_bsee.entity import GOMFieldsJob
from scraper.core.dimension import Updater
gom_upd = Updater(GOMFieldsJob, 'entity')

# %%
gom_upd.run()
# Out:
# 2019-05-07 16:52:20,493 - scraper.core.utils - DEBUG: Entering get_sources()
# 2019-05-07 16:52:20,494 - scraper.core.utils - DEBUG: Appending one source to sources: {'code': 'gov_bsee_deepqualfields', 'url': 'https://www.data.bsee.gov/Other/DataTables/DeepQualFields.aspx', 'path': 'gov_bsee_deepqualfields.csv', 'long_name': 'USA GOV_BSEE Deepwater Natural Gas and Oil Qualified Fields'}
# 2019-05-07 16:52:20,494 - scraper.core.utils - DEBUG: dynamic_dim["source"] after removing existing: [{'code': 'gov_bsee_deepqualfields', 'url': 'https://www.data.bsee.gov/Other/DataTables/DeepQualFields.aspx', 'path': 'gov_bsee_deepqualfields.csv', 'long_name': 'USA GOV_BSEE Deepwater Natural Gas and Oil Qualified Fields'}]
# 2019-05-07 16:52:20,496 - scraper.core.utils - DEBUG: Going to URL: https://www.data.bsee.gov/Other/DataTables/DeepQualFields.aspx
# 2019-05-07 16:52:24,217 - scraper.core.utils - DEBUG: Clicking CSV button and waiting 5s
# ...

# %%
entity_df = df[['entity']].drop_duplicates()
entity_df
# Out:
#           entity
# 0          AC024
# 1          AC025
# 2          AC857
# 3          AC859
# 4         BA105A
# 5         BA133A
# 6          BA491
# 7          BM002
# 8          BS025
# 9          CA043
# 10         DC004
# 11         DC134
# 12         DD056
# 13         EB157
# 14         EB158
# 15         EB160
# 16         EB165
# 17         EB205
# 18         EB430
# 19         EB597
# 20         EB602
# 21         EB642
# 22         EB643
# 23         EB949
# 24         EC014
# 25         EC046
# 26         EC064
# 27         EC071
# 28         EC265
# 29         EC271
# ...          ...
# 193135  WLDAC200
# 195138     GC463
# 199517     HI108
# 199535    HI200A
# 199542    HI274A
# 199737     MU756
# 199762    PN072A
# 199763     PN967
# 199893     ST241
# 200071     WC592
# 204693    HI402A
# 207828  WLDEB301
# 209589     BA507
# 209591     BA538
# 209703     EI283
# 209750     GA320
# 209752     GA330
# 209795     GC691
# 209818     HI093
# 209830     HI164
# ...

# %%
df_entity = pd.read_csv('C:\\Users\\ROSA_L\\PycharmProjects\\scrapper\\filestore\\gov_bsee_deepqualfields.csv')

# %%
df_entity['Field Name Code']
# Out:
# 0      MC113
# 1      MC068
# 2      VK862
# 3      VK862
# 4      MC285
# 5      GC021
# 6      GC029
# 7      GC039
# 8      GC070
# 9      GC029
# 10     MC455
# 11     MC709
# 12     MC709
# 13     MC929
# 14     GC075
# 15     GC075
# 16     GC147
# 17     GC162
# 18     AT001
# 19     EB377
# 20     GB379
# 21     GB208
# 22     PI525
# 23     GC463
# 24     VK862
# 25     MC068
# 26     GC039
# 27     GB873
# 28     MC161
# 29     MC285
#        ...
# 594    GC768
# 595    AC818
# 596    GC195
# 597    MC555
# 598    AC859
# 599    AC859
# 600    GC244
# 601    GC244
# 602    GC244
# 603    GC244
# 604    GC244
# 605    MC699
# 606    MC682
# 607    MC682
# 608    MC682
# 609    MC682
# 610    MC682
# 611    MC707
# 612    MC393
# 613    VK823
# 614    VK823
# 615    MC940
# 616    MC940
# 617    AT261
# 618    GC490
# 619    MC506
# 620    MC354
# 621    MC354
# 622    MC354
# 623    MC354
# Name: Field Name Code, Length: 624, dtype: object

# %%
a = set(df.entity.unique())
b = set(df_entity['Field Name Code'])
result = a - b
print(f'a: {len(a)} b: {len(b)} result: {len(result)}')
len(df)
# Out:
# a: 1364 b: 260 result: 1121
# 219607

# %%
gom.run(download=True)
# Out:
# 2019-05-07 16:46:29,188 - scraper.core.utils - DEBUG: Running entity job first.
# 2019-05-07 16:46:29,189 - scraper.core.utils - DEBUG: Entering get_sources()
# 2019-05-07 16:46:29,190 - scraper.core.utils - DEBUG: Appending one source to sources: {'code': 'gov_bsee_deepqualfields', 'url': 'https://www.data.bsee.gov/Other/DataTables/DeepQualFields.aspx', 'path': 'gov_bsee_deepqualfields.csv', 'long_name': 'USA GOV_BSEE Deepwater Natural Gas and Oil Qualified Fields'}
# 2019-05-07 16:46:29,381 - scraper.core.utils - DEBUG: dynamic_dim["source"] after removing existing: []
# 2019-05-07 16:46:29,382 - scraper.core.utils - DEBUG: Going to URL: https://www.data.bsee.gov/Other/DataTables/DeepQualFields.aspx
# 2019-05-07 16:46:32,904 - scraper.core.utils - DEBUG: Clicking CSV button and waiting 5s
# 2019-05-07 16:46:39,024 - scraper.core.utils - DEBUG: renaming file C:\Users\ROSA_L\PycharmProjects\scrapper\filestore\DeepQualFields.csv into gov_bsee_deepqualfields.csv
# ...

# %%
[x['source'] for x in gom.data]
# Out:
# ['GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
#  'GOV_BSEE_OGOR-A',
# ...

# %%
gom = None

# %%
from scraper.jobs.gov_bsee import entity
gomfields = entity.GOMFieldsJob()

# %%
gomfields.run(download=False)
# Out:
# 2019-05-03 17:18:20,510 - scraper.core.utils - DEBUG: Entering get_sources()
# 2019-05-03 17:18:20,510 - scraper.core.utils - DEBUG: Appending one source to sources: {'code': 'gov_bsee_deepqualfields', 'url': 'https://www.data.bsee.gov/Other/DataTables/DeepQualFields.aspx', 'path': 'gov_bsee_deepqualfields.csv', 'long_name': 'USA GOV_BSEE Deepwater Natural Gas and Oil Qualified Fields'}
# 2019-05-03 17:18:20,665 - scraper.core.utils - INFO: download_and_get_checksum: 0.0 ms
# 2019-05-03 17:18:20,691 - scraper.core.utils - INFO: rm_sources_up_to_date: 25.23970603942871 ms
# 2019-05-03 17:18:20,692 - scraper.core.utils - DEBUG: Transforming data...
# 2019-05-03 17:18:20,692 - scraper.core.utils - INFO: insert_new_dynamic_dim: 0.0 ms
# 2019-05-03 17:18:20,693 - scraper.core.utils - INFO: upsert: 0.0 ms
# 2019-05-03 17:18:20,693 - scraper.core.utils - INFO: update_sources_metadata: 0.0 ms

# %%
gomfields = None
