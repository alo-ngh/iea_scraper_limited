# %%
import pandas as pd
from sqlalchemy import create_engine

OCB_STR = "mssql+pyodbc://omr_reader:SU4bJSXAL8Zwyh0hV6z8@vihexa/ocb?driver=ODBC+Driver+13+for+SQL+Server"

print(OCB_STR)

engine = create_engine(
    OCB_STR,
    fast_executemany=True)

sql = "select * from demand_alchemy.v_demand_fact where frequency='yearly' and time_fk=2019"

df = pd.read_sql(sql, engine)

df
# Out:
# mssql+pyodbc://omr_reader:SU4bJSXAL8Zwyh0hV6z8@vihexa/ocb?driver=ODBC+Driver+13+for+SQL+Server
#       country_fk country_code  product_fk product_code  sector_fk sector_code  \
# 0              1          UAE           2     TOTPRODS          1         ALL
# 1              2      ALBANIA           2     TOTPRODS          1         ALL
# 2              3      ARMENIA           2     TOTPRODS          1         ALL
# 3              4       ANGOLA           2     TOTPRODS          1         ALL
# 4              5    ARGENTINA           2     TOTPRODS          1         ALL
# 5              6      AUSTRIA           2     TOTPRODS          1         ALL
# 6              7     AUSTRALI           2     TOTPRODS          1         ALL
# 7              8   AZERBAIJAN           2     TOTPRODS          1         ALL
# 8              9   BOSNIAHERZ           2     TOTPRODS          1         ALL
# 9             10   BANGLADESH           2     TOTPRODS          1         ALL
# ...
