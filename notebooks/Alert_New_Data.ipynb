# %% [markdown]
# # Alert new data
#
# New functionality to send an e-mail when new data is detected.
#
# ## Expected flow
#
# 1. get sources from external-db
# 1. filter sources if date_created or date_modified is today

# %%
import requests

#API_END_POINT = "http://vipenta:8000"
API_END_POINT = "http://vihexa:8000"
dimension = 'source'
r = requests.get(f"{API_END_POINT}/dimension/{dimension}")
data = r.json()

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                             checksum  \
# 0                                               None
# 1  e58e5d09150132aba6382944d87f2540              ...
# 2  4342825dcd97023c969a8561b9b1c213              ...
# 3  e48e4ec5c2fce7ded5239df898870f3a              ...
# 4  715d1f79d1d57b2df89699741ecb7082              ...
#
#                            code                      date_created  \
# 0                          None  2019-04-05T14:15:06.330000+00:00
# 1    org_jodidata_world_primary  2019-04-12T10:43:21.737000+00:00
# 2  org_jodidata_world_secondary  2019-04-12T10:43:21.813000+00:00
# 3  mx_gob_cnh_PRODUCCION_CAMPOS  2019-04-15T14:45:53.507000+00:00
# 4  mx_gob_cnh_PRODUCCION_CUENCA  2019-04-15T14:45:53.567000+00:00
#
#                       date_modified  id              last_download  \
# 0  2019-04-05T14:15:06.330000+00:00   0                       None
# 1  2019-04-24T11:25:39.987000+00:00   1  2019-04-24T11:11:14+00:00
# ...

# %%
from datetime import date

for x in ['date_created', 'date_modified', 'last_download', 'last_update']:
    df[x] = pd.to_datetime(df[x], infer_datetime_format=True)

df.head()
# Out:
#                                             checksum  \
# 0                                               None
# 1  e58e5d09150132aba6382944d87f2540              ...
# 2  4342825dcd97023c969a8561b9b1c213              ...
# 3  e48e4ec5c2fce7ded5239df898870f3a              ...
# 4  715d1f79d1d57b2df89699741ecb7082              ...
#
#                            code            date_created  \
# 0                          None 2019-04-05 14:15:06.330
# 1    org_jodidata_world_primary 2019-04-12 10:43:21.737
# 2  org_jodidata_world_secondary 2019-04-12 10:43:21.813
# 3  mx_gob_cnh_PRODUCCION_CAMPOS 2019-04-15 14:45:53.507
# 4  mx_gob_cnh_PRODUCCION_CUENCA 2019-04-15 14:45:53.567
#
#             date_modified  id       last_download         last_update  \
# 0 2019-04-05 14:15:06.330   0                 NaT                 NaT
# 1 2019-04-24 11:25:39.987   1 2019-04-24 11:11:14 2019-04-24 11:26:04
# 2 2019-04-24 11:25:40.033   2 2019-04-24 11:11:17 2019-04-24 11:26:04
# ...

# %%
today = pd.to_datetime('today').normalize()
df[(df['code'] == 'com_argusmedia_ru_ref_output') & (df['last_update'] >=  today) | (df['date_modified'] >= today) | (df['date_created'] >= today)]
# Out:
# Empty DataFrame
# Columns: [checksum, code, date_created, date_modified, id, last_download, last_update, long_name, meta_data, path, schedule, url]
# Index: []

# %%
pd.set_option('colheader_justify', 'center')
table = df[['long_name', 'path']].rename(columns={'long_name': 'source', 'path': 'file'}).head().to_html(index=False)

html = """
<html>
<head>
<style>
table {
  border-collapse: collapse;
}

table, th, td {
  border: 1px solid black;
}       
</style>
</head>
<body>
""" 
html += table
html += """
</body>
</html>
"""


print(html)
# Out:
# <html>
# <head>
# <style>
# table {
#   border-collapse: collapse;
# }
#
# table, th, td {
#   border: 1px solid black;
# }
# </style>
# </head>
# <body>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>source</th>
#       <th>file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>JODI WORLD OIL Primary</td>
#       <td>org_jodidata_world_primary_csv.zip</td>
#     </tr>
#     <tr>
#       <td>JODI WORLD OIL Secondary</td>
#       <td>org_jodidata_world_secondary_csv.zip</td>
#     </tr>
#     <tr>
#       <td>MEXICO CNH OIL PRODUCTION Campos</td>
#       <td>mx_gob_cnh_PRODUCCION_CAMPOS.zip</td>
#     </tr>
#     <tr>
#       <td>MEXICO CNH OIL PRODUCTION Cuenca</td>
#       <td>mx_gob_cnh_PRODUCCION_CUENCA.zip</td>
#     </tr>
#   </tbody>
# </table>
# </body>
# </html>

# %%
table = df[['long_name', 'path']].rename(columns={'long_name': 'source', 'path': 'file'}).head().to_string(index=False)
message = f"Dear OMR Analyst,\n\nNew data was loaded today into External-DB database from the following sources: \n\n {table}\n\nRegards, \n\nOMR data scraper"

print(message)
# Out:
# Dear OMR Analyst,
#
# New data was loaded today into External-DB database from the following sources:
#
#  source                               file
#                             None                                  None
#           JODI WORLD OIL Primary    org_jodidata_world_primary_csv.zip
#         JODI WORLD OIL Secondary  org_jodidata_world_secondary_csv.zip
# MEXICO CNH OIL PRODUCTION Campos      mx_gob_cnh_PRODUCCION_CAMPOS.zip
# MEXICO CNH OIL PRODUCTION Cuenca      mx_gob_cnh_PRODUCCION_CUENCA.zip
#
# Regards,
#
# OMR data scraper

# %%
from scraper.core.utils import logger
import logging
logger.level = logging.DEBUG
from daily_master import alert_upon_new_data
alert_upon_new_data()
# Out:
# 2019-05-21 11:31:40,582 - scraper.core.utils - DEBUG: len(df): 0

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df
# Out:
#                          checksum                       \
# 0                                                 None
# 1    e58e5d09150132aba6382944d87f2540              ...
# 2    4342825dcd97023c969a8561b9b1c213              ...
# 3    e48e4ec5c2fce7ded5239df898870f3a              ...
# 4    715d1f79d1d57b2df89699741ecb7082              ...
# 5    55a612ee5b472976081d874873539260              ...
# 6    413356021a0295ca80dcd96f3be6b070              ...
# 7    66247fe7f629bd88a3434ccc468a0f6f              ...
# 8    3da5b327b9e80a2d5bf4bb08b005142e              ...
# 9    04fc1d01430db8ada62e9afd5282700e              ...
# 10   7a4841427ecdd9b365f817cbddcad5bc              ...
# 11   099ea658514bcf96678296e4848c5c6c              ...
# 12   543ef2f9e7569f02fd695d24a7ed94fd              ...
# 13   f582a757df91d5cb43c3a02b87bf3fd0              ...
# 14   46bafc43e08ef0286ea5dd5921b0c7d2              ...
# 15   c3487cb3137c6ce2927a73a289fea567              ...
# ...

# %%
import pymssql

str = 'mssql+pymssql://extdb_worker:ErjCYNXMkgyORaydxV6B@vimars/IEA_External-DB'
#user_info, server_info = str.split('//')[1].split('@')
#user, password = user_info.split(':')
#server, database = server_info.split('/')

#conn = pymssql.connect(server, user, password, database)

from sqlalchemy import create_engine
conn = create_engine(str)

# %%
stmt = """select s.long_name as [source], d.period_fk as [period], d.[affected rows]
    from 
    (select source_fk, period_fk, count(*) [affected rows]
     from main.FACT_datapoint
     where date_created > Cast(GetDate() AS date) 
        or date_modified > Cast(GetDate() AS date)
     group by source_fk, period_fk) d
    inner join dimension.LU_source s
    on s.id = d.source_fk
    where s.code in ('com_argusmedia_ru_ref_output')
    order by 2 desc
"""
df = pd.read_sql(stmt,conn)

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-8dd0cd799055> in <module>()
# ----> 1 conn.close()
#
# AttributeError: 'Engine' object has no attribute 'close'

# %%
result = df.to_string(index=False)
print(result)
# Out:
# Empty DataFrame
# Columns: [source, period, affected rows]
# Index: []

# %%
# Send an HTML email with an embedded image and a plain text message for
# email clients that don't want to display the HTML.
import scraper.settings as settings


from email.MIMEMultipart import MIMEMultipart
from email.MIMEText import MIMEText
from email.MIMEImage import MIMEImage

# Define these once; use them twice!
strFrom = settings.MAIL_DEFAULT_SENDER
strTo = 'LuisFernando.ROSA@iea.org'

# Create the root message and fill in the from, to, and subject headers
msgRoot = MIMEMultipart('related')
msgRoot['Subject'] = 'test message'
msgRoot['From'] = strFrom
msgRoot['To'] = strTo
msgRoot.preamble = 'This is a multi-part message in MIME format.'

# Encapsulate the plain and HTML versions of the message body in an
# 'alternative' part, so message agents can decide which they want to display.
msgAlternative = MIMEMultipart('alternative')
msgRoot.attach(msgAlternative)

msgText = MIMEText('This is the alternative plain text message.')
msgAlternative.attach(msgText)

# We reference the image in the IMG SRC attribute by the ID we give it below
msgText = MIMEText('<b>Some <i>HTML</i> text</b> and an image.<br><img src="cid:image1"><br>Nifty!', 'html')
msgAlternative.attach(msgText)

# This example assumes the image is in the current directory
fp = open('test.jpg', 'rb')
msgImage = MIMEImage(fp.read())
fp.close()

# Define the image's ID as referenced above
msgImage.add_header('Content-ID', '<image1>')
msgRoot.attach(msgImage)

# Send the email (this example assumes SMTP authentication is required)
import smtplib
smtp = smtplib.SMTP()
smtp.connect(settings.MAIL_SERVER)
#smtp.login('exampleuser', 'examplepass')
smtp.sendmail(strFrom, strTo, msgRoot.as_string())

smtp.quit()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-174-40027744cc37> in <module>()
#       4
#       5
# ----> 6 from email.MIMEMultipart import MIMEMultipart
#       7 from email.MIMEText import MIMEText
#       8 from email.MIMEImage import MIMEImage
#
# ModuleNotFoundError: No module named 'email.MIMEMultipart'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scraper.settings import LOGGING_DAILY, ROOT_PATH
import logging
import logging.config


print(LOGGING_DAILY)

logging.config.dictConfig(LOGGING_DAILY)
logger = logging.getLogger(__name__)

logger.info("info test")
logger.debug("debug test")
# Out:
# info test
# {'version': 1, 'formatters': {'default': {'format': '%(asctime)s - %(name)s - %(levelname)s: %(message)s'}}, 'handlers': {'console': {'class': 'logging.StreamHandler'}, 'file': {'class': 'logging.handlers.TimedRotatingFileHandler', 'formatter': 'default', 'filename': WindowsPath('C:/Users/ROSA_L/PycharmProjects/scrapper/logs/daily_master.log'), 'when': 'D', 'backupCount': 5}}, 'root': {'level': 'INFO', 'handlers': ['console', 'file']}}

# %%
log_path = ROOT_PATH / 'logs' / 'daily_master.log'

# %%
logger.info(log_path)
logger.info(LOGGING_DAILY)
# Out:
# C:\Users\ROSA_L\PycharmProjects\scrapper\logs\daily_master.log
# {'version': 1, 'formatters': {'default': {'format': '%(asctime)s - %(name)s - %(levelname)s: %(message)s'}}, 'handlers': {'console': {'class': 'logging.StreamHandler'}, 'file': {'class': 'logging.handlers.TimedRotatingFileHandler', 'formatter': 'default', 'filename': WindowsPath('C:/Users/ROSA_L/PycharmProjects/scrapper/logs/daily_master.log'), 'when': 'D', 'backupCount': 5}}, 'root': {'level': 'INFO', 'handlers': ['console', 'file']}}

# %%
import daily_master as d
d.main()
# Out:
# 0 items ([]...) inserted to http://vipenta:8000/dimension/entity
# 0 items ([]...) inserted to http://vipenta:8000/main/datapoint
# 0 items ([]...) inserted to http://vipenta:8000/dimension/detail
# c:\users\rosa_l\pycharmprojects\scrapper\venv\lib\site-packages\urllib3\connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 0 items ([]...) inserted to http://vipenta:8000/main/datapoint
# 0 items ([]...) inserted to http://vipenta:8000/main/datapoint
# 0 items ([]...) inserted to http://vipenta:8000/main/datapoint

# %%
import weekly_master as d
d.main()
# Out:
# 0 items ([]...) inserted to http://vipenta:8000/main/datapoint
