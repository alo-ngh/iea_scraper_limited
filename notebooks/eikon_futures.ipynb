# %%
import pandas as pd
import numpy as np
import eikon as ek
import time

app_display_name = 'IEA_DATA_SCRAPER'
product_id = 'OECD.IEADATASCRAPER'
app_key = '0b32d069a93849488b1f24f70342382cf1e26523'
ek.set_app_key(app_key)

# %%
import sys
sys.version
# Out:
# '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:15:42) [MSC v.1916 64 bit (AMD64)]'

# %%
list_of_contracts = ['CLc2', 'CLc3',
                     'CLc4', 'CLc5',
                     'CLc6', 'CLc7',
                     'CLc8', 'CLc9',
                     'CLc10', 'CLc11',
                     'CLc12', 'HOc1',
                     'HOc2', 'HOc3',
                     'HOc4', 'HOc5',
                     'HOc6', 'HOc7',
                     'HOc8', 'HOc9',
                     'HOc10', 'HOc11',
                     'HOc12', 'NGc1',
                     'NGc2', 'NGc3',
                     'NGc4', 'NGc5', 
                     'NGc6', 'NGc7',
                     'NGc8', 'NGc9',
                     'NGc10', 'NGc11',
                     'NGc12', 'LCOc1',
                     'LCOc2', 'LCOc3', 
                     'LCOc4', 'LCOc5', 
                     'LCOc6', 'LCOc7', 
                     'LCOc8', 'LCOc9', 
                     'LCOc10', 'LCOc11',
                     'LCOc12', 'LGOc1',
                     'LGOc2', 'LGOc3', 
                     'LGOc4', 'LGOc5', 
                     'LGOc6', 'LGOc7', 
                     'LGOc8', 'LGOc9', 
                     'LGOc10', 'LGOc11', 
                     'LGOc12', 'RBc1',
                     'RBc2', 'RBc3', 
                     'RBc4', 'RBc5', 
                     'RBc6', 'RBc7', 
                     'RBc8', 'RBc9', 
                     'RBc10', 'RBc11', 
                     'RBc12', 'RBc1',
                     'RBc2', 'RBc3', 
                     'RBc4', 'RBc5', 
                     'RBc6', 'RBc7', 
                     'RBc8', 'RBc9', 
                     'RBc10', 'RBc11', 
                     'RBc12', 'WTCLc1', 
                     'WTCLc2', 'WTCLc3', 
                     'CLc1', 'CLc2', 
                     'CLc3', 'CLc4', 
                     'CLc5', 'CLc6', 
                     'CLc7', 'CLc8', 
                     'CLc9', 'CLc10', 
                     'CLc11', 'CLc12',
                     'CLc13', 'CLc14', 
                     'CLc15', 'CLc16', 
                     'CLc17', 'CLc18', 
                     'CLc19', 'CLc20', 
                     'CLc21', 'CLc22', 
                     'CLc23', 'CLc24',
                     'CLc25', 'CLc26', 
                     'CLc27', 'CLc28', 
                     'CLc29', 'CLc30', 
                     'CLc31', 'CLc32',
                     'CLc33', 'CLc34', 
                     'CLc35', 'CLc36',
                     'CLc37', 'CLc38', 
                     'CLc39', 'CLc40', 
                     'CLc41', 'CLc42', 
                     'CLc43', 'CLc44', 
                     'CLc45', 'CLc46', 
                     'CLc47', 'CLc48',
                     'CLc49', 'CLc50', 
                     'CLc51', 'CLc52', 
                     'CLc53', 'CLc54', 
                     'CLc55', 'CLc56', 
                     'CLc57', 'CLc58', 
                     'CLc59', 'CLc60',
                     'CLc61', 'CLc62', 
                     'CLc63', 'CLc64', 
                     'CLc65', 'CLc66', 
                     'CLc67', 'CLc68', 
                     'CLc69', 'CLc70', 
                     'CLc71', 'CLc72',
                     'CLc73', 'CLc74', 
                     'CLc75', 'CLc76', 
                     'CLc77', 'CLc78',
                     'LCOc1', 'LCOc2', 
                     'LCOc3', 'LCOc4', 
                     'LCOc5', 'LCOc6', 
                     'LCOc7', 'LCOc8', 
                     'LCOc9', 'LCOc10', 
                     'LCOc11', 'LCOc12',
                     'LCOc13', 'LCOc14', 
                     'LCOc15', 'LCOc16', 
                     'LCOc17', 'LCOc18', 
                     'LCOc19', 'LCOc20', 
                     'LCOc21', 'LCOc22', 
                     'LCOc23', 'LCOc24',
                     'LCOc25', 'LCOc26', 
                     'LCOc27', 'LCOc28', 
                     'LCOc29', 'LCOc30', 
                     'LCOc31', 'LCOc32',
                     'LCOc33', 'LCOc34', 
                     'LCOc35', 'LCOc36']

list_of_contract_names = ['NymexWTI_M2', 'NymexWTI_M3',
                          'NymexWTI_M4', 'NymexWTI_M5',
                          'NymexWTI_M6', 'NymexWTI_M7',
                          'NymexWTI_M8', 'NymexWTI_M9',
                          'NymexWTI_M10', 'NymexWTI_M11', 
                          'NymexWTI_M12', 'NymexULSD_M1', 
                          'NymexULSD_M2', 'NymexULSD_M3',
                          'NymexULSD_M4', 'NymexULSD_M5',
                          'NymexULSD_M6', 'NymexULSD_M7',
                          'NymexULSD_M8', 'NymexULSD_M9',
                          'NymexULSD_M10', 'NymexULSD_M11', 
                          'NymexULSD_M12', 'NymexHenryHubNatGas_M1', 
                          'NymexHenryHubNatGas_M2', 'NymexHenryHubNatGas_M3',
                          'NymexHenryHubNatGas_M4', 'NymexHenryHubNatGas_M5',
                          'NymexHenryHubNatGas_M6', 'NymexHenryHubNatGas_M7',
                          'NymexHenryHubNatGas_M8', 'NymexHenryHubNatGas_M9',
                          'NymexHenryHubNatGas_M10', 'NymexHenryHubNatGas_M11', 
                          'NymexHenryHubNatGas_M12', 'ICEBrent_M1', 
                          'ICEBrent_M2', 'ICEBrent_M3',
                          'ICEBrent_M4', 'ICEBrent_M5',
                          'ICEBrent_M6', 'ICEBrent_M7',
                          'ICEBrent_M8', 'ICEBrent_M9',
                          'ICEBrent_M10', 'ICEBrent_M11', 
                          'ICEBrent_M12', 'ICELSGasoil_M1', 
                          'ICELSGasoil_M2', 'ICELSGasoil_M3',
                          'ICELSGasoil_M4', 'ICELSGasoil_M5',
                          'ICELSGasoil_M6', 'ICELSGasoil_M7',
                          'ICELSGasoil_M8', 'ICELSGasoil_M9',
                          'ICELSGasoil_M10', 'ICELSGasoil_M11', 
                          'ICELSGasoil_M12', 'NymexRBOB_M1', 
                          'NymexRBOB_M2', 'NymexRBOB_M3',
                          'NymexRBOB_M4', 'NymexRBOB_M5',
                          'NymexRBOB_M6', 'NymexRBOB_M7',
                          'NymexRBOB_M8', 'NymexRBOB_M9',
                          'NymexRBOB_M10', 'NymexRBOB_M11', 
                          'NymexRBOB_M12', 'NymexRBOBPit_M1', 
                          'NymexRBOBPit_M2', 'NymexRBOBPit_M3',
                          'NymexRBOBPit_M4', 'NymexRBOBPit_M5',
                          'NymexRBOBPit_M6', 'NymexRBOBPit_M7',
                          'NymexRBOBPit_M8', 'NymexRBOBPit_M9',
                          'NymexRBOBPit_M10', 'NymexRBOBPit_M11', 
                          'NymexRBOBPit_M12', 'ICEWTI_M1', 
                          'ICEWTI_M2', 'ICEWTI_M3',
                          'NymexWTI__M1', 'NymexWTI__M2', 
                          'NymexWTI__M3', 'NymexWTI__M4', 
                          'NymexWTI__M5', 'NymexWTI__M6', 
                          'NymexWTI__M7', 'NymexWTI__M8', 
                          'NymexWTI__M9', 'NymexWTI__M10', 
                          'NymexWTI__M11', 'NymexWTI__M12',
                          'NymexWTI__M13', 'NymexWTI__M14', 
                          'NymexWTI__M15', 'NymexWTI__M16', 
                          'NymexWTI__M17', 'NymexWTI__M18',
                          'NymexWTI__M19', 'NymexWTI__M20',
                          'NymexWTI__M21', 'NymexWTI__M22', 
                          'NymexWTI__M23', 'NymexWTI__M24', 
                          'NymexWTI__M25', 'NymexWTI__M26', 
                          'NymexWTI__M27', 'NymexWTI__M28', 
                          'NymexWTI__M29', 'NymexWTI__M30', 
                          'NymexWTI__M31', 'NymexWTI__M32',
                          'NymexWTI__M33', 'NymexWTI__M34', 
                          'NymexWTI__M35', 'NymexWTI__M36', 
                          'NymexWTI__M37', 'NymexWTI__M38',
                          'NymexWTI__M39', 'NymexWTI__M40',
                          'NymexWTI__M41', 'NymexWTI__M42', 
                          'NymexWTI__M43', 'NymexWTI__M44', 
                          'NymexWTI__M45', 'NymexWTI__M46', 
                          'NymexWTI__M47', 'NymexWTI__M48', 
                          'NymexWTI__M49', 'NymexWTI__M50', 
                          'NymexWTI__M51', 'NymexWTI__M52',
                          'NymexWTI__M53', 'NymexWTI__M54', 
                          'NymexWTI__M55', 'NymexWTI__M56', 
                          'NymexWTI__M57', 'NymexWTI__M58',
                          'NymexWTI__M59', 'NymexWTI__M60',
                          'NymexWTI__M61', 'NymexWTI__M62', 
                          'NymexWTI__M63', 'NymexWTI__M64', 
                          'NymexWTI__M65', 'NymexWTI__M66', 
                          'NymexWTI__M67', 'NymexWTI__M68', 
                          'NymexWTI__M69', 'NymexWTI__M70', 
                          'NymexWTI__M71', 'NymexWTI__M72',
                          'NymexWTI__M73', 'NymexWTI__M74', 
                          'NymexWTI__M75', 'NymexWTI__M76', 
                          'NymexWTI__M77', 'NymexWTI__M78',                          
                          'ICEBrent__M1', 'ICEBrent__M2', 
                          'ICEBrent__M3', 'ICEBrent__M4', 
                          'ICEBrent__M5', 'ICEBrent__M6', 
                          'ICEBrent__M7', 'ICEBrent__M8', 
                          'ICEBrent__M9', 'ICEBrent__M10', 
                          'ICEBrent__M11', 'ICEBrent__M12',
                          'ICEBrent__M13', 'ICEBrent__M14', 
                          'ICEBrent__M15', 'ICEBrent__M16', 
                          'ICEBrent__M17', 'ICEBrent__M18',
                          'ICEBrent__M19', 'ICEBrent__M20',
                          'ICEBrent__M21', 'ICEBrent__M22', 
                          'ICEBrent__M23', 'ICEBrent__M24', 
                          'ICEBrent__M25', 'ICEBrent__M26', 
                          'ICEBrent__M27', 'ICEBrent__M28', 
                          'ICEBrent__M29', 'ICEBrent__M30', 
                          'ICEBrent__M31', 'ICEBrent__M32',
                          'ICEBrent__M33', 'ICEBrent__M34', 
                          'ICEBrent__M35', 'ICEBrent__M36']

def download_data():
    main_df = ek.get_timeseries(['CLc1'], interval='daily', start_date='2021-06-01', end_date=None)
    main_df = main_df[['CLOSE']]
    main_df.rename(columns={"CLOSE": "NymexWTI_M1"}, inplace=True)
    print('NymexWTI_M1 downloaded')
    for id, contract in zip(list_of_contracts, list_of_contract_names):
        try:
            df = ek.get_timeseries([id], interval='daily', start_date='2021-06-01', end_date=None)
            df = df[['CLOSE']]
            df.rename(columns={"CLOSE": contract}, inplace=True)
            main_df = pd.concat([main_df, df], axis=1)
            print(contract, 'downloaded')
            time.sleep(0.15)
        except:
            try:
                df = ek.get_timeseries([id], interval='daily', start_date='2021-06-01', end_date=None)
                df = df[['CLOSE']]
                df.rename(columns={"CLOSE": contract}, inplace=True)
                main_df = pd.concat([main_df, df], axis=1)
                print(contract, 'downloaded')
                time.sleep(0.15)
            except Exception as e:
                print('error in downloading', contract, e)
    main_df.replace('<NA>', np.nan, inplace=True)
    return main_df

def export_to_excel(main_df):
    path = 'Futures_for_Luis.xlsx'
    with pd.ExcelWriter(path, engine='xlsxwriter') as writer:
        main_df.to_excel(writer, sheet_name='daily')
        main_df.resample('w').mean().to_excel(writer, sheet_name='weekly')
        main_df.resample('m').mean().to_excel(writer, sheet_name='monthly')
    return print('all done')

main_df = download_data()
export_to_excel(main_df)
# Out:
# NymexWTI_M1 downloaded
# NymexWTI_M2 downloaded
# NymexWTI_M3 downloaded
# NymexWTI_M4 downloaded
# NymexWTI_M5 downloaded
# NymexWTI_M6 downloaded
# NymexWTI_M7 downloaded
# NymexWTI_M8 downloaded
# NymexWTI_M9 downloaded
# NymexWTI_M10 downloaded
# NymexWTI_M11 downloaded
# NymexWTI_M12 downloaded
# NymexULSD_M1 downloaded
# NymexULSD_M2 downloaded
# NymexULSD_M3 downloaded
# NymexULSD_M4 downloaded
# NymexULSD_M5 downloaded
# NymexULSD_M6 downloaded
# NymexULSD_M7 downloaded
# NymexULSD_M8 downloaded
# NymexULSD_M9 downloaded
# NymexULSD_M10 downloaded
# NymexULSD_M11 downloaded
# NymexULSD_M12 downloaded
# NymexHenryHubNatGas_M1 downloaded
# NymexHenryHubNatGas_M2 downloaded
# NymexHenryHubNatGas_M3 downloaded
# NymexHenryHubNatGas_M4 downloaded
# NymexHenryHubNatGas_M5 downloaded
# NymexHenryHubNatGas_M6 downloaded
# NymexHenryHubNatGas_M7 downloaded
# NymexHenryHubNatGas_M8 downloaded
# NymexHenryHubNatGas_M9 downloaded
# NymexHenryHubNatGas_M10 downloaded
# ...

# %%
from datetime import date, timedelta

main_df = ek.get_timeseries(['CLc1'], interval='daily', start_date=(date.today() - timedelta(5)).strftime(('%Y-%m-%d %H:%M:%S')), end_date=None)
main_df = main_df[['CLOSE']]
main_df.rename(columns={"CLOSE": "NymexWTI_M1"}, inplace=True)

main_df
# Out:
# C:\Users\DEGUCHI_T\PycharmProjects\scraper\.env\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CLc1        NymexWTI_M1
# Date
# 2022-03-23       114.93
# 2022-03-24       112.34
# 2022-03-25        113.9
# 2022-03-28       105.73

# %%
test = main_df.stack()

# %%
test
# Out:
# Date        CLc1
# 2022-03-23  NymexWTI_M1    114.93
# 2022-03-24  NymexWTI_M1    112.34
# 2022-03-25  NymexWTI_M1     113.9
# 2022-03-28  NymexWTI_M1    105.73
# dtype: Float64

# %%
test = test.reset_index()

# %%
test
# Out:
#         Date         CLc1       0
# 0 2022-03-23  NymexWTI_M1  114.93
# 1 2022-03-24  NymexWTI_M1  112.34
# 2 2022-03-25  NymexWTI_M1   113.9
# 3 2022-03-28  NymexWTI_M1  105.73

# %%
list_of_contracts = ['CLc2', 'CLc3',
                     'CLc4', 'CLc5',
                     'CLc6', 'CLc7',
                     'CLc8', 'CLc9',
                     'CLc10', 'CLc11',
                     'CLc12', 'HOc1',
                     'HOc2', 'HOc3',
                     'HOc4', 'HOc5',
                     'HOc6', 'HOc7',
                     'HOc8', 'HOc9',
                     'HOc10', 'HOc11',
                     'HOc12', 'NGc1',
                     'NGc2', 'NGc3',
                     'NGc4', 'NGc5', 
                     'NGc6', 'NGc7',
                     'NGc8', 'NGc9',
                     'NGc10', 'NGc11',
                     'NGc12', 'LCOc1',
                     'LCOc2', 'LCOc3', 
                     'LCOc4', 'LCOc5', 
                     'LCOc6', 'LCOc7', 
                     'LCOc8', 'LCOc9', 
                     'LCOc10', 'LCOc11',
                     'LCOc12', 'LGOc1',
                     'LGOc2', 'LGOc3', 
                     'LGOc4', 'LGOc5', 
                     'LGOc6', 'LGOc7', 
                     'LGOc8', 'LGOc9', 
                     'LGOc10', 'LGOc11', 
                     'LGOc12', 'RBc1',
                     'RBc2', 'RBc3', 
                     'RBc4', 'RBc5', 
                     'RBc6', 'RBc7', 
                     'RBc8', 'RBc9', 
                     'RBc10', 'RBc11', 
                     'RBc12', 'RBc1',
                     'RBc2', 'RBc3', 
                     'RBc4', 'RBc5', 
                     'RBc6', 'RBc7', 
                     'RBc8', 'RBc9', 
                     'RBc10', 'RBc11', 
                     'RBc12', 'WTCLc1', 
                     'WTCLc2', 'WTCLc3', 
                     'CLc1', 'CLc2', 
                     'CLc3', 'CLc4', 
                     'CLc5', 'CLc6', 
                     'CLc7', 'CLc8', 
                     'CLc9', 'CLc10', 
                     'CLc11', 'CLc12',
                     'CLc13', 'CLc14', 
                     'CLc15', 'CLc16', 
                     'CLc17', 'CLc18', 
                     'CLc19', 'CLc20', 
                     'CLc21', 'CLc22', 
                     'CLc23', 'CLc24',
                     'CLc25', 'CLc26', 
                     'CLc27', 'CLc28', 
                     'CLc29', 'CLc30', 
                     'CLc31', 'CLc32',
                     'CLc33', 'CLc34', 
                     'CLc35', 'CLc36',
                     'CLc37', 'CLc38', 
                     'CLc39', 'CLc40', 
                     'CLc41', 'CLc42', 
                     'CLc43', 'CLc44', 
                     'CLc45', 'CLc46', 
                     'CLc47', 'CLc48',
                     'CLc49', 'CLc50', 
                     'CLc51', 'CLc52', 
                     'CLc53', 'CLc54', 
                     'CLc55', 'CLc56', 
                     'CLc57', 'CLc58', 
                     'CLc59', 'CLc60',
                     'CLc61', 'CLc62', 
                     'CLc63', 'CLc64', 
                     'CLc65', 'CLc66', 
                     'CLc67', 'CLc68', 
                     'CLc69', 'CLc70', 
                     'CLc71', 'CLc72',
                     'CLc73', 'CLc74', 
                     'CLc75', 'CLc76', 
                     'CLc77', 'CLc78',
                     'LCOc1', 'LCOc2', 
                     'LCOc3', 'LCOc4', 
                     'LCOc5', 'LCOc6', 
                     'LCOc7', 'LCOc8', 
                     'LCOc9', 'LCOc10', 
                     'LCOc11', 'LCOc12',
                     'LCOc13', 'LCOc14', 
                     'LCOc15', 'LCOc16', 
                     'LCOc17', 'LCOc18', 
                     'LCOc19', 'LCOc20', 
                     'LCOc21', 'LCOc22', 
                     'LCOc23', 'LCOc24',
                     'LCOc25', 'LCOc26', 
                     'LCOc27', 'LCOc28', 
                     'LCOc29', 'LCOc30', 
                     'LCOc31', 'LCOc32',
                     'LCOc33', 'LCOc34', 
                     'LCOc35', 'LCOc36']

list_of_contract_names = ['NymexWTI_M2', 'NymexWTI_M3',
                          'NymexWTI_M4', 'NymexWTI_M5',
                          'NymexWTI_M6', 'NymexWTI_M7',
                          'NymexWTI_M8', 'NymexWTI_M9',
                          'NymexWTI_M10', 'NymexWTI_M11', 
                          'NymexWTI_M12', 'NymexULSD_M1', 
                          'NymexULSD_M2', 'NymexULSD_M3',
                          'NymexULSD_M4', 'NymexULSD_M5',
                          'NymexULSD_M6', 'NymexULSD_M7',
                          'NymexULSD_M8', 'NymexULSD_M9',
                          'NymexULSD_M10', 'NymexULSD_M11', 
                          'NymexULSD_M12', 'NymexHenryHubNatGas_M1', 
                          'NymexHenryHubNatGas_M2', 'NymexHenryHubNatGas_M3',
                          'NymexHenryHubNatGas_M4', 'NymexHenryHubNatGas_M5',
                          'NymexHenryHubNatGas_M6', 'NymexHenryHubNatGas_M7',
                          'NymexHenryHubNatGas_M8', 'NymexHenryHubNatGas_M9',
                          'NymexHenryHubNatGas_M10', 'NymexHenryHubNatGas_M11', 
                          'NymexHenryHubNatGas_M12', 'ICEBrent_M1', 
                          'ICEBrent_M2', 'ICEBrent_M3',
                          'ICEBrent_M4', 'ICEBrent_M5',
                          'ICEBrent_M6', 'ICEBrent_M7',
                          'ICEBrent_M8', 'ICEBrent_M9',
                          'ICEBrent_M10', 'ICEBrent_M11', 
                          'ICEBrent_M12', 'ICELSGasoil_M1', 
                          'ICELSGasoil_M2', 'ICELSGasoil_M3',
                          'ICELSGasoil_M4', 'ICELSGasoil_M5',
                          'ICELSGasoil_M6', 'ICELSGasoil_M7',
                          'ICELSGasoil_M8', 'ICELSGasoil_M9',
                          'ICELSGasoil_M10', 'ICELSGasoil_M11', 
                          'ICELSGasoil_M12', 'NymexRBOB_M1', 
                          'NymexRBOB_M2', 'NymexRBOB_M3',
                          'NymexRBOB_M4', 'NymexRBOB_M5',
                          'NymexRBOB_M6', 'NymexRBOB_M7',
                          'NymexRBOB_M8', 'NymexRBOB_M9',
                          'NymexRBOB_M10', 'NymexRBOB_M11', 
                          'NymexRBOB_M12', 'NymexRBOBPit_M1', 
                          'NymexRBOBPit_M2', 'NymexRBOBPit_M3',
                          'NymexRBOBPit_M4', 'NymexRBOBPit_M5',
                          'NymexRBOBPit_M6', 'NymexRBOBPit_M7',
                          'NymexRBOBPit_M8', 'NymexRBOBPit_M9',
                          'NymexRBOBPit_M10', 'NymexRBOBPit_M11', 
                          'NymexRBOBPit_M12', 'ICEWTI_M1', 
                          'ICEWTI_M2', 'ICEWTI_M3',
                          'NymexWTI__M1', 'NymexWTI__M2', 
                          'NymexWTI__M3', 'NymexWTI__M4', 
                          'NymexWTI__M5', 'NymexWTI__M6', 
                          'NymexWTI__M7', 'NymexWTI__M8', 
                          'NymexWTI__M9', 'NymexWTI__M10', 
                          'NymexWTI__M11', 'NymexWTI__M12',
                          'NymexWTI__M13', 'NymexWTI__M14', 
                          'NymexWTI__M15', 'NymexWTI__M16', 
                          'NymexWTI__M17', 'NymexWTI__M18',
                          'NymexWTI__M19', 'NymexWTI__M20',
                          'NymexWTI__M21', 'NymexWTI__M22', 
                          'NymexWTI__M23', 'NymexWTI__M24', 
                          'NymexWTI__M25', 'NymexWTI__M26', 
                          'NymexWTI__M27', 'NymexWTI__M28', 
                          'NymexWTI__M29', 'NymexWTI__M30', 
                          'NymexWTI__M31', 'NymexWTI__M32',
                          'NymexWTI__M33', 'NymexWTI__M34', 
                          'NymexWTI__M35', 'NymexWTI__M36', 
                          'NymexWTI__M37', 'NymexWTI__M38',
                          'NymexWTI__M39', 'NymexWTI__M40',
                          'NymexWTI__M41', 'NymexWTI__M42', 
                          'NymexWTI__M43', 'NymexWTI__M44', 
                          'NymexWTI__M45', 'NymexWTI__M46', 
                          'NymexWTI__M47', 'NymexWTI__M48', 
                          'NymexWTI__M49', 'NymexWTI__M50', 
                          'NymexWTI__M51', 'NymexWTI__M52',
                          'NymexWTI__M53', 'NymexWTI__M54', 
                          'NymexWTI__M55', 'NymexWTI__M56', 
                          'NymexWTI__M57', 'NymexWTI__M58',
                          'NymexWTI__M59', 'NymexWTI__M60',
                          'NymexWTI__M61', 'NymexWTI__M62', 
                          'NymexWTI__M63', 'NymexWTI__M64', 
                          'NymexWTI__M65', 'NymexWTI__M66', 
                          'NymexWTI__M67', 'NymexWTI__M68', 
                          'NymexWTI__M69', 'NymexWTI__M70', 
                          'NymexWTI__M71', 'NymexWTI__M72',
                          'NymexWTI__M73', 'NymexWTI__M74', 
                          'NymexWTI__M75', 'NymexWTI__M76', 
                          'NymexWTI__M77', 'NymexWTI__M78',                          
                          'ICEBrent__M1', 'ICEBrent__M2', 
                          'ICEBrent__M3', 'ICEBrent__M4', 
                          'ICEBrent__M5', 'ICEBrent__M6', 
                          'ICEBrent__M7', 'ICEBrent__M8', 
                          'ICEBrent__M9', 'ICEBrent__M10', 
                          'ICEBrent__M11', 'ICEBrent__M12',
                          'ICEBrent__M13', 'ICEBrent__M14', 
                          'ICEBrent__M15', 'ICEBrent__M16', 
                          'ICEBrent__M17', 'ICEBrent__M18',
                          'ICEBrent__M19', 'ICEBrent__M20',
                          'ICEBrent__M21', 'ICEBrent__M22', 
                          'ICEBrent__M23', 'ICEBrent__M24', 
                          'ICEBrent__M25', 'ICEBrent__M26', 
                          'ICEBrent__M27', 'ICEBrent__M28', 
                          'ICEBrent__M29', 'ICEBrent__M30', 
                          'ICEBrent__M31', 'ICEBrent__M32',
                          'ICEBrent__M33', 'ICEBrent__M34', 
                          'ICEBrent__M35', 'ICEBrent__M36']

# %%
ls = []

for k,v in zip(list_of_contracts, list_of_contract_names):
    ls.append({'eikon_code': k, 'column_code' : v.split('_')[0], 'month' : v.split('_')[1] })

# %%
import json

js = json.dumps(ls)

# %%
from datetime import datetime as dt

diff = 3

df = ek.get_timeseries(['CLc1'], interval='daily', start_date= (dt.today() - timedelta(1)), end_date=(dt.today()))

# %%
df
# Out:
# CLc1          HIGH     LOW    OPEN  CLOSE  VOLUME
# Date
# 2022-03-25  114.12  108.68  111.75  113.9  320304

# %%
(dt.today() - timedelta(diff))
# Out:
# datetime.datetime(2022, 3, 25, 14, 9, 34, 17801)
