# %% [markdown]
# # Scrapper for Annual Refinery data - Russia
#
# Scrapper intended to get annual refinery information for primary and secondary oil products for Russia.
#
# Data source: Argus fundamentals file for Russia.
#
# ## How to use
#
# 1. convert manually the Argus file from *.xslx to *.xls
# 2. run the script : it will generate a csv file on the same directory
# 3. import data into an excel file using PowerQuery and pivot *Period* column using Value as value.

# %%
import pandas as pd
import datetime

# 
# selects the worksheets used for annual purposes from argus excel file:
# + all worksheets starting with 'Dec'
# + the last worksheet (if it does not start with 'Dec')
#
def select_annual_worksheets(excelpath):
    xl = pd.ExcelFile(excelpath)
    xl.sheet_names

    # select all december months
    selectedWks = [x for x in xl.sheet_names if x.startswith('Dec')]

    # adding latest month of the last year (if not already included)
    if not xl.sheet_names[-1].startswith("Dec"):
        selectedWks.append(xl.sheet_names[-1])
    
    return selectedWks

#
# Filter empty or non-rows
#
def clean_data(df):
    #print('cleaning data ...')
    # drop empty rows
    df.dropna(how='all', inplace=True)
    # filter out 'Russian refinery ...' rows
    df = df[~df["Company/refinery"].str.contains("Russian refinery output")]
    df = df[~df["Company/refinery"].str.contains("Comparisons")]
    return df

# 
# It split the worksheets in separate data frames when finding a title line.
# It returns a dictionary of data frames.
#
def break_into_tables(df):
    #print('breaking into tables ...')
    # get the index of table breaks
    breakIndex = df.loc[df["Company/refinery"] == "Company/refinery"].index

    # loop to split tables
    tableDic = {}
    startIndex = 0
    for num, index in enumerate(breakIndex):
        endIndex = (index - 1)
        tableDic[num] = df.loc[startIndex:endIndex].copy()
        if num != 0:
            tableDic[num].columns = tableDic[num].loc[startIndex].values
            tableDic[num] = tableDic[num].iloc[1:]
        startIndex = index

    # this creates a data frame for the last table
    tableDic[num + 1] = df.loc[startIndex:].copy()
    tableDic[num + 1].columns = tableDic[num + 1].loc[startIndex].values
    tableDic[num + 1] = tableDic[num + 1].iloc[1:]
      
    return tableDic

#
# Unpivot each data frame of the dictionary and concat them.
# It returns the resulting data frame.
#
def melt_and_concat(tableDic):
    #print('melting and concatenating data ...')
    listOfMeltedDfs = None
    # for each table, melt and concat
    for myDf in tableDic.values():
        # drop empty columns
        myDf.dropna(how='all', axis=1, inplace=True)
      
        # get the list of columns to unpivot
        varcols = [x for x in myDf.columns if x != "Company/refinery"]
        
        # unpivot it !
        meltedDf = myDf.melt(id_vars=["Company/refinery"], value_vars=varcols, var_name="Product", value_name="Value")

        # concat data frames
        if not listOfMeltedDfs:
            listOfMeltedDfs = [meltedDf]
        else:
            listOfMeltedDfs.append(meltedDf)

    # concat all data frames
    return pd.concat(listOfMeltedDfs)

#
# It returns a data frame with a Period column added as the 1st column
#
def add_period(df, period):
    #print('adding period ...')
    # add period col
    df['Period'] = period
    
    # get the list of cols
    cols = df.columns.tolist()

    # Put 'Period' at first
    cols = cols[-1:] + cols[:-1]
    return df[cols]

#
# process each selected worksheet of the excel file.
#
def process_worksheet(wks):
    start = datetime.datetime.now()
    print('processing ' + wks)
    df = pd.read_excel(excelpath, sheet_name=wks,  skiprows=5)

    # apply transformations
    cleanedDf = clean_data(df)
    tableDict = break_into_tables(cleanedDf)
    concatDf = melt_and_concat(tableDict)

    # keep only columns ending with 'YTD'
    dfYTD = concatDf[concatDf["Product"].str.endswith('YTD')]
    # add period
    periodDf = add_period(dfYTD, wks)
    
    # standardize first column
    periodDf["Company/refinery"] = periodDf["Company/refinery"].str.lstrip("\xa0")
    periodDf["Company/refinery"] = periodDf["Company/refinery"].str.lstrip(" ")
    
    end = datetime.datetime.now()
    print(f"Duration for {wks}: {str(end - start)}")
    return periodDf


#
#  Main
#

#exceldir = 'G:\OMRrefinery\MTOMR\MTOMR 2019\Refining Model\Russia'
exceldir = 'C:\\Users\\ROSA_L\\Downloads'
#filename = 'Russian refinery output.xlsx'
filename = 'Russian refinery output.xls'
excelpath = exceldir + '\\' + filename

print(f'Processing {excelpath}')

# process selected worksheets
listOfWksDfs = [process_worksheet(wks) for wks in select_annual_worksheets(excelpath)]

# concat results
fullDf = pd.concat(listOfWksDfs)
    
csvFile = "Russia_refinery_annual.csv"
csvPath = exceldir + "\\" + csvFile

fullDf.to_csv(path_or_buf=csvPath, index=False)
print(f'Done: file {csvPath} exported.')

# %%
import requests

r = requests.get("http://www.eppo.go.th/epposite/images/Energy-Statistics/energyinformation/Energy_Statistics/Petroleum/T02_02_02-1.xls")

# %%
f"The status code is: {r.status_code}"
# Out:
# 'The status code is: 200'

# %%
import pandas as pd

mappings = {mapping: pd.read_csv(f"C:\\Users\\ROSA_L\\Downloads\\Russia\\201901\\{mapping}_mapping.csv", encoding='windows-1252').set_index('argus_name') for mapping in ['entity','product']}

# open csv
# rename and lowercase column names
# join with products mapping
df = pd.read_csv(f"C:\\Users\\ROSA_L\\Downloads\\Russia\\201901\\Russian_refinery_output.csv")\
    .rename(str.lower, axis='columns').rename(columns={'company/refinery': 'entity'})\
    .join(mappings['product'], on='product',rsuffix='_product')

# get rejected rows from df x prod mapping
df_rej_products = df[df["short_name"].isnull()][['period','product']].drop_duplicates()

# drops nulls from right side of join
# join with entity mapping
# [~df["short_name"].isnull()].
df = df.join(mappings['entity'],on='entity',rsuffix='_entity')
df_rej_entities = df[df["short_name_entity"].isnull()][['period','entity']].drop_duplicates()

df = df[~df["short_name"].isnull() & ~df["short_name_entity"].isnull()]
df
# Out:
#        period                 entity                    product    value  \
# 0      Jan-03       TOTAL FOR RUSSIA  CRUDE THROUGHPUT ’000 B/D  3613.03
# 1      Jan-03               BASHNEFT  CRUDE THROUGHPUT ’000 B/D   381.63
# 2      Jan-03                 NOVOIL  CRUDE THROUGHPUT ’000 B/D   110.49
# 3      Jan-03                    UFA  CRUDE THROUGHPUT ’000 B/D   143.13
# 4      Jan-03           UFANEFTEKHIM  CRUDE THROUGHPUT ’000 B/D   128.01
# 5      Jan-03                    CFC  CRUDE THROUGHPUT ’000 B/D   186.50
# 6      Jan-03                GAZPROM  CRUDE THROUGHPUT ’000 B/D   140.65
# 7      Jan-03       ASTRAKHANGAZPROM  CRUDE THROUGHPUT ’000 B/D    49.50
# 8      Jan-03         NORILSKGAZPROM  CRUDE THROUGHPUT ’000 B/D     0.00
# 9      Jan-03       SURGUTGAZDOBYCHA  CRUDE THROUGHPUT ’000 B/D    78.25
# 10     Jan-03         URENGOIGAZPROM  CRUDE THROUGHPUT ’000 B/D     9.77
# 11     Jan-03           YAKUTGAZPROM  CRUDE THROUGHPUT ’000 B/D     3.13
# 12     Jan-03                 LUKOIL  CRUDE THROUGHPUT ’000 B/D   688.77
# 13     Jan-03        KOGALYMNEFTEGAZ  CRUDE THROUGHPUT ’000 B/D     3.11
# 14     Jan-03                  UKHTA  CRUDE THROUGHPUT ’000 B/D    74.51
# 15     Jan-03     PERMNEFTEORGSINTEZ  CRUDE THROUGHPUT ’000 B/D   212.95
# 16     Jan-03           URAINEFTEGAZ  CRUDE THROUGHPUT ’000 B/D     0.68
# 17     Jan-03              VOLGOGRAD  CRUDE THROUGHPUT ’000 B/D   171.71
# 18     Jan-03              NORSI OIL  CRUDE THROUGHPUT ’000 B/D   225.81
# 19     Jan-03             ONACO-ORSK  CRUDE THROUGHPUT ’000 B/D    62.78
# 20     Jan-03                ROSNEFT  CRUDE THROUGHPUT ’000 B/D   199.71
# 21     Jan-03             KOMSOMOLSK  CRUDE THROUGHPUT ’000 B/D    95.37
# 22     Jan-03       KRASNODAREKONEFT  CRUDE THROUGHPUT ’000 B/D    24.54
# 23     Jan-03                 TUAPSE  CRUDE THROUGHPUT ’000 B/D    79.81
# 24     Jan-03  SALAVATNEFTEORGSINTEZ  CRUDE THROUGHPUT ’000 B/D    96.81
# 25     Jan-03           SIBNEFT-OMSK  CRUDE THROUGHPUT ’000 B/D   184.34
# 26     Jan-03                SIDANCO  CRUDE THROUGHPUT ’000 B/D   143.69
# 27     Jan-03                ANGARSK  CRUDE THROUGHPUT ’000 B/D    58.71
# 28     Jan-03             KHABAROVSK  CRUDE THROUGHPUT ’000 B/D    84.75
# 29     Jan-03                KREKING  CRUDE THROUGHPUT ’000 B/D     0.24
# ...       ...                    ...                        ...      ...
# 59020  Dec-18       TOTAL FOR RUSSIA              FUEL OIL 3.0%  1695.50
# 59021  Dec-18            GAZPROMNEFT              FUEL OIL 3.0%   224.80
# 59022  Dec-18                 MOSCOW              FUEL OIL 3.0%   224.80
# 59023  Dec-18                 LUKOIL              FUEL OIL 3.0%   318.10
# 59024  Dec-18             N.NOVGOROD              FUEL OIL 3.0%   318.10
# 59025  Dec-18                ROSNEFT              FUEL OIL 3.0%   665.90
# 59026  Dec-18        NOVOKUIBYSHEVSK              FUEL OIL 3.0%   176.30
# 59027  Dec-18                 RYAZAN              FUEL OIL 3.0%   384.80
# 59028  Dec-18                SARATOV              FUEL OIL 3.0%   104.80
# 59029  Dec-18   SLAVNEFT (YAROSLAVL)              FUEL OIL 3.0%   486.70
# 59030  Dec-18       TOTAL FOR RUSSIA              FUEL OIL 3.5%   876.60
# 59031  Dec-18               BASHNEFT              FUEL OIL 3.5%   326.80
# 59032  Dec-18                 NOVOIL              FUEL OIL 3.5%   106.30
# 59033  Dec-18                    UFA              FUEL OIL 3.5%   175.80
# 59034  Dec-18           UFANEFTEKHIM              FUEL OIL 3.5%    44.70
# 59035  Dec-18                GAZPROM              FUEL OIL 3.5%    38.60
# 59036  Dec-18                ROSNEFT              FUEL OIL 3.5%   268.90
# 59037  Dec-18              KUIBYSHEV              FUEL OIL 3.5%   174.50
# 59038  Dec-18                 SYZRAN              FUEL OIL 3.5%    94.40
# 59039  Dec-18                SALAVAT              FUEL OIL 3.5%    31.60
# 59040  Dec-18     NIZHNEKAMSK (TAIF)              FUEL OIL 3.5%   210.70
# 59041  Dec-18       TOTAL FOR RUSSIA             OTHER FUEL OIL   279.40
# 59042  Dec-18               BASHNEFT             OTHER FUEL OIL     0.00
# 59043  Dec-18                 NOVOIL             OTHER FUEL OIL     0.00
# 59044  Dec-18                    UFA             OTHER FUEL OIL     0.00
# 59045  Dec-18           UFANEFTEKHIM             OTHER FUEL OIL     0.00
# 59046  Dec-18            GAZPROMNEFT             OTHER FUEL OIL     0.00
# 59047  Dec-18                   OMSK             OTHER FUEL OIL     0.00
# 59048  Dec-18     NOVATEK (UST-LUGA)             OTHER FUEL OIL    67.60
# 59049  Dec-18                 OTHERS             OTHER FUEL OIL   211.80
#
#        short_name detail_short             detail_long short_name_entity  \
# 0           CRUDE        TOTAL  Crude Throughput (Kbd)             TOTAL
# 1           CRUDE        TOTAL  Crude Throughput (Kbd)          BASHNEFT
# 2           CRUDE        TOTAL  Crude Throughput (Kbd)            NOVOIL
# 3           CRUDE        TOTAL  Crude Throughput (Kbd)               UFA
# 4           CRUDE        TOTAL  Crude Throughput (Kbd)      UFANEFTEKHIM
# 5           CRUDE        TOTAL  Crude Throughput (Kbd)               CFC
# 6           CRUDE        TOTAL  Crude Throughput (Kbd)           GAZPROM
# 7           CRUDE        TOTAL  Crude Throughput (Kbd)  ASTRAKHANGAZPROM
# 8           CRUDE        TOTAL  Crude Throughput (Kbd)    NORILSKGAZPROM
# 9           CRUDE        TOTAL  Crude Throughput (Kbd)     SURGUTGAZPROM
# 10          CRUDE        TOTAL  Crude Throughput (Kbd)    URENGOIGAZPROM
# 11          CRUDE        TOTAL  Crude Throughput (Kbd)      YAKUTGAZPROM
# 12          CRUDE        TOTAL  Crude Throughput (Kbd)            LUKOIL
# 13          CRUDE        TOTAL  Crude Throughput (Kbd)   KOGALYMNEFTEGAZ
# 14          CRUDE        TOTAL  Crude Throughput (Kbd)             UKHTA
# 15          CRUDE        TOTAL  Crude Throughput (Kbd)              PERM
# 16          CRUDE        TOTAL  Crude Throughput (Kbd)      URAINEFTEGAZ
# 17          CRUDE        TOTAL  Crude Throughput (Kbd)         VOLGOGRAD
# 18          CRUDE        TOTAL  Crude Throughput (Kbd)         NNOVGOROD
# 19          CRUDE        TOTAL  Crude Throughput (Kbd)              ORSK
# 20          CRUDE        TOTAL  Crude Throughput (Kbd)           ROSNEFT
# 21          CRUDE        TOTAL  Crude Throughput (Kbd)        KOMSOMOLSK
# 22          CRUDE        TOTAL  Crude Throughput (Kbd)         KRASNODAR
# 23          CRUDE        TOTAL  Crude Throughput (Kbd)            TUAPSE
# 24          CRUDE        TOTAL  Crude Throughput (Kbd)           SALAVAT
# 25          CRUDE        TOTAL  Crude Throughput (Kbd)              OMSK
# 26          CRUDE        TOTAL  Crude Throughput (Kbd)           SIDANCO
# 27          CRUDE        TOTAL  Crude Throughput (Kbd)           ANGARSK
# 28          CRUDE        TOTAL  Crude Throughput (Kbd)        KHABAROVSK
# 29          CRUDE        TOTAL  Crude Throughput (Kbd)           KREKING
# ...           ...          ...                     ...               ...
# 59020     FUELOIL    FUELOIL30           Fuel Oil 3.0%             TOTAL
# 59021     FUELOIL    FUELOIL30           Fuel Oil 3.0%       GAZPROMNEFT
# 59022     FUELOIL    FUELOIL30           Fuel Oil 3.0%            MOSCOW
# 59023     FUELOIL    FUELOIL30           Fuel Oil 3.0%            LUKOIL
# 59024     FUELOIL    FUELOIL30           Fuel Oil 3.0%         NNOVGOROD
# 59025     FUELOIL    FUELOIL30           Fuel Oil 3.0%           ROSNEFT
# 59026     FUELOIL    FUELOIL30           Fuel Oil 3.0%   NOVOKUIBYSHEVSK
# 59027     FUELOIL    FUELOIL30           Fuel Oil 3.0%            RYAZAN
# 59028     FUELOIL    FUELOIL30           Fuel Oil 3.0%           SARATOV
# 59029     FUELOIL    FUELOIL30           Fuel Oil 3.0%         YAROSLAVL
# 59030     FUELOIL    FUELOIL35           Fuel Oil 3.5%             TOTAL
# 59031     FUELOIL    FUELOIL35           Fuel Oil 3.5%          BASHNEFT
# 59032     FUELOIL    FUELOIL35           Fuel Oil 3.5%            NOVOIL
# 59033     FUELOIL    FUELOIL35           Fuel Oil 3.5%               UFA
# 59034     FUELOIL    FUELOIL35           Fuel Oil 3.5%      UFANEFTEKHIM
# 59035     FUELOIL    FUELOIL35           Fuel Oil 3.5%           GAZPROM
# 59036     FUELOIL    FUELOIL35           Fuel Oil 3.5%           ROSNEFT
# 59037     FUELOIL    FUELOIL35           Fuel Oil 3.5%         KUIBYSHEV
# 59038     FUELOIL    FUELOIL35           Fuel Oil 3.5%            SYZRAN
# 59039     FUELOIL    FUELOIL35           Fuel Oil 3.5%           SALAVAT
# 59040     FUELOIL    FUELOIL35           Fuel Oil 3.5%       NIZHNEKAMSK
# 59041  OTHFUELOIL        TOTAL          Other Fuel Oil             TOTAL
# 59042  OTHFUELOIL        TOTAL          Other Fuel Oil          BASHNEFT
# 59043  OTHFUELOIL        TOTAL          Other Fuel Oil            NOVOIL
# 59044  OTHFUELOIL        TOTAL          Other Fuel Oil               UFA
# 59045  OTHFUELOIL        TOTAL          Other Fuel Oil      UFANEFTEKHIM
# 59046  OTHFUELOIL        TOTAL          Other Fuel Oil       GAZPROMNEFT
# 59047  OTHFUELOIL        TOTAL          Other Fuel Oil              OMSK
# 59048  OTHFUELOIL        TOTAL          Other Fuel Oil    NOVATEKUSTLUGA
# 59049  OTHFUELOIL        TOTAL          Other Fuel Oil            OTHERS
#
#                                         detail_long_name  \
# 0                                           Total Russia
# 1                                               Bashneft
# 2                             Bashneft - Novoil Refinery
# 3                            Bashneft - Ufa Oil Refinery
# 4                                Bashneft - Ufaneftekhim
# 5                                                    CFC
# 6                                                Gazprom
# 7                                      Astrakhan Gazprom
# 8                                         Norilskgazprom
# 9            Surgutgazprom (now Gazprom Surgut Transgaz)
# 10                                     Urengoy - Gazprom
# 11                                          Yakutgazprom
# 12                                                Lukoil
# 13                             Lukoil - Kogalym Neftegaz
# 14                                        Lukoil - Ukhta
# 15                                Lukoil - Perm Refinery
# 16                                Lukoil - Urai Neftegaz
# 17                           Lukoil - Volvograd Refinery
# 18                     Lukoil - Nizhny Novgorod Refinery
# 19      Orsk Refinery (former Onaco, Orsknefteorgsintez)
# 20                                               Rosneft
# 21                        Rosneft - Komsomolsky Refinery
# 22                                Krasnodar Oil Refinery
# 23                             Rosneft - Tuapse Refinery
# 24     Gazprom neftekhim Salavat (Salavatnefteorgsint...
# 25     Gazprom neft - Omsk Refinery (Sibneft Omsk NPZ...
# 26          Sidanco (integrated in TNK-BP, then Rosneft)
# 27                                      Angarsk Refinery
# 28                                   Khabarovsk Refinery
# 29                                               Kreking
# ...                                                  ...
# 59020                                       Total Russia
# 59021                                       Gazprom Neft
# 59022                     Gazprom neft - Moscow Refinery
# 59023                                             Lukoil
# 59024                  Lukoil - Nizhny Novgorod Refinery
# 59025                                            Rosneft
# 59026                 Rosneft - Novokuibyshevsk Refinery
# 59027  Rosneft - Ryazan Oil Refining Company Joint St...
# 59028                          PJSC Saratov Oil Refinery
# 59029                               Yaroslavl (Slavneft)
# 59030                                       Total Russia
# 59031                                           Bashneft
# 59032                         Bashneft - Novoil Refinery
# 59033                        Bashneft - Ufa Oil Refinery
# 59034                            Bashneft - Ufaneftekhim
# 59035                                            Gazprom
# 59036                                            Rosneft
# 59037                       Rosneft - Kuibyshev Refinery
# 59038                          Rosneft - Syzran Refinery
# 59039  Gazprom neftekhim Salavat (Salavatnefteorgsint...
# 59040                                 Nizhnekamsk (Taif)
# 59041                                       Total Russia
# 59042                                           Bashneft
# 59043                         Bashneft - Novoil Refinery
# 59044                        Bashneft - Ufa Oil Refinery
# 59045                            Bashneft - Ufaneftekhim
# 59046                                       Gazprom Neft
# 59047  Gazprom neft - Omsk Refinery (Sibneft Omsk NPZ...
# 59048                         Novatek - Ust-Luga Complex
# 59049                                             Others
#
#                                               detail_url
# 0                                                    NaN
# 1                               http://www.bashneft.com/
# 2                               http://www.bashneft.com/
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                    http://astrakhandobycha.gazprom.ru/
# 8                                     http://www.tgaz.ru
# 9                     http://surgut-tr.gazprom.ru/about/
# 10         http://www.gazprom.com/projects/urengoyskoye/
# 11                                                   NaN
# 12                                http://www.lukoil.com/
# 13     http://www.lukoil.com/Business/Downstream/OilR...
# 14                               http://unp.lukoil.ru/ru
# 15     http://www.lukoil.com/Business/Downstream/OilR...
# 16     http://zs.lukoil.ru/ru/About/Structure/Urainef...
# 17     http://www.lukoil.com/Business/Downstream/OilR...
# 18     http://www.lukoil.com/Business/Downstream/OilR...
# 19                                  http://www.ornpz.ru/
# 20                              https://www.rosneft.com/
# 21     https://komsomolskrefinery.rosneft.com/about/R...
# 22                                  https://knpz-ken.ru/
# 23     https://tnpz.rosneft.ru/about/Glance/Operation...
# 24                 http://salavat-neftekhim.gazprom.com/
# 25                         https://onpz.gazprom-neft.ru/
# 26                                                   NaN
# 27                                   http://www.anhk.ru/
# 28                               http://www.khab-npz.ru/
# 29                                                   NaN
# ...                                                  ...
# 59020                                                NaN
# 59021                                                NaN
# 59022  https://www.gazprom-neft.com/company/business/...
# 59023                             http://www.lukoil.com/
# 59024  http://www.lukoil.com/Business/Downstream/OilR...
# 59025                           https://www.rosneft.com/
# 59026  https://www.rosneft.com/business/Downstream/Ne...
# 59027  https://rnpk.rosneft.com/about/Rosneft_today/O...
# 59028                   http://www.saratovoil-npz.ru/fr/
# 59029  http://www.refinery.yaroslavl.su/en/about/comp...
# 59030                                                NaN
# 59031                           http://www.bashneft.com/
# 59032                           http://www.bashneft.com/
# 59033                                                NaN
# 59034                                                NaN
# 59035                                                NaN
# 59036                           https://www.rosneft.com/
# 59037  https://www.rosneft.com/business/Downstream/Ne...
# 59038  https://www.rosneft.com/business/Downstream/Ne...
# 59039              http://salavat-neftekhim.gazprom.com/
# 59040                             https://www.taifnk.ru/
# 59041                                                NaN
# 59042                           http://www.bashneft.com/
# 59043                           http://www.bashneft.com/
# 59044                                                NaN
# 59045                                                NaN
# 59046                                                NaN
# 59047                      https://onpz.gazprom-neft.ru/
# 59048  http://www.novatek.ru/en/business/processing/u...
# 59049                                                NaN
#
# [59050 rows x 10 columns]

# %%
df_rej_entities['type'] = 'entity'
df_rej_entities = df_rej_entities.rename(columns={'entity': 'value'})

df_rej_products['type'] = 'product'
df_rej_products = df_rej_products.rename(columns={'product': 'value'})

dfrej = df_rej_entities.append(df_rej_products, sort=False)

dfrej[['period','type', 'value']]
# Out:
#        period     type  value
# 59050  Dec-18   entity   TEST
# 59052  Dec-18   entity     BB
# 59050  Dec-18  product   TEST
# 59051  Dec-18  product  BIDON
