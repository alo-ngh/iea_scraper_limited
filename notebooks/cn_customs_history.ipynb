# %% [markdown]
# # China customs history
#
# Convert our history files to the format from China Customs:
#
#     - 2006 - 2016: G:\OMRrefinery\China\Exportimport\China Customs History\China_Customs_history.csv
#     - 1995 - 2015: G:\OMRrefinery\China\Exportimport\China Import History.xls
#
# Columns to output:
#
# "Date of data","Commodity code","Commodity","Trading partner code","Trading partner","Quantity","Unit","Supplimentary Quantity","Supplimentary Unit","Renminbi Yuan",

# %% [markdown]
# # 2006-2016 (old)
#
# There is a bug in the source file, ignore this.

# %%
import pandas as pd

df = pd.read_csv('G:\\OMRrefinery\\China\\Exportimport\\China Customs History\\China_Customs_history.csv', parse_dates=['Period'], dayfirst=True)
df = df[['Country Code', 'Country Name', 'Product Code', 'Unit', 'Period', 'Value']]
df['Date of data'] = df.Period.dt.strftime("%Y%m")
df['Commodity'] = 'Petroleum oils&oils obtained from bituminous minerals, crude'
df['Unit'] = 'Kilograms'
df["Supplimentary Quantity"] = "0"
df["Supplimentary Unit"] = '-'
df["Renminbi Yuan"] = None

df.rename(columns={"Product Code": "Commodity code", 
                    "Country Code": "Trading partner code", 
                    "Country Name": "Trading partner",
                    "Value": "Quantity"}, inplace=True)

df = df[["Date of data","Commodity code","Commodity","Trading partner code","Trading partner","Quantity","Unit","Supplimentary Quantity","Supplimentary Unit","Renminbi Yuan"]].sort_values(by=['Date of data', 'Trading partner code'])
df.head()
# Out:
#       Date of data  Commodity code  \
# 1791        200601        27090000
# 2653        200601        27090000
# 10337       200601        27090000
# 2767        200601        27090000
# 10932       200601        27090000
#
#                                                Commodity  \
# 1791   Petroleum oils&oils obtained from bituminous m...
# 2653   Petroleum oils&oils obtained from bituminous m...
# 10337  Petroleum oils&oils obtained from bituminous m...
# 2767   Petroleum oils&oils obtained from bituminous m...
# 10932  Petroleum oils&oils obtained from bituminous m...
#
#        Trading partner code Trading partner  Quantity       Unit  \
# 1791                    105          Brunei  81965000  Kilograms
# 2653                    106         Myanmar         0  Kilograms
# 10337                   109     North Korea  51130000  Kilograms
# 2767                    110       Hong Kong         0  Kilograms
# 10932                   110       Hong Kong         0  Kilograms
#
#       Supplimentary Quantity Supplimentary Unit Renminbi Yuan
# 1791                       0                  -          None
# 2653                       0                  -          None
# 10337                      0                  -          None
# 2767                       0                  -          None
# 10932                      0                  -          None

# %%
df.to_csv('cn_customs_crudeoil_imp_2006_2016.csv', index=False)

# %% [markdown]
# # 2006 - 2016 (new)

# %%
import pandas as pd
df = pd.read_excel('G:\\OMRrefinery\\China\\Exportimport\\China Customs History\\China_Customs_history_2006-2016.xlsx', 'Sheet1')\
       .replace(0,None)\
       .melt(id_vars=['Code_cn', 'code', 'country'], var_name='period', value_name='value')\
       .dropna(subset=['value'])
# "Date of data","Commodity code","Commodity","Trading partner code","Trading partner","Quantity","Unit","Supplimentary Quantity","Supplimentary Unit","Renminbi Yuan",
df = df.rename(columns={'Code_cn': 'Trading partner code',
           'country': 'Trading partner',
           'value': 'Quantity'})\
       .assign(**{'Date of data' : df.period.dt.strftime("%Y%m"),
                  'Commodity code': '27090000',
                  'Commodity': 'Petroleum oils&oils obtained from bituminous minerals, crude',
                  'Unit': 'Kilograms',
                  'Supplimentary Quantity': '0',
                  'Supplimentary Unit': '-',
                  'Renminbi Yuan': None})\
       .drop(columns=['code', 'period'])
df = df[["Date of data","Commodity code","Commodity","Trading partner code","Trading partner","Quantity","Unit","Supplimentary Quantity","Supplimentary Unit","Renminbi Yuan"]]
df.to_csv('cn_customs_crudeoil_imp_2006_2016.csv', index=False)
# Out:
#       Date of data Commodity code  \
# 0           200601       27090000
# 1           200601       27090000
# 2           200601       27090000
# 3           200601       27090000
# 4           200601       27090000
# 5           200601       27090000
# 6           200601       27090000
# 7           200601       27090000
# 8           200601       27090000
# 9           200601       27090000
# 10          200601       27090000
# 11          200601       27090000
# 12          200601       27090000
# 13          200601       27090000
# 14          200601       27090000
# 15          200601       27090000
# 16          200601       27090000
# 17          200601       27090000
# 18          200601       27090000
# 19          200601       27090000
# 20          200601       27090000
# 21          200601       27090000
# 22          200601       27090000
# 23          200601       27090000
# 24          200601       27090000
# 25          200601       27090000
# 26          200601       27090000
# 27          200601       27090000
# 28          200601       27090000
# 29          200601       27090000
# ...            ...            ...
# 10615       201612       27090000
# 10616       201612       27090000
# 10617       201612       27090000
# 10618       201612       27090000
# 10621       201612       27090000
# 10622       201612       27090000
# 10623       201612       27090000
# 10624       201612       27090000
# 10625       201612       27090000
# 10627       201612       27090000
# 10639       201612       27090000
# 10640       201612       27090000
# 10641       201612       27090000
# 10642       201612       27090000
# 10644       201612       27090000
# 10645       201612       27090000
# 10646       201612       27090000
# 10649       201612       27090000
# 10650       201612       27090000
# 10661       201612       27090000
# 10662       201612       27090000
# 10663       201612       27090000
# 10668       201612       27090000
# 10669       201612       27090000
# 10678       201612       27090000
# 10679       201612       27090000
# 10680       201612       27090000
# 10684       201612       27090000
# 10685       201612       27090000
# 10686       201612       27090000
#
#                                                Commodity  \
# 0      Petroleum oils&oils obtained from bituminous m...
# 1      Petroleum oils&oils obtained from bituminous m...
# 2      Petroleum oils&oils obtained from bituminous m...
# 3      Petroleum oils&oils obtained from bituminous m...
# 4      Petroleum oils&oils obtained from bituminous m...
# 5      Petroleum oils&oils obtained from bituminous m...
# 6      Petroleum oils&oils obtained from bituminous m...
# 7      Petroleum oils&oils obtained from bituminous m...
# 8      Petroleum oils&oils obtained from bituminous m...
# 9      Petroleum oils&oils obtained from bituminous m...
# 10     Petroleum oils&oils obtained from bituminous m...
# 11     Petroleum oils&oils obtained from bituminous m...
# 12     Petroleum oils&oils obtained from bituminous m...
# 13     Petroleum oils&oils obtained from bituminous m...
# 14     Petroleum oils&oils obtained from bituminous m...
# 15     Petroleum oils&oils obtained from bituminous m...
# 16     Petroleum oils&oils obtained from bituminous m...
# 17     Petroleum oils&oils obtained from bituminous m...
# 18     Petroleum oils&oils obtained from bituminous m...
# 19     Petroleum oils&oils obtained from bituminous m...
# 20     Petroleum oils&oils obtained from bituminous m...
# 21     Petroleum oils&oils obtained from bituminous m...
# 22     Petroleum oils&oils obtained from bituminous m...
# 23     Petroleum oils&oils obtained from bituminous m...
# 24     Petroleum oils&oils obtained from bituminous m...
# 25     Petroleum oils&oils obtained from bituminous m...
# 26     Petroleum oils&oils obtained from bituminous m...
# 27     Petroleum oils&oils obtained from bituminous m...
# 28     Petroleum oils&oils obtained from bituminous m...
# 29     Petroleum oils&oils obtained from bituminous m...
# ...                                                  ...
# 10615  Petroleum oils&oils obtained from bituminous m...
# 10616  Petroleum oils&oils obtained from bituminous m...
# 10617  Petroleum oils&oils obtained from bituminous m...
# 10618  Petroleum oils&oils obtained from bituminous m...
# 10621  Petroleum oils&oils obtained from bituminous m...
# 10622  Petroleum oils&oils obtained from bituminous m...
# 10623  Petroleum oils&oils obtained from bituminous m...
# 10624  Petroleum oils&oils obtained from bituminous m...
# 10625  Petroleum oils&oils obtained from bituminous m...
# 10627  Petroleum oils&oils obtained from bituminous m...
# 10639  Petroleum oils&oils obtained from bituminous m...
# 10640  Petroleum oils&oils obtained from bituminous m...
# 10641  Petroleum oils&oils obtained from bituminous m...
# 10642  Petroleum oils&oils obtained from bituminous m...
# 10644  Petroleum oils&oils obtained from bituminous m...
# 10645  Petroleum oils&oils obtained from bituminous m...
# 10646  Petroleum oils&oils obtained from bituminous m...
# 10649  Petroleum oils&oils obtained from bituminous m...
# 10650  Petroleum oils&oils obtained from bituminous m...
# 10661  Petroleum oils&oils obtained from bituminous m...
# 10662  Petroleum oils&oils obtained from bituminous m...
# 10663  Petroleum oils&oils obtained from bituminous m...
# 10668  Petroleum oils&oils obtained from bituminous m...
# 10669  Petroleum oils&oils obtained from bituminous m...
# 10678  Petroleum oils&oils obtained from bituminous m...
# 10679  Petroleum oils&oils obtained from bituminous m...
# 10680  Petroleum oils&oils obtained from bituminous m...
# 10684  Petroleum oils&oils obtained from bituminous m...
# 10685  Petroleum oils&oils obtained from bituminous m...
# 10686  Petroleum oils&oils obtained from bituminous m...
#
#        Trading partner code    Trading partner   Quantity       Unit  \
# 0                       126               Oman  1365277.0  Kilograms
# 1                       113               Iran  1891841.0  Kilograms
# 2                       131       Saudi Arabia  1604366.0  Kilograms
# 3                       139              Yemen   353846.0  Kilograms
# 4                       114               Iraq   353846.0  Kilograms
# 5                       130              Qatar   135634.0  Kilograms
# 6                       138                UAE   569072.0  Kilograms
# 7                       118             Kuwait   139773.0  Kilograms
# 8                       135              Syria   139773.0  Kilograms
# 9                       112          Indonesia   486129.0  Kilograms
# 10                      141            Vietnam   136191.0  Kilograms
# 11                      601          Australia    81980.0  Kilograms
# 12                      122           Malaysia    34531.0  Kilograms
# 13                      105             Brunei    81965.0  Kilograms
# 14                      136           Thailand   151893.0  Kilograms
# 15                      611   Papua New Guinea   151893.0  Kilograms
# 16                      124           Mongolia     4924.0  Kilograms
# 17                      127           Pakistan     4924.0  Kilograms
# 18                      132          Singapore     4924.0  Kilograms
# 19                      116              Japan     4924.0  Kilograms
# 20                      106            Myanmar     4924.0  Kilograms
# 21                      110          Hong Kong     4924.0  Kilograms
# 22                      143      Taiwan, China     4924.0  Kilograms
# 23                      142              China     4924.0  Kilograms
# 24                      609        New Zealand     4924.0  Kilograms
# 25                      111              India     4924.0  Kilograms
# 26                      133        South Korea     4924.0  Kilograms
# 27                      129        Philippines     4924.0  Kilograms
# 28                      202             Angola  1553668.0  Kilograms
# 29                      218              Gabon   131658.0  Kilograms
# ...                     ...                ...        ...        ...
# 10615                   114               Iraq  3132628.0  Kilograms
# 10616                   130              Qatar    65751.0  Kilograms
# 10617                   138                UAE  1687388.0  Kilograms
# 10618                   118             Kuwait  1483663.0  Kilograms
# 10621                   141            Vietnam   223611.0  Kilograms
# 10622                   601          Australia   288799.0  Kilograms
# 10623                   122           Malaysia   907074.0  Kilograms
# 10624                   105             Brunei    75659.0  Kilograms
# 10625                   136           Thailand    42725.0  Kilograms
# 10627                   124           Mongolia    89558.0  Kilograms
# 10639                   202             Angola  3397961.0  Kilograms
# 10640                   218              Gabon   437706.0  Kilograms
# 10641                   246              Sudan    94739.0  Kilograms
# 10642                   216  Equatorial Guinea   137441.0  Kilograms
# 10644                   226              Libya   376710.0  Kilograms
# 10645                   215              Egypt   136545.0  Kilograms
# 10646                   213              Congo   600035.0  Kilograms
# 10649                   220              Ghana   258062.0  Kilograms
# 10650                   260        South Sudan   450104.0  Kilograms
# 10661                   145         Kazakhstan   203310.0  Kilograms
# 10662                   344             Russia  5040687.0  Kilograms
# 10663                   339         Azerbaijan   265523.0  Kilograms
# 10668                   326             Norway   138349.0  Kilograms
# 10669                   303     United Kingdom   937780.0  Kilograms
# 10678                   429             Mexico    73878.0  Kilograms
# 10679                   410             Brazil  2552761.0  Kilograms
# 10680                   402          Argentina   296705.0  Kilograms
# 10684                   419            Ecuador   307034.0  Kilograms
# 10685                   445          Venezuela  1749681.0  Kilograms
# 10686                   413           Columbia   628335.0  Kilograms
#
#       Supplimentary Quantity Supplimentary Unit Renminbi Yuan
# 0                          0                  -          None
# 1                          0                  -          None
# 2                          0                  -          None
# 3                          0                  -          None
# 4                          0                  -          None
# 5                          0                  -          None
# 6                          0                  -          None
# 7                          0                  -          None
# 8                          0                  -          None
# 9                          0                  -          None
# 10                         0                  -          None
# 11                         0                  -          None
# 12                         0                  -          None
# 13                         0                  -          None
# 14                         0                  -          None
# 15                         0                  -          None
# 16                         0                  -          None
# 17                         0                  -          None
# 18                         0                  -          None
# 19                         0                  -          None
# 20                         0                  -          None
# 21                         0                  -          None
# 22                         0                  -          None
# 23                         0                  -          None
# 24                         0                  -          None
# 25                         0                  -          None
# 26                         0                  -          None
# 27                         0                  -          None
# 28                         0                  -          None
# 29                         0                  -          None
# ...                      ...                ...           ...
# 10615                      0                  -          None
# 10616                      0                  -          None
# 10617                      0                  -          None
# 10618                      0                  -          None
# 10621                      0                  -          None
# 10622                      0                  -          None
# 10623                      0                  -          None
# 10624                      0                  -          None
# 10625                      0                  -          None
# 10627                      0                  -          None
# 10639                      0                  -          None
# 10640                      0                  -          None
# 10641                      0                  -          None
# 10642                      0                  -          None
# 10644                      0                  -          None
# 10645                      0                  -          None
# 10646                      0                  -          None
# 10649                      0                  -          None
# 10650                      0                  -          None
# 10661                      0                  -          None
# 10662                      0                  -          None
# 10663                      0                  -          None
# 10668                      0                  -          None
# 10669                      0                  -          None
# 10678                      0                  -          None
# 10679                      0                  -          None
# 10680                      0                  -          None
# 10684                      0                  -          None
# 10685                      0                  -          None
# 10686                      0                  -          None
#
# [9521 rows x 10 columns]

# %% [markdown]
# # 1995 - 2005

# %%
# 1995 - 2005
country_mapping = {'Russia': 'Russian Federation',
                   'Saudi': 'Saudi Arabia',
                   'Congo': 'Republic of Congo',
                   'Libya': 'Libyan Arab Jamahiriya',
                   'UAE': 'United Arab Emirates',
                   'Democratic Republic of the Congo': 'Congo (Gold)',
                   'South Sudan': 'Republic of South Sudan',
                   'US': 'United States',
                   'UK': 'United Kingdom'}


df = pd.read_excel('G:\OMRrefinery\China\Exportimport\China Import History.xls', 'Oil Imports').query('Period.dt.year < 2006')
df = df.assign(**{'Date of data' : df.Period.dt.strftime("%Y%m"),
                'Commodity code': '27090000',
                'Commodity': 'Petroleum oils&oils obtained from bituminous minerals, crude',
                'Unit': 'Kilograms',
                'Supplimentary Quantity': '0',
                'Supplimentary Unit': '-',
                'Renminbi Yuan': None})\
       .rename(columns={"Product Code": "Commodity code",
                        "Attribute": "Trading partner",
                    "Country Code": "Trading partner code",
                    "Value": "Quantity"})
df['Trading partner'] = df['Trading partner'].apply(lambda x : country_mapping[x] if x in country_mapping else x)

# %%
df.head()
# Out:
#       Period Trading partner   Quantity Date of data Commodity code  \
# 0 1995-01-31            Oman  139218345       199501       27090000
# 1 1995-01-31       Indonesia  149962998       199501       27090000
# 2 1995-02-28       Indonesia  209311244       199502       27090000
# 3 1995-03-31          Angola  250294188       199503       27090000
# 4 1995-03-31            Oman  414925988       199503       27090000
#
#                                            Commodity       Unit  \
# 0  Petroleum oils&oils obtained from bituminous m...  Kilograms
# 1  Petroleum oils&oils obtained from bituminous m...  Kilograms
# 2  Petroleum oils&oils obtained from bituminous m...  Kilograms
# 3  Petroleum oils&oils obtained from bituminous m...  Kilograms
# 4  Petroleum oils&oils obtained from bituminous m...  Kilograms
#
#   Supplimentary Quantity Supplimentary Unit Renminbi Yuan
# 0                      0                  -          None
# 1                      0                  -          None
# 2                      0                  -          None
# 3                      0                  -          None
# 4                      0                  -          None

# %%
mapping = pd.read_excel('cn_customs_mappings.xlsx', 'COUNTRIES')

# %%
merged = df.merge(mapping, left_on = 'Trading partner', right_on = 'country_name_en', how='left', indicator='join_side').rename(columns={'country_code': 'Trading partner code'})
if len(merged.query('join_side == "left_only"')[['Trading partner']].drop_duplicates()) > 0:
        raise ValueError("still wrong names")
merged = merged[["Date of data","Commodity code","Commodity","Trading partner code","Trading partner","Quantity","Unit","Supplimentary Quantity","Supplimentary Unit","Renminbi Yuan"]].sort_values(by=['Date of data', 'Trading partner code'])
merged.head()
# Out:
#   Date of data Commodity code  \
# 1       199501       27090000
# 0       199501       27090000
# 2       199502       27090000
# 5       199503       27090000
# 4       199503       27090000
#
#                                            Commodity  Trading partner code  \
# 1  Petroleum oils&oils obtained from bituminous m...                   112
# 0  Petroleum oils&oils obtained from bituminous m...                   126
# 2  Petroleum oils&oils obtained from bituminous m...                   112
# 5  Petroleum oils&oils obtained from bituminous m...                   112
# 4  Petroleum oils&oils obtained from bituminous m...                   126
#
#   Trading partner   Quantity       Unit Supplimentary Quantity  \
# 1       Indonesia  149962998  Kilograms                      0
# 0            Oman  139218345  Kilograms                      0
# 2       Indonesia  209311244  Kilograms                      0
# 5       Indonesia  796453975  Kilograms                      0
# 4            Oman  414925988  Kilograms                      0
#
#   Supplimentary Unit Renminbi Yuan
# 1                  -          None
# 0                  -          None
# 2                  -          None
# 5                  -          None
# 4                  -          None

# %%
merged['Date of data'].drop_duplicates()
# Out:
# 1       199501
# 2       199502
# 5       199503
# 11      199504
# 18      199505
# 29      199506
# 34      199507
# 40      199508
# 47      199509
# 53      199510
# 57      199511
# 64      199512
# 70      199701
# 77      199702
# 82      199703
# 89      199704
# 96      199705
# 103     199706
# 111     199707
# 120     199708
# 130     199709
# 139     199710
# 147     199711
# 158     199712
# 167     199801
# 178     199802
# 190     199803
# 199     199804
# 205     199805
# 214     199806
#          ...
# 1025    200307
# 1039    200308
# 1055    200309
# 1073    200310
# 1092    200311
# 1107    200312
# 1123    200401
# 1138    200402
# 1154    200403
# 1171    200404
# 1192    200405
# 1211    200406
# 1229    200407
# 1245    200408
# 1264    200409
# 1282    200410
# 1299    200411
# 1316    200412
# 1332    200501
# 1348    200502
# 1365    200503
# 1385    200504
# 1406    200505
# 1423    200506
# 1441    200507
# 1461    200508
# 1479    200509
# 1500    200510
# 1519    200511
# 1536    200512
# Name: Date of data, Length: 120, dtype: object

# %%
merged.to_csv('cn_customs_crudeoil_imp_1995_2005.csv', index=False)

# %% [markdown]
# # Load history into External-DB

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import scraper.jobs.cn_customs.crude_imports_job as crude_imports_job
import logging
crude_imports_job.logger.level = logging.DEBUG

cn = crude_imports_job.CrudeImportsJob(full_load=True)

cn.run()
# Out:
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# WARNING:scraper.jobs.cn_customs.crude_imports_job:Download method not implemented
# c:\users\rosa_l\pycharmprojects\scrapper\venv\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
cn.transform()
# Out:
# c:\users\rosa_l\pycharmprojects\scrapper\venv\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
cn.data[1:10]
# Out:
# [{'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'MYANMAR',
#   'unit': 'KT',
#   'value': 0.0,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'KOREADPR',
#   'unit': 'KT',
#   'value': 51.13,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'HONGKONG',
#   'unit': 'KT',
#   'value': 0.0,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'INDIA',
#   'unit': 'KT',
#   'value': 0.0,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'INDONESIA',
#   'unit': 'KT',
#   'value': 486.129,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'INDONESIA',
#   'unit': 'KT',
#   'value': 34.531,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'INDONESIA',
#   'unit': 'KT',
#   'value': 0.0,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'IRAN',
#   'unit': 'KT',
#   'value': 1891.841,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True},
#  {'source': 'cn_customs_crudeoil_imp_2006',
#   'period': 'JAN2006',
#   'to_area': 'IRAN',
#   'unit': 'KT',
#   'value': 0.0,
#   'provider': 'CN_CUSTOMS',
#   'area': 'CHINA',
#   'product': 'CRUDEOIL',
#   'frequency': 'Monthly',
#   'flow': 'IMPORTS',
#   'original': True}]

# %%
import pandas as pd
df = pd.DataFrame(cn.data)

# %%
#df.dropna(axis='index', subset=['value'],inplace=True)
df.isnull().values.any()
# Out:
# False

# %%
df
# Out:
#         area     flow frequency  original   period   product    provider  \
# 0      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 1      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 2      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 3      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 4      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 5      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 6      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 7      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 8      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 9      CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 10     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 11     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 12     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 13     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 14     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 15     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 16     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 17     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 18     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 19     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 20     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 21     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 22     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 23     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 24     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 25     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 26     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 27     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 28     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# 29     CHINA  IMPORTS   Monthly      True  JAN2006  CRUDEOIL  CN_CUSTOMS
# ...      ...      ...       ...       ...      ...       ...         ...
# 14947  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14948  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14949  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14950  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14951  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14952  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14953  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14954  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14955  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14956  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14957  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14958  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14959  CHINA  IMPORTS   Monthly      True  NOV2005  CRUDEOIL  CN_CUSTOMS
# 14960  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14961  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14962  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14963  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14964  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14965  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14966  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14967  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14968  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14969  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14970  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14971  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14972  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14973  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14974  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14975  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
# 14976  CHINA  IMPORTS   Monthly      True  DEC2005  CRUDEOIL  CN_CUSTOMS
#
#                              source     to_area unit        value
# 0      cn_customs_crudeoil_imp_2006      BRUNEI   KT    81.965000
# 1      cn_customs_crudeoil_imp_2006     MYANMAR   KT     0.000000
# 2      cn_customs_crudeoil_imp_2006    KOREADPR   KT    51.130000
# 3      cn_customs_crudeoil_imp_2006    HONGKONG   KT     0.000000
# 4      cn_customs_crudeoil_imp_2006       INDIA   KT     0.000000
# 5      cn_customs_crudeoil_imp_2006   INDONESIA   KT   486.129000
# 6      cn_customs_crudeoil_imp_2006   INDONESIA   KT    34.531000
# 7      cn_customs_crudeoil_imp_2006   INDONESIA   KT     0.000000
# 8      cn_customs_crudeoil_imp_2006        IRAN   KT  1891.841000
# 9      cn_customs_crudeoil_imp_2006        IRAN   KT     0.000000
# 10     cn_customs_crudeoil_imp_2006        IRAQ   KT     0.000000
# 11     cn_customs_crudeoil_imp_2006      ISRAEL   KT     0.000000
# 12     cn_customs_crudeoil_imp_2006       JAPAN   KT     0.000000
# 13     cn_customs_crudeoil_imp_2006      KUWAIT   KT   135.634000
# 14     cn_customs_crudeoil_imp_2006      KUWAIT   KT   139.773000
# 15     cn_customs_crudeoil_imp_2006    MALAYSIA   KT     0.000000
# 16     cn_customs_crudeoil_imp_2006    MONGOLIA   KT     4.924000
# 17     cn_customs_crudeoil_imp_2006        OMAN   KT  1365.277000
# 18     cn_customs_crudeoil_imp_2006        OMAN   KT     0.000000
# 19     cn_customs_crudeoil_imp_2006    PAKISTAN   KT     0.000000
# 20     cn_customs_crudeoil_imp_2006  PHILIPPINE   KT     0.000000
# 21     cn_customs_crudeoil_imp_2006  SAUDIARABI   KT  1604.366000
# 22     cn_customs_crudeoil_imp_2006   SINGAPORE   KT     0.000000
# 23     cn_customs_crudeoil_imp_2006   SINGAPORE   KT    78.868000
# 24     cn_customs_crudeoil_imp_2006       KOREA   KT     0.000000
# 25     cn_customs_crudeoil_imp_2006       KOREA   KT   257.709000
# 26     cn_customs_crudeoil_imp_2006       SYRIA   KT     0.000000
# 27     cn_customs_crudeoil_imp_2006    THAILAND   KT   151.893000
# 28     cn_customs_crudeoil_imp_2006    THAILAND   KT     0.000000
# 29     cn_customs_crudeoil_imp_2006      TURKEY   KT     0.000000
# ...                             ...         ...  ...          ...
# 14947  cn_customs_crudeoil_imp_1995    THAILAND   KT    73.607720
# 14948  cn_customs_crudeoil_imp_1995         UAE   KT   131.891000
# 14949  cn_customs_crudeoil_imp_1995     VIETNAM   KT   311.278182
# 14950  cn_customs_crudeoil_imp_1995  KAZAKHSTAN   KT    71.204441
# 14951  cn_customs_crudeoil_imp_1995     ALGERIA   KT   173.350028
# 14952  cn_customs_crudeoil_imp_1995      ANGOLA   KT  1667.548102
# 14953  cn_customs_crudeoil_imp_1995       CONGO   KT   763.598424
# 14954  cn_customs_crudeoil_imp_1995    EQGUINEA   KT   424.397079
# 14955  cn_customs_crudeoil_imp_1995       LIBYA   KT    70.056000
# 14956  cn_customs_crudeoil_imp_1995       SUDAN   KT   393.389670
# 14957  cn_customs_crudeoil_imp_1995      RUSSIA   KT  1320.764460
# 14958  cn_customs_crudeoil_imp_1995      BRAZIL   KT   140.000000
# 14959  cn_customs_crudeoil_imp_1995   VENEZUELA   KT   137.974970
# 14960  cn_customs_crudeoil_imp_1995   INDONESIA   KT   304.569243
# 14961  cn_customs_crudeoil_imp_1995        IRAN   KT   415.524040
# 14962  cn_customs_crudeoil_imp_1995    MONGOLIA   KT     0.857840
# 14963  cn_customs_crudeoil_imp_1995        OMAN   KT  1009.865666
# 14964  cn_customs_crudeoil_imp_1995  SAUDIARABI   KT  2164.955612
# 14965  cn_customs_crudeoil_imp_1995    THAILAND   KT    55.235677
# 14966  cn_customs_crudeoil_imp_1995         UAE   KT   258.713609
# 14967  cn_customs_crudeoil_imp_1995     VIETNAM   KT   187.167383
# 14968  cn_customs_crudeoil_imp_1995  KAZAKHSTAN   KT   138.418755
# 14969  cn_customs_crudeoil_imp_1995      ANGOLA   KT  2059.892784
# 14970  cn_customs_crudeoil_imp_1995       CONGO   KT   297.718921
# 14971  cn_customs_crudeoil_imp_1995    EQGUINEA   KT   412.281100
# 14972  cn_customs_crudeoil_imp_1995       LIBYA   KT   193.493590
# 14973  cn_customs_crudeoil_imp_1995       SUDAN   KT   412.379851
# 14974  cn_customs_crudeoil_imp_1995      RUSSIA   KT  1231.030485
# 14975  cn_customs_crudeoil_imp_1995      BRAZIL   KT   112.232040
# 14976  cn_customs_crudeoil_imp_1995   VENEZUELA   KT   736.047020
#
# [14977 rows x 11 columns]

# %%
cn.sources
# Out:
# ['BaseSource(c...imp_2006.csv)', 'BaseSource(c...imp_1995.csv)']

# %%
df.index
# Out:
# Index([], dtype='object')

# %%
import pandas as pd
data = pd.DataFrame([{'country': 'AUSTRALI'}])
data.isin(['AUSTRALIA', 'BRAZIL'])
# Out:
#    country
# 0    False

# %%
len(data.index)
# Out:
# 1
